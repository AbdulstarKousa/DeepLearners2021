# %%
## ====================== Mount Google Drive:
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
## ====================== Libraries:
""" For plotting """
import numpy as np
import matplotlib.pyplot as plt

""" For IPython """
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')

""" For conversion """
from skimage.color import lab2rgb, rgb2lab, rgb2gray

""" For everything """
import torch
import torch.nn as nn
import torch.nn.functional as F

""" For our model """
import torchvision.models as models
from torchvision import datasets, transforms

""" For utilities """
import os, time

""" Check if GPU is available """
use_gpu = torch.cuda.is_available()

"""" new """
import glob
from torch.utils.data import Dataset, DataLoader
from PIL import Image

# %%
train_paths[0]
# Out:
# '/content/gdrive/MyDrive/Data/DeepLearning2021/images/train/death cap/2828975396_f32cfd25e1.jpg'

# %%
## ====================== Load data:
# paths
train_path = '/content/gdrive/MyDrive/Data/DeepLearning2021/images/train'
val_path   = '/content/gdrive/MyDrive/Data/DeepLearning2021/images/val'
train_paths = glob.glob(train_path + "/**/*.jpg") # Grabbing all the image file names
val_paths   = glob.glob(val_path + "/**/*.jpg")   # Grabbing all the image file names

# def dataset
SIZE = 256
class ColorizationDataset(Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE),  Image.BICUBIC),
                transforms.RandomHorizontalFlip(), # A little data augmentation!
            ])
        elif split == 'val':
            self.transforms = transforms.Resize((SIZE, SIZE),  Image.BICUBIC)
        
        self.split = split
        self.size = SIZE
        self.paths = paths
        self.labels = list(set([value.split('/')[2] for value in paths]))
        self.class_to_idx = {j:i for i, j in enumerate(self.labels)}
        
    def __getitem__(self, idx):
        img = Image.open(self.paths[idx]).convert("RGB")
        img = self.transforms(img)
        img = np.array(img)
        img_lab = rgb2lab(img).astype("float32") # Converting RGB to L*a*b
        img_lab = transforms.ToTensor()(img_lab)
        L = img_lab[[0], ...] / 50. - 1. # Between -1 and 1
        ab = img_lab[[1, 2], ...] / 110. # Between -1 and 1
        label = self.paths[idx].split("/")[2]
        idx = self.class_to_idx[label]
        # return {'L': L, 'ab': ab, "label": idx}
        img_original = L
        img_ab = ab
        target = idx
        return img_original, img_ab, target
    
    def __len__(self):
        return len(self.paths)

# def dataloader
def make_dataloaders(batch_size=16, n_workers=0, pin_memory=True, **kwargs): # A handy function to make our dataloaders
    dataset = ColorizationDataset(**kwargs)
    dataloader = DataLoader(dataset, 
                            batch_size=batch_size, 
                            num_workers=n_workers,
                            pin_memory=pin_memory)
    return dataloader

# loaders 
train_loader = make_dataloaders(paths=train_paths, split='train')
val_loader = make_dataloaders(paths=val_paths, split='val')
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "

# %%
# check 
batche_size = 16
print(f"batche size: {batche_size}")
batches = iter(train_loader)
print(f"number of Batches: {len(batches)}")
batch = next(batches)
print(f"number of features: {len(batch)}")
feature_01 = batch[0] 
print(f"features 01 shape: {feature_01.size()}")
observation_01 = feature_01[0]
print(f"observations 01 shape: {observation_01.size()}")
img = observation_01.squeeze()
print(f"image shape: {img.size()}")
plt.imshow(img, cmap="gray")
plt.show()
# Out:
# batche size: 16
# number of Batches: 134
# number of features: 3
# features 01 shape: torch.Size([16, 1, 256, 256])
# observations 01 shape: torch.Size([1, 256, 256])
# image shape: torch.Size([256, 256])

# %%
## ====================== The Model:
class ColorizationNet(nn.Module):
  def __init__(self, input_size=128):
    super(ColorizationNet, self).__init__()
    MIDLEVEL_FEATURE_SIZE = 128

    # First half: ResNet
    resnet = models.resnet18(num_classes=365) 
    """ Change first conv layer to accept single-channel (grayscale) input """
    resnet.conv1.weight = nn.Parameter(resnet.conv1.weight.sum(dim=1).unsqueeze(1)) 
    """ Extract midlevel features from ResNet-gray """
    self.midlevel_resnet = nn.Sequential(*list(resnet.children())[0:6])

    # Second half: Upsampling
    self.upsample = nn.Sequential(     
      nn.Conv2d(MIDLEVEL_FEATURE_SIZE, 128, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(128),
      nn.ReLU(),
      nn.Upsample(scale_factor=2),
      nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(64),
      nn.ReLU(),
      nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(64),
      nn.ReLU(),
      nn.Upsample(scale_factor=2),
      nn.Conv2d(64, 32, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(32),
      nn.ReLU(),
      nn.Conv2d(32, 2, kernel_size=3, stride=1, padding=1),
      nn.Upsample(scale_factor=2)
    )

  def forward(self, input):
    # Pass input through ResNet-gray to extract features
    midlevel_features = self.midlevel_resnet(input)
    # Upsample to get colors
    output = self.upsample(midlevel_features)
    return output

model = ColorizationNet()

# %%
## ====================== Helper functions:
class AverageMeter(object):
  '''A handy class from the PyTorch ImageNet tutorial''' 
  def __init__(self):
    self.reset()

  def reset(self):
    self.val, self.avg, self.sum, self.count = 0, 0, 0, 0

  def update(self, val, n=1):
    self.val = val
    self.sum += val * n
    self.count += n
    self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
  '''Show/save rgb image from grayscale and ab channels
     Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
  plt.clf() # clear matplotlib 
  color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
  color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
  color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
  color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
  color_image = lab2rgb(color_image.astype(np.float64))
  grayscale_input = grayscale_input.squeeze().numpy()
  if save_path is not None and save_name is not None: 
    plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
    plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
## ====================== Set-up Training:
# Loss Function
criterion = nn.MSELoss()

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2, weight_decay=0.0)

## ====================== Training:
def train(train_loader, model, criterion, optimizer, epoch):
  print('Starting training epoch {}'.format(epoch))
  model.train()
  
  # Prepare value counters and timers
  batch_time, data_time, losses = AverageMeter(), AverageMeter(), AverageMeter()

  end = time.time()
  for i, (input_gray, input_ab, target) in enumerate(train_loader):
    
    # Use GPU if available
    if use_gpu: input_gray, input_ab, target = input_gray.cuda(), input_ab.cuda(), target.cuda()

    # Record time to load data (above)
    data_time.update(time.time() - end)

    # Run forward pass
    output_ab = model(input_gray) 
    loss = criterion(output_ab, input_ab) 
    losses.update(loss.item(), input_gray.size(0))

    # Compute gradient and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Record time to do forward and backward passes
    batch_time.update(time.time() - end)
    end = time.time()

    # Print model accuracy -- in the code below, val refers to value, not validation
    if i % 25 == 0:
      print('Epoch: [{0}][{1}/{2}]\t'
            'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
            'Data {data_time.val:.3f} ({data_time.avg:.3f})\t'
            'Loss {loss.val:.4f} ({loss.avg:.4f})\t'.format(
              epoch, i, len(train_loader), batch_time=batch_time,
             data_time=data_time, loss=losses)) 

  print('Finished training epoch {}'.format(epoch))

# %%
## ====================== Validation:
def validate(val_loader, model, criterion, save_images, epoch):
  model.eval()

  # Prepare value counters and timers
  batch_time, data_time, losses = AverageMeter(), AverageMeter(), AverageMeter()

  end = time.time()
  already_saved_images = False
  for i, (input_gray, input_ab, target) in enumerate(val_loader):
    data_time.update(time.time() - end)

    # Use GPU
    if use_gpu: input_gray, input_ab, target = input_gray.cuda(), input_ab.cuda(), target.cuda()

    # Run model and record loss
    output_ab = model(input_gray) # throw away class predictions
    loss = criterion(output_ab, input_ab)
    losses.update(loss.item(), input_gray.size(0))

    # Save images to file
    if save_images and not already_saved_images:
      already_saved_images = True
      for j in range(min(len(output_ab), 10)): # save at most 5 images
        save_path = {'grayscale': 'outputs/gray/', 'colorized': 'outputs/color/'}
        save_name = 'img-{}-epoch-{}.jpg'.format(i * val_loader.batch_size + j, epoch)
        to_rgb(input_gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    # Record time to do forward passes and save images
    batch_time.update(time.time() - end)
    end = time.time()

    # Print model accuracy -- in the code below, val refers to both value and validation
    if i % 25 == 0:
      print('Validate: [{0}/{1}]\t'
            'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
            'Loss {loss.val:.4f} ({loss.avg:.4f})\t'.format(
             i, len(val_loader), batch_time=batch_time, loss=losses))

  print('Finished validation.')
  return losses.avg

# %%
## ====================== Main Driver:
# to GPU
if use_gpu: 
  criterion = criterion.cuda()
  model = model.cuda()

# Make folders and set parameters
import os
os.makedirs('outputs/color', exist_ok=True)
os.makedirs('outputs/gray', exist_ok=True)
os.makedirs('checkpoints', exist_ok=True)
save_images = False
best_losses = 1e10
epochs = 100

# Train model
for epoch in range(epochs):
  # Train for one epoch, then validate
  train(train_loader, model, criterion, optimizer, epoch)
  with torch.no_grad():
    losses = validate(val_loader, model, criterion, save_images, epoch)
  # Save checkpoint and replace old best model if current model is better
  if losses < best_losses:
    best_losses = losses
    torch.save(model.state_dict(), 'checkpoints/model-epoch-{}-losses-{:.3f}.pth'.format(epoch+1,losses))
# Out:
# Starting training epoch 0
# Epoch: [0][0/134]	Time 0.837 (0.837)	Data 0.494 (0.494)	Loss 0.1147 (0.1147)
# Epoch: [0][25/134]	Time 4.790 (4.325)	Data 4.763 (4.286)	Loss 0.0394 (0.0399)
# Epoch: [0][50/134]	Time 4.126 (4.271)	Data 4.098 (4.238)	Loss 0.0248 (0.0330)
# Epoch: [0][75/134]	Time 4.188 (4.301)	Data 4.161 (4.270)	Loss 0.0356 (0.0321)
# Epoch: [0][100/134]	Time 4.220 (4.303)	Data 4.193 (4.273)	Loss 0.0229 (0.0316)
# Epoch: [0][125/134]	Time 4.237 (4.313)	Data 4.210 (4.284)	Loss 0.0244 (0.0331)
# Finished training epoch 0
# Validate: [0/34]	Time 4.070 (4.070)	Loss 0.0492 (0.0492)
# Validate: [25/34]	Time 4.192 (4.288)	Loss 0.1244 (0.1429)
# Finished validation.
# Starting training epoch 1
# Epoch: [1][0/134]	Time 0.527 (0.527)	Data 0.500 (0.500)	Loss 0.0143 (0.0143)
# Epoch: [1][25/134]	Time 0.510 (0.533)	Data 0.483 (0.506)	Loss 0.0192 (0.0197)
# Epoch: [1][50/134]	Time 0.545 (0.528)	Data 0.518 (0.502)	Loss 0.0209 (0.0236)
# Epoch: [1][75/134]	Time 0.502 (0.527)	Data 0.475 (0.500)	Loss 0.0399 (0.0260)
# Epoch: [1][100/134]	Time 0.516 (0.525)	Data 0.490 (0.498)	Loss 0.0256 (0.0271)
# Epoch: [1][125/134]	Time 0.513 (0.523)	Data 0.486 (0.496)	Loss 0.0179 (0.0283)
# Finished training epoch 1
# Validate: [0/34]	Time 0.515 (0.515)	Loss 0.0369 (0.0369)
# Validate: [25/34]	Time 0.506 (0.508)	Loss 0.0290 (0.0254)
# Finished validation.
# Starting training epoch 2
# Epoch: [2][0/134]	Time 0.519 (0.519)	Data 0.491 (0.491)	Loss 0.0138 (0.0138)
# Epoch: [2][25/134]	Time 0.512 (0.533)	Data 0.486 (0.507)	Loss 0.0187 (0.0192)
# Epoch: [2][50/134]	Time 0.538 (0.528)	Data 0.511 (0.501)	Loss 0.0241 (0.0218)
# Epoch: [2][75/134]	Time 0.495 (0.524)	Data 0.469 (0.497)	Loss 0.0395 (0.0244)
# Epoch: [2][100/134]	Time 0.513 (0.523)	Data 0.484 (0.496)	Loss 0.0241 (0.0258)
# Epoch: [2][125/134]	Time 0.520 (0.521)	Data 0.493 (0.495)	Loss 0.0179 (0.0273)
# Finished training epoch 2
# Validate: [0/34]	Time 0.518 (0.518)	Loss 0.0375 (0.0375)
# Validate: [25/34]	Time 0.501 (0.510)	Loss 0.0287 (0.0251)
# Finished validation.
# Starting training epoch 3
# Epoch: [3][0/134]	Time 0.510 (0.510)	Data 0.484 (0.484)	Loss 0.0133 (0.0133)
# Epoch: [3][25/134]	Time 0.497 (0.527)	Data 0.470 (0.500)	Loss 0.0193 (0.0194)
# Epoch: [3][50/134]	Time 0.528 (0.524)	Data 0.502 (0.498)	Loss 0.0250 (0.0219)
# Epoch: [3][75/134]	Time 0.492 (0.522)	Data 0.465 (0.495)	Loss 0.0393 (0.0246)
# Epoch: [3][100/134]	Time 0.502 (0.520)	Data 0.475 (0.494)	Loss 0.0253 (0.0260)
# Epoch: [3][125/134]	Time 0.507 (0.519)	Data 0.480 (0.493)	Loss 0.0176 (0.0273)
# Finished training epoch 3
# Validate: [0/34]	Time 0.510 (0.510)	Loss 0.0365 (0.0365)
# Validate: [25/34]	Time 0.501 (0.508)	Loss 0.0289 (0.0255)
# Finished validation.
# Starting training epoch 4
# Epoch: [4][0/134]	Time 0.531 (0.531)	Data 0.504 (0.504)	Loss 0.0135 (0.0135)
# Epoch: [4][25/134]	Time 0.509 (0.534)	Data 0.482 (0.508)	Loss 0.0192 (0.0196)
# Epoch: [4][50/134]	Time 0.544 (0.529)	Data 0.517 (0.502)	Loss 0.0250 (0.0220)
# Epoch: [4][75/134]	Time 0.501 (0.526)	Data 0.474 (0.499)	Loss 0.0390 (0.0246)
# Epoch: [4][100/134]	Time 0.509 (0.524)	Data 0.481 (0.497)	Loss 0.0253 (0.0260)
# Epoch: [4][125/134]	Time 0.509 (0.521)	Data 0.482 (0.494)	Loss 0.0178 (0.0273)
# Finished training epoch 4
# Validate: [0/34]	Time 0.510 (0.510)	Loss 0.0366 (0.0366)
# Validate: [25/34]	Time 0.500 (0.504)	Loss 0.0293 (0.0259)
# Finished validation.
# Starting training epoch 5
# Epoch: [5][0/134]	Time 0.518 (0.518)	Data 0.491 (0.491)	Loss 0.0139 (0.0139)
# Epoch: [5][25/134]	Time 0.504 (0.528)	Data 0.477 (0.501)	Loss 0.0192 (0.0197)
# Epoch: [5][50/134]	Time 0.531 (0.526)	Data 0.504 (0.499)	Loss 0.0249 (0.0221)
# Epoch: [5][75/134]	Time 0.496 (0.522)	Data 0.468 (0.495)	Loss 0.0389 (0.0246)
# Epoch: [5][100/134]	Time 0.511 (0.521)	Data 0.484 (0.494)	Loss 0.0243 (0.0259)
# Epoch: [5][125/134]	Time 0.508 (0.519)	Data 0.482 (0.492)	Loss 0.0178 (0.0275)
# Finished training epoch 5
# Validate: [0/34]	Time 0.515 (0.515)	Loss 0.0369 (0.0369)
# Validate: [25/34]	Time 0.508 (0.504)	Loss 0.0293 (0.0259)
# Finished validation.
# Starting training epoch 6
# Epoch: [6][0/134]	Time 0.513 (0.513)	Data 0.487 (0.487)	Loss 0.0140 (0.0140)
# Epoch: [6][25/134]	Time 0.505 (0.525)	Data 0.479 (0.499)	Loss 0.0192 (0.0196)
# Epoch: [6][50/134]	Time 0.534 (0.525)	Data 0.507 (0.498)	Loss 0.0251 (0.0220)
# Epoch: [6][75/134]	Time 0.500 (0.522)	Data 0.473 (0.496)	Loss 0.0394 (0.0246)
# Epoch: [6][100/134]	Time 0.511 (0.522)	Data 0.484 (0.495)	Loss 0.0250 (0.0260)
# Epoch: [6][125/134]	Time 0.512 (0.520)	Data 0.485 (0.493)	Loss 0.0177 (0.0274)
# Finished training epoch 6
# Validate: [0/34]	Time 0.514 (0.514)	Loss 0.0365 (0.0365)
# Validate: [25/34]	Time 0.502 (0.505)	Loss 0.0289 (0.0254)
# Finished validation.
# Starting training epoch 7
# Epoch: [7][0/134]	Time 0.514 (0.514)	Data 0.487 (0.487)	Loss 0.0137 (0.0137)
# Epoch: [7][25/134]	Time 0.503 (0.529)	Data 0.476 (0.502)	Loss 0.0191 (0.0196)
# Epoch: [7][50/134]	Time 0.530 (0.523)	Data 0.503 (0.496)	Loss 0.0245 (0.0220)
# Epoch: [7][75/134]	Time 0.504 (0.521)	Data 0.478 (0.495)	Loss 0.0398 (0.0246)
# Epoch: [7][100/134]	Time 0.505 (0.521)	Data 0.479 (0.494)	Loss 0.0257 (0.0260)
# Epoch: [7][125/134]	Time 0.498 (0.519)	Data 0.471 (0.492)	Loss 0.0177 (0.0273)
# Finished training epoch 7
# Validate: [0/34]	Time 0.513 (0.513)	Loss 0.0364 (0.0364)
# Validate: [25/34]	Time 0.502 (0.508)	Loss 0.0286 (0.0250)
# Finished validation.
# Starting training epoch 8
# Epoch: [8][0/134]	Time 0.519 (0.519)	Data 0.492 (0.492)	Loss 0.0135 (0.0135)
# Epoch: [8][25/134]	Time 0.501 (0.528)	Data 0.475 (0.501)	Loss 0.0210 (0.0202)
# Epoch: [8][50/134]	Time 0.536 (0.525)	Data 0.509 (0.498)	Loss 0.0255 (0.0224)
# Epoch: [8][75/134]	Time 0.506 (0.522)	Data 0.479 (0.495)	Loss 0.0393 (0.0249)
# Epoch: [8][100/134]	Time 0.514 (0.521)	Data 0.487 (0.495)	Loss 0.0250 (0.0262)
# Epoch: [8][125/134]	Time 0.513 (0.519)	Data 0.487 (0.493)	Loss 0.0179 (0.0276)
# Finished training epoch 8
# Validate: [0/34]	Time 0.517 (0.517)	Loss 0.0366 (0.0366)
# Validate: [25/34]	Time 0.504 (0.504)	Loss 0.0285 (0.0249)
# Finished validation.
# Starting training epoch 9
# Epoch: [9][0/134]	Time 0.527 (0.527)	Data 0.500 (0.500)	Loss 0.0132 (0.0132)
# Epoch: [9][25/134]	Time 0.501 (0.529)	Data 0.473 (0.502)	Loss 0.0193 (0.0195)
# Epoch: [9][50/134]	Time 0.521 (0.526)	Data 0.495 (0.499)	Loss 0.0250 (0.0219)
# Epoch: [9][75/134]	Time 0.494 (0.524)	Data 0.468 (0.497)	Loss 0.0394 (0.0246)
# Epoch: [9][100/134]	Time 0.512 (0.524)	Data 0.486 (0.497)	Loss 0.0260 (0.0260)
# Epoch: [9][125/134]	Time 0.507 (0.522)	Data 0.481 (0.495)	Loss 0.0195 (0.0272)
# Finished training epoch 9
# Validate: [0/34]	Time 0.511 (0.511)	Loss 0.0312 (0.0312)
# Validate: [25/34]	Time 0.499 (0.508)	Loss 0.0271 (0.0254)
# Finished validation.
# Starting training epoch 10
# Epoch: [10][0/134]	Time 0.513 (0.513)	Data 0.486 (0.486)	Loss 0.0142 (0.0142)
# Epoch: [10][25/134]	Time 0.505 (0.530)	Data 0.479 (0.504)	Loss 0.0185 (0.0206)
# Epoch: [10][50/134]	Time 0.526 (0.526)	Data 0.500 (0.499)	Loss 0.0248 (0.0225)
# Epoch: [10][75/134]	Time 0.496 (0.523)	Data 0.469 (0.497)	Loss 0.0393 (0.0249)
# Epoch: [10][100/134]	Time 0.511 (0.522)	Data 0.484 (0.495)	Loss 0.0260 (0.0263)
# Epoch: [10][125/134]	Time 0.505 (0.520)	Data 0.478 (0.493)	Loss 0.0178 (0.0275)
# Finished training epoch 10
# Validate: [0/34]	Time 0.506 (0.506)	Loss 0.0362 (0.0362)
# Validate: [25/34]	Time 0.498 (0.506)	Loss 0.0285 (0.0249)
# Finished validation.
# Starting training epoch 11
# Epoch: [11][0/134]	Time 0.517 (0.517)	Data 0.489 (0.489)	Loss 0.0135 (0.0135)
# Epoch: [11][25/134]	Time 0.498 (0.529)	Data 0.472 (0.502)	Loss 0.0192 (0.0194)
# Epoch: [11][50/134]	Time 0.531 (0.526)	Data 0.504 (0.500)	Loss 0.0252 (0.0218)
# Epoch: [11][75/134]	Time 0.485 (0.524)	Data 0.459 (0.497)	Loss 0.0392 (0.0245)
# Epoch: [11][100/134]	Time 0.511 (0.522)	Data 0.485 (0.495)	Loss 0.0260 (0.0259)
# Epoch: [11][125/134]	Time 0.503 (0.520)	Data 0.477 (0.494)	Loss 0.0179 (0.0272)
# Finished training epoch 11
# Validate: [0/34]	Time 0.509 (0.509)	Loss 0.0359 (0.0359)
# Validate: [25/34]	Time 0.507 (0.511)	Loss 0.0285 (0.0251)
# Finished validation.
# Starting training epoch 12
# Epoch: [12][0/134]	Time 0.517 (0.517)	Data 0.490 (0.490)	Loss 0.0137 (0.0137)
# Epoch: [12][25/134]	Time 0.509 (0.532)	Data 0.481 (0.506)	Loss 0.0192 (0.0194)
# Epoch: [12][50/134]	Time 0.532 (0.527)	Data 0.505 (0.500)	Loss 0.0252 (0.0218)
# Epoch: [12][75/134]	Time 0.496 (0.525)	Data 0.470 (0.498)	Loss 0.0392 (0.0245)
# Epoch: [12][100/134]	Time 0.509 (0.522)	Data 0.482 (0.495)	Loss 0.0259 (0.0259)
# Epoch: [12][125/134]	Time 0.510 (0.520)	Data 0.483 (0.493)	Loss 0.0180 (0.0272)
# Finished training epoch 12
# Validate: [0/34]	Time 0.530 (0.530)	Loss 0.0358 (0.0358)
# Validate: [25/34]	Time 0.509 (0.508)	Loss 0.0291 (0.0257)
# Finished validation.
# Starting training epoch 13
# Epoch: [13][0/134]	Time 0.525 (0.525)	Data 0.498 (0.498)	Loss 0.0140 (0.0140)
# Epoch: [13][25/134]	Time 0.502 (0.531)	Data 0.476 (0.504)	Loss 0.0192 (0.0194)
# Epoch: [13][50/134]	Time 0.529 (0.527)	Data 0.502 (0.501)	Loss 0.0253 (0.0218)
# Epoch: [13][75/134]	Time 0.505 (0.525)	Data 0.478 (0.498)	Loss 0.0389 (0.0244)
# Epoch: [13][100/134]	Time 0.527 (0.525)	Data 0.500 (0.498)	Loss 0.0193 (0.0257)
# Epoch: [13][125/134]	Time 0.498 (0.522)	Data 0.471 (0.496)	Loss 0.0173 (0.0279)
# Finished training epoch 13
# Validate: [0/34]	Time 0.525 (0.525)	Loss 0.0312 (0.0312)
# Validate: [25/34]	Time 0.510 (0.510)	Loss 0.0269 (0.0247)
# Finished validation.
# Starting training epoch 14
# Epoch: [14][0/134]	Time 0.525 (0.525)	Data 0.498 (0.498)	Loss 0.0144 (0.0144)
# Epoch: [14][25/134]	Time 0.501 (0.532)	Data 0.476 (0.505)	Loss 0.0185 (0.0201)
# Epoch: [14][50/134]	Time 0.528 (0.527)	Data 0.502 (0.500)	Loss 0.0250 (0.0222)
# Epoch: [14][75/134]	Time 0.499 (0.525)	Data 0.472 (0.498)	Loss 0.0396 (0.0248)
# Epoch: [14][100/134]	Time 0.518 (0.523)	Data 0.491 (0.496)	Loss 0.0258 (0.0261)
# Epoch: [14][125/134]	Time 0.501 (0.521)	Data 0.475 (0.494)	Loss 0.0178 (0.0274)
# Finished training epoch 14
# Validate: [0/34]	Time 0.509 (0.509)	Loss 0.0360 (0.0360)
# Validate: [25/34]	Time 0.507 (0.507)	Loss 0.0280 (0.0245)
# Finished validation.
# Starting training epoch 15
# Epoch: [15][0/134]	Time 0.516 (0.516)	Data 0.490 (0.490)	Loss 0.0133 (0.0133)
# Epoch: [15][25/134]	Time 0.502 (0.532)	Data 0.475 (0.505)	Loss 0.0190 (0.0193)
# Epoch: [15][50/134]	Time 0.532 (0.527)	Data 0.505 (0.500)	Loss 0.0253 (0.0218)
# Epoch: [15][75/134]	Time 0.506 (0.525)	Data 0.480 (0.498)	Loss 0.0393 (0.0245)
# Epoch: [15][100/134]	Time 0.502 (0.522)	Data 0.476 (0.495)	Loss 0.0259 (0.0258)
# Epoch: [15][125/134]	Time 0.494 (0.518)	Data 0.467 (0.491)	Loss 0.0180 (0.0272)
# Finished training epoch 15
# Validate: [0/34]	Time 0.515 (0.515)	Loss 0.0357 (0.0357)
# Validate: [25/34]	Time 0.491 (0.505)	Loss 0.0278 (0.0244)
# Finished validation.
# Starting training epoch 16
# Epoch: [16][0/134]	Time 0.511 (0.511)	Data 0.485 (0.485)	Loss 0.0145 (0.0145)
# Epoch: [16][25/134]	Time 0.500 (0.524)	Data 0.473 (0.497)	Loss 0.0190 (0.0195)
# Epoch: [16][50/134]	Time 0.529 (0.520)	Data 0.502 (0.494)	Loss 0.0250 (0.0219)
# Epoch: [16][75/134]	Time 0.496 (0.518)	Data 0.469 (0.491)	Loss 0.0306 (0.0243)
# Epoch: [16][100/134]	Time 0.507 (0.517)	Data 0.480 (0.490)	Loss 0.0225 (0.0255)
# Epoch: [16][125/134]	Time 0.503 (0.515)	Data 0.476 (0.488)	Loss 0.0180 (0.0269)
# Finished training epoch 16
# Validate: [0/34]	Time 0.516 (0.516)	Loss 0.0354 (0.0354)
# Validate: [25/34]	Time 0.504 (0.500)	Loss 0.0284 (0.0252)
# Finished validation.
# Starting training epoch 17
# Epoch: [17][0/134]	Time 0.519 (0.519)	Data 0.492 (0.492)	Loss 0.0138 (0.0138)
# Epoch: [17][25/134]	Time 0.499 (0.522)	Data 0.472 (0.495)	Loss 0.0193 (0.0196)
# Epoch: [17][50/134]	Time 0.532 (0.520)	Data 0.504 (0.493)	Loss 0.0242 (0.0220)
# Epoch: [17][75/134]	Time 0.494 (0.518)	Data 0.467 (0.491)	Loss 0.0396 (0.0246)
# Epoch: [17][100/134]	Time 0.507 (0.516)	Data 0.482 (0.489)	Loss 0.0256 (0.0259)
# Epoch: [17][125/134]	Time 0.508 (0.514)	Data 0.482 (0.488)	Loss 0.0181 (0.0273)
# Finished training epoch 17
# Validate: [0/34]	Time 0.513 (0.513)	Loss 0.0597 (0.0597)
# Validate: [25/34]	Time 0.492 (0.504)	Loss 0.0568 (0.0662)
# Finished validation.
# Starting training epoch 18
# Epoch: [18][0/134]	Time 0.526 (0.526)	Data 0.499 (0.499)	Loss 0.0390 (0.0390)
# Epoch: [18][25/134]	Time 0.507 (0.527)	Data 0.481 (0.500)	Loss 0.0183 (0.0214)
# Epoch: [18][50/134]	Time 0.517 (0.523)	Data 0.491 (0.496)	Loss 0.0251 (0.0231)
# Epoch: [18][75/134]	Time 0.496 (0.520)	Data 0.469 (0.493)	Loss 0.0404 (0.0255)
# Epoch: [18][100/134]	Time 0.507 (0.518)	Data 0.480 (0.491)	Loss 0.0249 (0.0266)
# Epoch: [18][125/134]	Time 0.499 (0.516)	Data 0.472 (0.489)	Loss 0.0175 (0.0278)
# Finished training epoch 18
# Validate: [0/34]	Time 0.509 (0.509)	Loss 0.0362 (0.0362)
# Validate: [25/34]	Time 0.498 (0.502)	Loss 0.0282 (0.0248)
# Finished validation.
# Starting training epoch 19
# Epoch: [19][0/134]	Time 0.511 (0.511)	Data 0.484 (0.484)	Loss 0.0135 (0.0135)
# Epoch: [19][25/134]	Time 0.502 (0.525)	Data 0.475 (0.499)	Loss 0.0188 (0.0193)
# Epoch: [19][50/134]	Time 0.524 (0.521)	Data 0.497 (0.494)	Loss 0.0246 (0.0219)
# Epoch: [19][75/134]	Time 0.491 (0.520)	Data 0.464 (0.493)	Loss 0.0402 (0.0246)
# Epoch: [19][100/134]	Time 0.499 (0.519)	Data 0.472 (0.492)	Loss 0.0247 (0.0259)
# Epoch: [19][125/134]	Time 0.505 (0.516)	Data 0.477 (0.489)	Loss 0.0182 (0.0288)
# Finished training epoch 19
# Validate: [0/34]	Time 0.509 (0.509)	Loss 0.0392 (0.0392)
# Validate: [25/34]	Time 0.501 (0.503)	Loss 0.0297 (0.0257)
# Finished validation.
# Starting training epoch 20
# Epoch: [20][0/134]	Time 0.516 (0.516)	Data 0.490 (0.490)	Loss 0.0142 (0.0142)
# Epoch: [20][25/134]	Time 0.499 (0.530)	Data 0.472 (0.503)	Loss 0.0193 (0.0191)
# Epoch: [20][50/134]	Time 0.522 (0.525)	Data 0.495 (0.498)	Loss 0.0253 (0.0219)
# Epoch: [20][75/134]	Time 0.494 (0.521)	Data 0.467 (0.494)	Loss 0.0414 (0.0247)
# Epoch: [20][100/134]	Time 0.507 (0.520)	Data 0.480 (0.493)	Loss 0.0250 (0.0262)
# Epoch: [20][125/134]	Time 0.503 (0.518)	Data 0.475 (0.491)	Loss 0.0179 (0.0276)
# Finished training epoch 20
# Validate: [0/34]	Time 0.524 (0.524)	Loss 0.0373 (0.0373)
# Validate: [25/34]	Time 0.500 (0.508)	Loss 0.0290 (0.0252)
# Finished validation.
# Starting training epoch 21
# Epoch: [21][0/134]	Time 0.504 (0.504)	Data 0.478 (0.478)	Loss 0.0140 (0.0140)
# Epoch: [21][25/134]	Time 0.495 (0.529)	Data 0.469 (0.502)	Loss 0.0192 (0.0193)
# Epoch: [21][50/134]	Time 0.526 (0.525)	Data 0.500 (0.498)	Loss 0.0250 (0.0218)
# Epoch: [21][75/134]	Time 0.496 (0.522)	Data 0.469 (0.495)	Loss 0.0404 (0.0246)
# Epoch: [21][100/134]	Time 0.504 (0.520)	Data 0.477 (0.493)	Loss 0.0254 (0.0260)
# Epoch: [21][125/134]	Time 0.507 (0.518)	Data 0.480 (0.491)	Loss 0.0178 (0.0273)
# Finished training epoch 21
# Validate: [0/34]	Time 0.516 (0.516)	Loss 0.0354 (0.0354)
# Validate: [25/34]	Time 0.500 (0.504)	Loss 0.0279 (0.0247)
# Finished validation.
# Starting training epoch 22
# Epoch: [22][0/134]	Time 0.533 (0.533)	Data 0.504 (0.504)	Loss 0.0135 (0.0135)
# Epoch: [22][25/134]	Time 0.494 (0.523)	Data 0.468 (0.496)	Loss 0.0189 (0.0195)
# Epoch: [22][50/134]	Time 0.523 (0.520)	Data 0.497 (0.493)	Loss 0.0249 (0.0219)
# Epoch: [22][75/134]	Time 0.488 (0.518)	Data 0.462 (0.491)	Loss 0.0398 (0.0246)
# Epoch: [22][100/134]	Time 0.503 (0.515)	Data 0.476 (0.489)	Loss 0.0260 (0.0259)
# Epoch: [22][125/134]	Time 0.497 (0.513)	Data 0.470 (0.486)	Loss 0.0179 (0.0273)
# Finished training epoch 22
# Validate: [0/34]	Time 0.509 (0.509)	Loss 0.0357 (0.0357)
# Validate: [25/34]	Time 0.497 (0.504)	Loss 0.0280 (0.0248)
# Finished validation.
# Starting training epoch 23
# Epoch: [23][0/134]	Time 0.510 (0.510)	Data 0.484 (0.484)	Loss 0.0136 (0.0136)
# Epoch: [23][25/134]	Time 0.508 (0.524)	Data 0.481 (0.497)	Loss 0.0190 (0.0195)
# Epoch: [23][50/134]	Time 0.532 (0.520)	Data 0.505 (0.494)	Loss 0.0242 (0.0220)
# Epoch: [23][75/134]	Time 0.497 (0.518)	Data 0.470 (0.491)	Loss 0.0406 (0.0247)
# Epoch: [23][100/134]	Time 0.504 (0.517)	Data 0.477 (0.491)	Loss 0.0249 (0.0262)
# Epoch: [23][125/134]	Time 0.498 (0.516)	Data 0.472 (0.489)	Loss 0.0179 (0.0276)
# Finished training epoch 23
# Validate: [0/34]	Time 0.511 (0.511)	Loss 0.0373 (0.0373)
# Validate: [25/34]	Time 0.495 (0.503)	Loss 0.0291 (0.0252)
# Finished validation.
# Starting training epoch 24
# Epoch: [24][0/134]	Time 0.511 (0.511)	Data 0.483 (0.483)	Loss 0.0141 (0.0141)
# Epoch: [24][25/134]	Time 0.495 (0.526)	Data 0.468 (0.499)	Loss 0.0192 (0.0193)
# Epoch: [24][50/134]	Time 0.525 (0.522)	Data 0.499 (0.495)	Loss 0.0252 (0.0219)
# Epoch: [24][75/134]	Time 0.495 (0.520)	Data 0.469 (0.493)	Loss 0.0413 (0.0248)
# Epoch: [24][100/134]	Time 0.514 (0.519)	Data 0.488 (0.493)	Loss 0.0250 (0.0263)
# Epoch: [24][125/134]	Time 0.505 (0.518)	Data 0.478 (0.491)	Loss 0.0179 (0.0276)
# Finished training epoch 24
# Validate: [0/34]	Time 0.511 (0.511)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.514 (0.506)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 25
# Epoch: [25][0/134]	Time 0.513 (0.513)	Data 0.486 (0.486)	Loss 0.0141 (0.0141)
# Epoch: [25][25/134]	Time 0.499 (0.528)	Data 0.473 (0.501)	Loss 0.0192 (0.0193)
# Epoch: [25][50/134]	Time 0.532 (0.525)	Data 0.505 (0.498)	Loss 0.0252 (0.0219)
# Epoch: [25][75/134]	Time 0.498 (0.522)	Data 0.472 (0.495)	Loss 0.0413 (0.0248)
# Epoch: [25][100/134]	Time 0.503 (0.520)	Data 0.476 (0.493)	Loss 0.0250 (0.0262)
# Epoch: [25][125/134]	Time 0.507 (0.518)	Data 0.480 (0.491)	Loss 0.0179 (0.0276)
# Finished training epoch 25
# Validate: [0/34]	Time 0.513 (0.513)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.497 (0.504)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 26
# Epoch: [26][0/134]	Time 0.517 (0.517)	Data 0.490 (0.490)	Loss 0.0141 (0.0141)
# Epoch: [26][25/134]	Time 0.506 (0.523)	Data 0.478 (0.497)	Loss 0.0192 (0.0193)
# Epoch: [26][50/134]	Time 0.528 (0.522)	Data 0.500 (0.495)	Loss 0.0252 (0.0219)
# Epoch: [26][75/134]	Time 0.493 (0.519)	Data 0.466 (0.493)	Loss 0.0413 (0.0247)
# Epoch: [26][100/134]	Time 0.510 (0.519)	Data 0.483 (0.492)	Loss 0.0250 (0.0262)
# Epoch: [26][125/134]	Time 0.506 (0.518)	Data 0.479 (0.491)	Loss 0.0179 (0.0276)
# Finished training epoch 26
# Validate: [0/34]	Time 0.507 (0.507)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.498 (0.505)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 27
# Epoch: [27][0/134]	Time 0.518 (0.518)	Data 0.492 (0.492)	Loss 0.0141 (0.0141)
# Epoch: [27][25/134]	Time 0.502 (0.530)	Data 0.476 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [27][50/134]	Time 0.536 (0.523)	Data 0.510 (0.497)	Loss 0.0252 (0.0219)
# Epoch: [27][75/134]	Time 0.499 (0.521)	Data 0.472 (0.494)	Loss 0.0413 (0.0247)
# Epoch: [27][100/134]	Time 0.524 (0.521)	Data 0.496 (0.494)	Loss 0.0250 (0.0262)
# Epoch: [27][125/134]	Time 0.505 (0.519)	Data 0.478 (0.492)	Loss 0.0179 (0.0276)
# Finished training epoch 27
# Validate: [0/34]	Time 0.520 (0.520)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.496 (0.507)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 28
# Epoch: [28][0/134]	Time 0.527 (0.527)	Data 0.501 (0.501)	Loss 0.0141 (0.0141)
# Epoch: [28][25/134]	Time 0.512 (0.531)	Data 0.484 (0.505)	Loss 0.0192 (0.0193)
# Epoch: [28][50/134]	Time 0.529 (0.526)	Data 0.502 (0.499)	Loss 0.0252 (0.0219)
# Epoch: [28][75/134]	Time 0.500 (0.522)	Data 0.473 (0.495)	Loss 0.0413 (0.0247)
# Epoch: [28][100/134]	Time 0.516 (0.522)	Data 0.488 (0.495)	Loss 0.0250 (0.0262)
# Epoch: [28][125/134]	Time 0.506 (0.519)	Data 0.477 (0.492)	Loss 0.0179 (0.0276)
# Finished training epoch 28
# Validate: [0/34]	Time 0.515 (0.515)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.507 (0.508)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 29
# Epoch: [29][0/134]	Time 0.507 (0.507)	Data 0.480 (0.480)	Loss 0.0141 (0.0141)
# Epoch: [29][25/134]	Time 0.506 (0.529)	Data 0.479 (0.502)	Loss 0.0192 (0.0193)
# Epoch: [29][50/134]	Time 0.535 (0.525)	Data 0.506 (0.498)	Loss 0.0252 (0.0219)
# Epoch: [29][75/134]	Time 0.494 (0.521)	Data 0.468 (0.494)	Loss 0.0413 (0.0247)
# Epoch: [29][100/134]	Time 0.510 (0.519)	Data 0.483 (0.492)	Loss 0.0250 (0.0262)
# Epoch: [29][125/134]	Time 0.502 (0.517)	Data 0.476 (0.490)	Loss 0.0179 (0.0276)
# Finished training epoch 29
# Validate: [0/34]	Time 0.515 (0.515)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.508 (0.508)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 30
# Epoch: [30][0/134]	Time 0.514 (0.514)	Data 0.487 (0.487)	Loss 0.0141 (0.0141)
# Epoch: [30][25/134]	Time 0.498 (0.528)	Data 0.472 (0.502)	Loss 0.0192 (0.0193)
# Epoch: [30][50/134]	Time 0.518 (0.523)	Data 0.491 (0.496)	Loss 0.0252 (0.0219)
# Epoch: [30][75/134]	Time 0.511 (0.520)	Data 0.484 (0.493)	Loss 0.0413 (0.0247)
# Epoch: [30][100/134]	Time 0.514 (0.519)	Data 0.486 (0.492)	Loss 0.0250 (0.0262)
# Epoch: [30][125/134]	Time 0.498 (0.517)	Data 0.471 (0.490)	Loss 0.0179 (0.0276)
# Finished training epoch 30
# Validate: [0/34]	Time 0.523 (0.523)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.510 (0.509)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 31
# Epoch: [31][0/134]	Time 0.525 (0.525)	Data 0.498 (0.498)	Loss 0.0141 (0.0141)
# Epoch: [31][25/134]	Time 0.497 (0.530)	Data 0.470 (0.504)	Loss 0.0192 (0.0193)
# Epoch: [31][50/134]	Time 0.536 (0.528)	Data 0.509 (0.501)	Loss 0.0252 (0.0219)
# Epoch: [31][75/134]	Time 0.502 (0.525)	Data 0.475 (0.498)	Loss 0.0413 (0.0247)
# Epoch: [31][100/134]	Time 0.536 (0.523)	Data 0.509 (0.496)	Loss 0.0250 (0.0262)
# Epoch: [31][125/134]	Time 0.500 (0.520)	Data 0.473 (0.494)	Loss 0.0179 (0.0276)
# Finished training epoch 31
# Validate: [0/34]	Time 0.518 (0.518)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.506 (0.507)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 32
# Epoch: [32][0/134]	Time 0.518 (0.518)	Data 0.492 (0.492)	Loss 0.0141 (0.0141)
# Epoch: [32][25/134]	Time 0.504 (0.529)	Data 0.478 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [32][50/134]	Time 0.555 (0.530)	Data 0.529 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [32][75/134]	Time 0.516 (0.531)	Data 0.489 (0.504)	Loss 0.0413 (0.0247)
# Epoch: [32][100/134]	Time 0.535 (0.531)	Data 0.508 (0.505)	Loss 0.0250 (0.0262)
# Epoch: [32][125/134]	Time 0.523 (0.530)	Data 0.496 (0.503)	Loss 0.0179 (0.0276)
# Finished training epoch 32
# Validate: [0/34]	Time 0.517 (0.517)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.504 (0.510)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 33
# Epoch: [33][0/134]	Time 0.523 (0.523)	Data 0.496 (0.496)	Loss 0.0141 (0.0141)
# Epoch: [33][25/134]	Time 0.502 (0.537)	Data 0.475 (0.511)	Loss 0.0192 (0.0193)
# Epoch: [33][50/134]	Time 0.528 (0.530)	Data 0.500 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [33][75/134]	Time 0.496 (0.527)	Data 0.470 (0.500)	Loss 0.0413 (0.0247)
# Epoch: [33][100/134]	Time 0.513 (0.526)	Data 0.487 (0.499)	Loss 0.0250 (0.0262)
# Epoch: [33][125/134]	Time 0.514 (0.524)	Data 0.487 (0.497)	Loss 0.0179 (0.0276)
# Finished training epoch 33
# Validate: [0/34]	Time 0.519 (0.519)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.519 (0.514)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 34
# Epoch: [34][0/134]	Time 0.528 (0.528)	Data 0.502 (0.502)	Loss 0.0141 (0.0141)
# Epoch: [34][25/134]	Time 0.511 (0.536)	Data 0.484 (0.509)	Loss 0.0192 (0.0193)
# Epoch: [34][50/134]	Time 0.536 (0.532)	Data 0.509 (0.505)	Loss 0.0252 (0.0219)
# Epoch: [34][75/134]	Time 0.509 (0.529)	Data 0.478 (0.502)	Loss 0.0413 (0.0247)
# Epoch: [34][100/134]	Time 0.514 (0.527)	Data 0.488 (0.501)	Loss 0.0250 (0.0262)
# Epoch: [34][125/134]	Time 0.522 (0.526)	Data 0.496 (0.499)	Loss 0.0179 (0.0276)
# Finished training epoch 34
# Validate: [0/34]	Time 0.520 (0.520)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.514 (0.512)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 35
# Epoch: [35][0/134]	Time 0.525 (0.525)	Data 0.498 (0.498)	Loss 0.0141 (0.0141)
# Epoch: [35][25/134]	Time 0.512 (0.536)	Data 0.480 (0.509)	Loss 0.0192 (0.0193)
# Epoch: [35][50/134]	Time 0.537 (0.530)	Data 0.509 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [35][75/134]	Time 0.499 (0.528)	Data 0.473 (0.501)	Loss 0.0413 (0.0247)
# Epoch: [35][100/134]	Time 0.521 (0.526)	Data 0.493 (0.500)	Loss 0.0250 (0.0262)
# Epoch: [35][125/134]	Time 0.506 (0.525)	Data 0.479 (0.498)	Loss 0.0179 (0.0276)
# Finished training epoch 35
# Validate: [0/34]	Time 0.519 (0.519)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.517 (0.510)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 36
# Epoch: [36][0/134]	Time 0.516 (0.516)	Data 0.487 (0.487)	Loss 0.0141 (0.0141)
# Epoch: [36][25/134]	Time 0.491 (0.529)	Data 0.465 (0.502)	Loss 0.0192 (0.0193)
# Epoch: [36][50/134]	Time 0.538 (0.526)	Data 0.511 (0.499)	Loss 0.0252 (0.0219)
# Epoch: [36][75/134]	Time 0.507 (0.525)	Data 0.480 (0.498)	Loss 0.0413 (0.0247)
# Epoch: [36][100/134]	Time 0.509 (0.523)	Data 0.482 (0.496)	Loss 0.0250 (0.0262)
# Epoch: [36][125/134]	Time 0.502 (0.521)	Data 0.475 (0.494)	Loss 0.0179 (0.0276)
# Finished training epoch 36
# Validate: [0/34]	Time 0.513 (0.513)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.506 (0.508)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 37
# Epoch: [37][0/134]	Time 0.529 (0.529)	Data 0.503 (0.503)	Loss 0.0141 (0.0141)
# Epoch: [37][25/134]	Time 0.502 (0.530)	Data 0.475 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [37][50/134]	Time 0.529 (0.525)	Data 0.502 (0.498)	Loss 0.0252 (0.0219)
# Epoch: [37][75/134]	Time 0.503 (0.521)	Data 0.477 (0.494)	Loss 0.0413 (0.0247)
# Epoch: [37][100/134]	Time 0.510 (0.520)	Data 0.483 (0.493)	Loss 0.0250 (0.0262)
# Epoch: [37][125/134]	Time 0.506 (0.518)	Data 0.480 (0.491)	Loss 0.0179 (0.0276)
# Finished training epoch 37
# Validate: [0/34]	Time 0.518 (0.518)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.509 (0.512)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 38
# Epoch: [38][0/134]	Time 0.521 (0.521)	Data 0.494 (0.494)	Loss 0.0141 (0.0141)
# Epoch: [38][25/134]	Time 0.508 (0.538)	Data 0.482 (0.511)	Loss 0.0192 (0.0193)
# Epoch: [38][50/134]	Time 0.533 (0.531)	Data 0.506 (0.504)	Loss 0.0252 (0.0219)
# Epoch: [38][75/134]	Time 0.511 (0.528)	Data 0.484 (0.501)	Loss 0.0413 (0.0247)
# Epoch: [38][100/134]	Time 0.509 (0.526)	Data 0.483 (0.499)	Loss 0.0250 (0.0262)
# Epoch: [38][125/134]	Time 0.518 (0.524)	Data 0.491 (0.497)	Loss 0.0179 (0.0276)
# Finished training epoch 38
# Validate: [0/34]	Time 0.520 (0.520)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.504 (0.510)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 39
# Epoch: [39][0/134]	Time 0.515 (0.515)	Data 0.488 (0.488)	Loss 0.0141 (0.0141)
# Epoch: [39][25/134]	Time 0.504 (0.533)	Data 0.477 (0.507)	Loss 0.0192 (0.0193)
# Epoch: [39][50/134]	Time 0.542 (0.530)	Data 0.515 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [39][75/134]	Time 0.510 (0.527)	Data 0.483 (0.501)	Loss 0.0413 (0.0247)
# Epoch: [39][100/134]	Time 0.516 (0.528)	Data 0.490 (0.501)	Loss 0.0250 (0.0262)
# Epoch: [39][125/134]	Time 0.522 (0.525)	Data 0.495 (0.498)	Loss 0.0179 (0.0276)
# Finished training epoch 39
# Validate: [0/34]	Time 0.523 (0.523)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.518 (0.513)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 40
# Epoch: [40][0/134]	Time 0.524 (0.524)	Data 0.497 (0.497)	Loss 0.0141 (0.0141)
# Epoch: [40][25/134]	Time 0.497 (0.529)	Data 0.471 (0.502)	Loss 0.0192 (0.0193)
# Epoch: [40][50/134]	Time 0.531 (0.524)	Data 0.505 (0.498)	Loss 0.0252 (0.0219)
# Epoch: [40][75/134]	Time 0.494 (0.522)	Data 0.467 (0.495)	Loss 0.0413 (0.0247)
# Epoch: [40][100/134]	Time 0.499 (0.521)	Data 0.473 (0.494)	Loss 0.0250 (0.0262)
# Epoch: [40][125/134]	Time 0.496 (0.519)	Data 0.469 (0.492)	Loss 0.0179 (0.0276)
# Finished training epoch 40
# Validate: [0/34]	Time 0.505 (0.505)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.515 (0.506)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 41
# Epoch: [41][0/134]	Time 0.511 (0.511)	Data 0.484 (0.484)	Loss 0.0141 (0.0141)
# Epoch: [41][25/134]	Time 0.498 (0.530)	Data 0.471 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [41][50/134]	Time 0.533 (0.526)	Data 0.506 (0.499)	Loss 0.0252 (0.0219)
# Epoch: [41][75/134]	Time 0.518 (0.524)	Data 0.491 (0.497)	Loss 0.0413 (0.0247)
# Epoch: [41][100/134]	Time 0.519 (0.524)	Data 0.493 (0.497)	Loss 0.0250 (0.0262)
# Epoch: [41][125/134]	Time 0.510 (0.522)	Data 0.484 (0.495)	Loss 0.0179 (0.0276)
# Finished training epoch 41
# Validate: [0/34]	Time 0.516 (0.516)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.504 (0.514)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 42
# Epoch: [42][0/134]	Time 0.521 (0.521)	Data 0.494 (0.494)	Loss 0.0141 (0.0141)
# Epoch: [42][25/134]	Time 0.512 (0.533)	Data 0.485 (0.507)	Loss 0.0192 (0.0193)
# Epoch: [42][50/134]	Time 0.539 (0.531)	Data 0.512 (0.504)	Loss 0.0252 (0.0219)
# Epoch: [42][75/134]	Time 0.501 (0.528)	Data 0.473 (0.501)	Loss 0.0413 (0.0247)
# Epoch: [42][100/134]	Time 0.514 (0.526)	Data 0.487 (0.499)	Loss 0.0250 (0.0262)
# Epoch: [42][125/134]	Time 0.513 (0.524)	Data 0.486 (0.497)	Loss 0.0179 (0.0276)
# Finished training epoch 42
# Validate: [0/34]	Time 0.521 (0.521)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.511 (0.514)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 43
# Epoch: [43][0/134]	Time 0.523 (0.523)	Data 0.496 (0.496)	Loss 0.0141 (0.0141)
# Epoch: [43][25/134]	Time 0.503 (0.533)	Data 0.476 (0.506)	Loss 0.0192 (0.0193)
# Epoch: [43][50/134]	Time 0.537 (0.529)	Data 0.510 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [43][75/134]	Time 0.504 (0.527)	Data 0.478 (0.500)	Loss 0.0413 (0.0247)
# Epoch: [43][100/134]	Time 0.515 (0.525)	Data 0.488 (0.498)	Loss 0.0250 (0.0262)
# Epoch: [43][125/134]	Time 0.521 (0.523)	Data 0.494 (0.496)	Loss 0.0179 (0.0276)
# Finished training epoch 43
# Validate: [0/34]	Time 0.516 (0.516)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.503 (0.512)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 44
# Epoch: [44][0/134]	Time 0.511 (0.511)	Data 0.484 (0.484)	Loss 0.0141 (0.0141)
# Epoch: [44][25/134]	Time 0.507 (0.533)	Data 0.480 (0.506)	Loss 0.0192 (0.0193)
# Epoch: [44][50/134]	Time 0.535 (0.530)	Data 0.508 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [44][75/134]	Time 0.499 (0.527)	Data 0.472 (0.500)	Loss 0.0413 (0.0247)
# Epoch: [44][100/134]	Time 0.523 (0.526)	Data 0.497 (0.499)	Loss 0.0250 (0.0262)
# Epoch: [44][125/134]	Time 0.516 (0.524)	Data 0.489 (0.497)	Loss 0.0179 (0.0276)
# Finished training epoch 44
# Validate: [0/34]	Time 0.507 (0.507)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.518 (0.512)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 45
# Epoch: [45][0/134]	Time 0.540 (0.540)	Data 0.512 (0.512)	Loss 0.0141 (0.0141)
# Epoch: [45][25/134]	Time 0.511 (0.545)	Data 0.485 (0.518)	Loss 0.0192 (0.0193)
# Epoch: [45][50/134]	Time 0.541 (0.539)	Data 0.514 (0.512)	Loss 0.0252 (0.0219)
# Epoch: [45][75/134]	Time 0.517 (0.533)	Data 0.490 (0.506)	Loss 0.0413 (0.0247)
# Epoch: [45][100/134]	Time 0.526 (0.533)	Data 0.499 (0.506)	Loss 0.0250 (0.0262)
# Epoch: [45][125/134]	Time 0.517 (0.532)	Data 0.491 (0.505)	Loss 0.0179 (0.0276)
# Finished training epoch 45
# Validate: [0/34]	Time 0.538 (0.538)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.529 (0.526)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 46
# Epoch: [46][0/134]	Time 0.535 (0.535)	Data 0.507 (0.507)	Loss 0.0141 (0.0141)
# Epoch: [46][25/134]	Time 0.512 (0.542)	Data 0.484 (0.515)	Loss 0.0192 (0.0193)
# Epoch: [46][50/134]	Time 0.544 (0.536)	Data 0.517 (0.509)	Loss 0.0252 (0.0219)
# Epoch: [46][75/134]	Time 0.509 (0.533)	Data 0.479 (0.506)	Loss 0.0413 (0.0247)
# Epoch: [46][100/134]	Time 0.530 (0.531)	Data 0.504 (0.504)	Loss 0.0250 (0.0262)
# Epoch: [46][125/134]	Time 0.506 (0.528)	Data 0.480 (0.501)	Loss 0.0179 (0.0276)
# Finished training epoch 46
# Validate: [0/34]	Time 0.526 (0.526)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.523 (0.522)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 47
# Epoch: [47][0/134]	Time 0.530 (0.530)	Data 0.503 (0.503)	Loss 0.0141 (0.0141)
# Epoch: [47][25/134]	Time 0.519 (0.551)	Data 0.491 (0.524)	Loss 0.0192 (0.0193)
# Epoch: [47][50/134]	Time 0.539 (0.544)	Data 0.512 (0.517)	Loss 0.0252 (0.0219)
# Epoch: [47][75/134]	Time 0.504 (0.536)	Data 0.477 (0.509)	Loss 0.0413 (0.0247)
# Epoch: [47][100/134]	Time 0.511 (0.533)	Data 0.485 (0.506)	Loss 0.0250 (0.0262)
# Epoch: [47][125/134]	Time 0.520 (0.530)	Data 0.493 (0.503)	Loss 0.0179 (0.0276)
# Finished training epoch 47
# Validate: [0/34]	Time 0.529 (0.529)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.509 (0.515)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 48
# Epoch: [48][0/134]	Time 0.519 (0.519)	Data 0.492 (0.492)	Loss 0.0141 (0.0141)
# Epoch: [48][25/134]	Time 0.512 (0.536)	Data 0.485 (0.509)	Loss 0.0192 (0.0193)
# Epoch: [48][50/134]	Time 0.545 (0.533)	Data 0.518 (0.506)	Loss 0.0252 (0.0219)
# Epoch: [48][75/134]	Time 0.503 (0.531)	Data 0.476 (0.504)	Loss 0.0413 (0.0247)
# Epoch: [48][100/134]	Time 0.526 (0.530)	Data 0.500 (0.503)	Loss 0.0250 (0.0262)
# Epoch: [48][125/134]	Time 0.530 (0.528)	Data 0.502 (0.501)	Loss 0.0179 (0.0276)
# Finished training epoch 48
# Validate: [0/34]	Time 0.518 (0.518)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.513 (0.515)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 49
# Epoch: [49][0/134]	Time 0.522 (0.522)	Data 0.494 (0.494)	Loss 0.0141 (0.0141)
# Epoch: [49][25/134]	Time 0.505 (0.538)	Data 0.478 (0.511)	Loss 0.0192 (0.0193)
# Epoch: [49][50/134]	Time 0.544 (0.534)	Data 0.517 (0.507)	Loss 0.0252 (0.0219)
# Epoch: [49][75/134]	Time 0.509 (0.531)	Data 0.483 (0.504)	Loss 0.0413 (0.0247)
# Epoch: [49][100/134]	Time 0.519 (0.530)	Data 0.493 (0.503)	Loss 0.0250 (0.0262)
# Epoch: [49][125/134]	Time 0.511 (0.527)	Data 0.484 (0.500)	Loss 0.0179 (0.0276)
# Finished training epoch 49
# Validate: [0/34]	Time 0.521 (0.521)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.511 (0.515)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 50
# Epoch: [50][0/134]	Time 0.525 (0.525)	Data 0.499 (0.499)	Loss 0.0141 (0.0141)
# Epoch: [50][25/134]	Time 0.510 (0.536)	Data 0.484 (0.509)	Loss 0.0192 (0.0193)
# Epoch: [50][50/134]	Time 0.539 (0.532)	Data 0.512 (0.505)	Loss 0.0252 (0.0219)
# Epoch: [50][75/134]	Time 0.500 (0.529)	Data 0.473 (0.502)	Loss 0.0413 (0.0247)
# Epoch: [50][100/134]	Time 0.517 (0.528)	Data 0.489 (0.501)	Loss 0.0250 (0.0262)
# Epoch: [50][125/134]	Time 0.511 (0.525)	Data 0.484 (0.499)	Loss 0.0179 (0.0276)
# Finished training epoch 50
# Validate: [0/34]	Time 0.517 (0.517)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.514 (0.514)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 51
# Epoch: [51][0/134]	Time 0.521 (0.521)	Data 0.493 (0.493)	Loss 0.0141 (0.0141)
# Epoch: [51][25/134]	Time 0.499 (0.532)	Data 0.473 (0.505)	Loss 0.0192 (0.0193)
# Epoch: [51][50/134]	Time 0.532 (0.530)	Data 0.505 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [51][75/134]	Time 0.500 (0.526)	Data 0.473 (0.499)	Loss 0.0413 (0.0247)
# Epoch: [51][100/134]	Time 0.513 (0.525)	Data 0.486 (0.498)	Loss 0.0250 (0.0262)
# Epoch: [51][125/134]	Time 0.501 (0.522)	Data 0.474 (0.496)	Loss 0.0179 (0.0276)
# Finished training epoch 51
# Validate: [0/34]	Time 0.511 (0.511)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.508 (0.508)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 52
# Epoch: [52][0/134]	Time 0.519 (0.519)	Data 0.493 (0.493)	Loss 0.0141 (0.0141)
# Epoch: [52][25/134]	Time 0.492 (0.530)	Data 0.464 (0.504)	Loss 0.0192 (0.0193)
# Epoch: [52][50/134]	Time 0.521 (0.528)	Data 0.495 (0.501)	Loss 0.0252 (0.0219)
# Epoch: [52][75/134]	Time 0.498 (0.524)	Data 0.472 (0.497)	Loss 0.0413 (0.0247)
# Epoch: [52][100/134]	Time 0.505 (0.523)	Data 0.479 (0.496)	Loss 0.0250 (0.0262)
# Epoch: [52][125/134]	Time 0.503 (0.520)	Data 0.477 (0.493)	Loss 0.0179 (0.0276)
# Finished training epoch 52
# Validate: [0/34]	Time 0.523 (0.523)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.502 (0.506)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 53
# Epoch: [53][0/134]	Time 0.513 (0.513)	Data 0.486 (0.486)	Loss 0.0141 (0.0141)
# Epoch: [53][25/134]	Time 0.511 (0.531)	Data 0.484 (0.504)	Loss 0.0192 (0.0193)
# Epoch: [53][50/134]	Time 0.535 (0.528)	Data 0.507 (0.502)	Loss 0.0252 (0.0219)
# Epoch: [53][75/134]	Time 0.502 (0.525)	Data 0.475 (0.498)	Loss 0.0413 (0.0247)
# Epoch: [53][100/134]	Time 0.513 (0.523)	Data 0.486 (0.496)	Loss 0.0250 (0.0262)
# Epoch: [53][125/134]	Time 0.501 (0.519)	Data 0.475 (0.493)	Loss 0.0179 (0.0276)
# Finished training epoch 53
# Validate: [0/34]	Time 0.514 (0.514)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.514 (0.504)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 54
# Epoch: [54][0/134]	Time 0.525 (0.525)	Data 0.498 (0.498)	Loss 0.0141 (0.0141)
# Epoch: [54][25/134]	Time 0.509 (0.528)	Data 0.482 (0.501)	Loss 0.0192 (0.0193)
# Epoch: [54][50/134]	Time 0.523 (0.523)	Data 0.496 (0.496)	Loss 0.0252 (0.0219)
# Epoch: [54][75/134]	Time 0.488 (0.521)	Data 0.462 (0.494)	Loss 0.0413 (0.0247)
# Epoch: [54][100/134]	Time 0.507 (0.520)	Data 0.481 (0.493)	Loss 0.0250 (0.0262)
# Epoch: [54][125/134]	Time 0.514 (0.518)	Data 0.488 (0.491)	Loss 0.0179 (0.0276)
# Finished training epoch 54
# Validate: [0/34]	Time 0.523 (0.523)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.510 (0.504)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 55
# Epoch: [55][0/134]	Time 0.513 (0.513)	Data 0.486 (0.486)	Loss 0.0141 (0.0141)
# Epoch: [55][25/134]	Time 0.498 (0.528)	Data 0.471 (0.501)	Loss 0.0192 (0.0193)
# Epoch: [55][50/134]	Time 0.518 (0.522)	Data 0.492 (0.495)	Loss 0.0252 (0.0219)
# Epoch: [55][75/134]	Time 0.490 (0.519)	Data 0.464 (0.492)	Loss 0.0413 (0.0247)
# Epoch: [55][100/134]	Time 0.498 (0.518)	Data 0.471 (0.491)	Loss 0.0250 (0.0262)
# Epoch: [55][125/134]	Time 0.503 (0.516)	Data 0.477 (0.489)	Loss 0.0179 (0.0276)
# Finished training epoch 55
# Validate: [0/34]	Time 0.516 (0.516)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.500 (0.505)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 56
# Epoch: [56][0/134]	Time 0.505 (0.505)	Data 0.479 (0.479)	Loss 0.0141 (0.0141)
# Epoch: [56][25/134]	Time 0.490 (0.525)	Data 0.463 (0.498)	Loss 0.0192 (0.0193)
# Epoch: [56][50/134]	Time 0.530 (0.521)	Data 0.504 (0.495)	Loss 0.0252 (0.0219)
# Epoch: [56][75/134]	Time 0.497 (0.519)	Data 0.470 (0.492)	Loss 0.0413 (0.0247)
# Epoch: [56][100/134]	Time 0.502 (0.518)	Data 0.475 (0.491)	Loss 0.0250 (0.0262)
# Epoch: [56][125/134]	Time 0.500 (0.516)	Data 0.474 (0.490)	Loss 0.0179 (0.0276)
# Finished training epoch 56
# Validate: [0/34]	Time 0.516 (0.516)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.498 (0.505)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 57
# Epoch: [57][0/134]	Time 0.504 (0.504)	Data 0.478 (0.478)	Loss 0.0141 (0.0141)
# Epoch: [57][25/134]	Time 0.503 (0.528)	Data 0.476 (0.502)	Loss 0.0192 (0.0193)
# Epoch: [57][50/134]	Time 0.533 (0.526)	Data 0.506 (0.499)	Loss 0.0252 (0.0219)
# Epoch: [57][75/134]	Time 0.497 (0.523)	Data 0.471 (0.496)	Loss 0.0413 (0.0247)
# Epoch: [57][100/134]	Time 0.515 (0.522)	Data 0.488 (0.495)	Loss 0.0250 (0.0262)
# Epoch: [57][125/134]	Time 0.497 (0.518)	Data 0.470 (0.492)	Loss 0.0179 (0.0276)
# Finished training epoch 57
# Validate: [0/34]	Time 0.514 (0.514)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.500 (0.502)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 58
# Epoch: [58][0/134]	Time 0.517 (0.517)	Data 0.488 (0.488)	Loss 0.0141 (0.0141)
# Epoch: [58][25/134]	Time 0.497 (0.527)	Data 0.470 (0.500)	Loss 0.0192 (0.0193)
# Epoch: [58][50/134]	Time 0.526 (0.523)	Data 0.499 (0.496)	Loss 0.0252 (0.0219)
# Epoch: [58][75/134]	Time 0.491 (0.521)	Data 0.465 (0.494)	Loss 0.0413 (0.0247)
# Epoch: [58][100/134]	Time 0.508 (0.519)	Data 0.482 (0.493)	Loss 0.0250 (0.0262)
# Epoch: [58][125/134]	Time 0.500 (0.517)	Data 0.473 (0.490)	Loss 0.0179 (0.0276)
# Finished training epoch 58
# Validate: [0/34]	Time 0.510 (0.510)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.517 (0.508)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 59
# Epoch: [59][0/134]	Time 0.524 (0.524)	Data 0.497 (0.497)	Loss 0.0141 (0.0141)
# Epoch: [59][25/134]	Time 0.501 (0.530)	Data 0.474 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [59][50/134]	Time 0.532 (0.526)	Data 0.506 (0.500)	Loss 0.0252 (0.0219)
# Epoch: [59][75/134]	Time 0.506 (0.525)	Data 0.480 (0.498)	Loss 0.0413 (0.0247)
# Epoch: [59][100/134]	Time 0.519 (0.524)	Data 0.491 (0.497)	Loss 0.0250 (0.0262)
# Epoch: [59][125/134]	Time 0.509 (0.521)	Data 0.483 (0.495)	Loss 0.0179 (0.0276)
# Finished training epoch 59
# Validate: [0/34]	Time 0.510 (0.510)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.507 (0.505)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 60
# Epoch: [60][0/134]	Time 0.510 (0.510)	Data 0.483 (0.483)	Loss 0.0141 (0.0141)
# Epoch: [60][25/134]	Time 0.500 (0.529)	Data 0.473 (0.502)	Loss 0.0192 (0.0193)
# Epoch: [60][50/134]	Time 0.530 (0.525)	Data 0.503 (0.499)	Loss 0.0252 (0.0219)
# Epoch: [60][75/134]	Time 0.495 (0.521)	Data 0.469 (0.495)	Loss 0.0413 (0.0247)
# Epoch: [60][100/134]	Time 0.514 (0.520)	Data 0.487 (0.494)	Loss 0.0250 (0.0262)
# Epoch: [60][125/134]	Time 0.500 (0.518)	Data 0.473 (0.491)	Loss 0.0179 (0.0276)
# Finished training epoch 60
# Validate: [0/34]	Time 0.508 (0.508)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.502 (0.504)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 61
# Epoch: [61][0/134]	Time 0.511 (0.511)	Data 0.483 (0.483)	Loss 0.0141 (0.0141)
# Epoch: [61][25/134]	Time 0.499 (0.523)	Data 0.472 (0.497)	Loss 0.0192 (0.0193)
# Epoch: [61][50/134]	Time 0.524 (0.520)	Data 0.498 (0.493)	Loss 0.0252 (0.0219)
# Epoch: [61][75/134]	Time 0.501 (0.518)	Data 0.473 (0.491)	Loss 0.0413 (0.0247)
# Epoch: [61][100/134]	Time 0.512 (0.517)	Data 0.485 (0.490)	Loss 0.0250 (0.0262)
# Epoch: [61][125/134]	Time 0.501 (0.515)	Data 0.475 (0.489)	Loss 0.0179 (0.0276)
# Finished training epoch 61
# Validate: [0/34]	Time 0.512 (0.512)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.501 (0.503)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 62
# Epoch: [62][0/134]	Time 0.512 (0.512)	Data 0.485 (0.485)	Loss 0.0141 (0.0141)
# Epoch: [62][25/134]	Time 0.494 (0.530)	Data 0.467 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [62][50/134]	Time 0.536 (0.525)	Data 0.510 (0.498)	Loss 0.0252 (0.0219)
# Epoch: [62][75/134]	Time 0.495 (0.522)	Data 0.468 (0.495)	Loss 0.0413 (0.0247)
# Epoch: [62][100/134]	Time 0.505 (0.520)	Data 0.478 (0.493)	Loss 0.0250 (0.0262)
# Epoch: [62][125/134]	Time 0.505 (0.517)	Data 0.478 (0.490)	Loss 0.0179 (0.0276)
# Finished training epoch 62
# Validate: [0/34]	Time 0.515 (0.515)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.504 (0.508)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 63
# Epoch: [63][0/134]	Time 0.534 (0.534)	Data 0.507 (0.507)	Loss 0.0141 (0.0141)
# Epoch: [63][25/134]	Time 0.502 (0.530)	Data 0.475 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [63][50/134]	Time 0.525 (0.525)	Data 0.497 (0.498)	Loss 0.0252 (0.0219)
# Epoch: [63][75/134]	Time 0.497 (0.522)	Data 0.469 (0.495)	Loss 0.0413 (0.0247)
# Epoch: [63][100/134]	Time 0.508 (0.520)	Data 0.481 (0.494)	Loss 0.0250 (0.0262)
# Epoch: [63][125/134]	Time 0.497 (0.518)	Data 0.470 (0.491)	Loss 0.0179 (0.0276)
# Finished training epoch 63
# Validate: [0/34]	Time 0.510 (0.510)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.525 (0.505)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 64
# Epoch: [64][0/134]	Time 0.507 (0.507)	Data 0.480 (0.480)	Loss 0.0141 (0.0141)
# Epoch: [64][25/134]	Time 0.498 (0.523)	Data 0.472 (0.496)	Loss 0.0192 (0.0193)
# Epoch: [64][50/134]	Time 0.520 (0.520)	Data 0.493 (0.493)	Loss 0.0252 (0.0219)
# Epoch: [64][75/134]	Time 0.491 (0.517)	Data 0.465 (0.491)	Loss 0.0413 (0.0247)
# Epoch: [64][100/134]	Time 0.508 (0.516)	Data 0.482 (0.489)	Loss 0.0250 (0.0262)
# Epoch: [64][125/134]	Time 0.508 (0.514)	Data 0.481 (0.487)	Loss 0.0179 (0.0276)
# Finished training epoch 64
# Validate: [0/34]	Time 0.514 (0.514)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.499 (0.506)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 65
# Epoch: [65][0/134]	Time 0.514 (0.514)	Data 0.487 (0.487)	Loss 0.0141 (0.0141)
# Epoch: [65][25/134]	Time 0.491 (0.530)	Data 0.465 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [65][50/134]	Time 0.529 (0.526)	Data 0.503 (0.499)	Loss 0.0252 (0.0219)
# Epoch: [65][75/134]	Time 0.497 (0.522)	Data 0.471 (0.495)	Loss 0.0413 (0.0247)
# Epoch: [65][100/134]	Time 0.520 (0.521)	Data 0.492 (0.494)	Loss 0.0250 (0.0262)
# Epoch: [65][125/134]	Time 0.503 (0.519)	Data 0.476 (0.492)	Loss 0.0179 (0.0276)
# Finished training epoch 65
# Validate: [0/34]	Time 0.521 (0.521)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.511 (0.513)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 66
# Epoch: [66][0/134]	Time 0.520 (0.520)	Data 0.493 (0.493)	Loss 0.0141 (0.0141)
# Epoch: [66][25/134]	Time 0.494 (0.528)	Data 0.468 (0.501)	Loss 0.0192 (0.0193)
# Epoch: [66][50/134]	Time 0.526 (0.526)	Data 0.499 (0.499)	Loss 0.0252 (0.0219)
# Epoch: [66][75/134]	Time 0.499 (0.523)	Data 0.473 (0.497)	Loss 0.0413 (0.0247)
# Epoch: [66][100/134]	Time 0.526 (0.524)	Data 0.499 (0.497)	Loss 0.0250 (0.0262)
# Epoch: [66][125/134]	Time 0.509 (0.522)	Data 0.482 (0.495)	Loss 0.0179 (0.0276)
# Finished training epoch 66
# Validate: [0/34]	Time 0.516 (0.516)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.509 (0.507)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 67
# Epoch: [67][0/134]	Time 0.533 (0.533)	Data 0.506 (0.506)	Loss 0.0141 (0.0141)
# Epoch: [67][25/134]	Time 0.498 (0.531)	Data 0.472 (0.504)	Loss 0.0192 (0.0193)
# Epoch: [67][50/134]	Time 0.537 (0.528)	Data 0.510 (0.501)	Loss 0.0252 (0.0219)
# Epoch: [67][75/134]	Time 0.496 (0.525)	Data 0.469 (0.498)	Loss 0.0413 (0.0247)
# Epoch: [67][100/134]	Time 0.507 (0.523)	Data 0.480 (0.496)	Loss 0.0250 (0.0262)
# Epoch: [67][125/134]	Time 0.503 (0.520)	Data 0.476 (0.493)	Loss 0.0179 (0.0276)
# Finished training epoch 67
# Validate: [0/34]	Time 0.516 (0.516)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.498 (0.505)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 68
# Epoch: [68][0/134]	Time 0.520 (0.520)	Data 0.493 (0.493)	Loss 0.0141 (0.0141)
# Epoch: [68][25/134]	Time 0.512 (0.529)	Data 0.485 (0.502)	Loss 0.0192 (0.0193)
# Epoch: [68][50/134]	Time 0.530 (0.525)	Data 0.503 (0.499)	Loss 0.0252 (0.0219)
# Epoch: [68][75/134]	Time 0.502 (0.523)	Data 0.475 (0.496)	Loss 0.0413 (0.0247)
# Epoch: [68][100/134]	Time 0.522 (0.523)	Data 0.496 (0.496)	Loss 0.0250 (0.0262)
# Epoch: [68][125/134]	Time 0.509 (0.521)	Data 0.482 (0.494)	Loss 0.0179 (0.0276)
# Finished training epoch 68
# Validate: [0/34]	Time 0.513 (0.513)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.511 (0.512)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 69
# Epoch: [69][0/134]	Time 0.516 (0.516)	Data 0.490 (0.490)	Loss 0.0141 (0.0141)
# Epoch: [69][25/134]	Time 0.508 (0.530)	Data 0.481 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [69][50/134]	Time 0.546 (0.526)	Data 0.519 (0.500)	Loss 0.0252 (0.0219)
# Epoch: [69][75/134]	Time 0.498 (0.524)	Data 0.472 (0.497)	Loss 0.0413 (0.0247)
# Epoch: [69][100/134]	Time 0.506 (0.522)	Data 0.481 (0.496)	Loss 0.0250 (0.0262)
# Epoch: [69][125/134]	Time 0.503 (0.521)	Data 0.477 (0.494)	Loss 0.0179 (0.0276)
# Finished training epoch 69
# Validate: [0/34]	Time 0.528 (0.528)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.514 (0.512)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 70
# Epoch: [70][0/134]	Time 0.528 (0.528)	Data 0.500 (0.500)	Loss 0.0141 (0.0141)
# Epoch: [70][25/134]	Time 0.513 (0.538)	Data 0.486 (0.512)	Loss 0.0192 (0.0193)
# Epoch: [70][50/134]	Time 0.538 (0.532)	Data 0.512 (0.506)	Loss 0.0252 (0.0219)
# Epoch: [70][75/134]	Time 0.510 (0.528)	Data 0.483 (0.501)	Loss 0.0413 (0.0247)
# Epoch: [70][100/134]	Time 0.509 (0.525)	Data 0.482 (0.498)	Loss 0.0250 (0.0262)
# Epoch: [70][125/134]	Time 0.504 (0.522)	Data 0.477 (0.495)	Loss 0.0179 (0.0276)
# Finished training epoch 70
# Validate: [0/34]	Time 0.516 (0.516)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.516 (0.514)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 71
# Epoch: [71][0/134]	Time 0.514 (0.514)	Data 0.487 (0.487)	Loss 0.0141 (0.0141)
# Epoch: [71][25/134]	Time 0.508 (0.549)	Data 0.482 (0.521)	Loss 0.0192 (0.0193)
# Epoch: [71][50/134]	Time 0.544 (0.542)	Data 0.517 (0.515)	Loss 0.0252 (0.0219)
# ...
# Epoch: [76][50/134]	Time 0.516 (0.523)	Data 0.489 (0.496)	Loss 0.0252 (0.0219)
# Epoch: [76][75/134]	Time 0.502 (0.520)	Data 0.475 (0.494)	Loss 0.0413 (0.0247)
# Epoch: [76][100/134]	Time 0.507 (0.518)	Data 0.481 (0.492)	Loss 0.0250 (0.0262)
# Epoch: [76][125/134]	Time 0.497 (0.517)	Data 0.470 (0.490)	Loss 0.0179 (0.0276)
# Finished training epoch 76
# Validate: [0/34]	Time 0.525 (0.525)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.506 (0.509)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 77
# Epoch: [77][0/134]	Time 0.510 (0.510)	Data 0.483 (0.483)	Loss 0.0141 (0.0141)
# Epoch: [77][25/134]	Time 0.513 (0.524)	Data 0.486 (0.498)	Loss 0.0192 (0.0193)
# Epoch: [77][50/134]	Time 0.541 (0.522)	Data 0.514 (0.495)	Loss 0.0252 (0.0219)
# Epoch: [77][75/134]	Time 0.499 (0.521)	Data 0.472 (0.494)	Loss 0.0413 (0.0247)
# Epoch: [77][100/134]	Time 0.510 (0.520)	Data 0.484 (0.493)	Loss 0.0250 (0.0262)
# Epoch: [77][125/134]	Time 0.496 (0.518)	Data 0.470 (0.492)	Loss 0.0179 (0.0276)
# Finished training epoch 77
# Validate: [0/34]	Time 0.520 (0.520)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.515 (0.508)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 78
# Epoch: [78][0/134]	Time 0.513 (0.513)	Data 0.486 (0.486)	Loss 0.0141 (0.0141)
# Epoch: [78][25/134]	Time 0.492 (0.530)	Data 0.466 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [78][50/134]	Time 0.538 (0.525)	Data 0.512 (0.498)	Loss 0.0252 (0.0219)
# Epoch: [78][75/134]	Time 0.505 (0.523)	Data 0.478 (0.496)	Loss 0.0413 (0.0247)
# Epoch: [78][100/134]	Time 0.505 (0.522)	Data 0.478 (0.495)	Loss 0.0250 (0.0262)
# Epoch: [78][125/134]	Time 0.515 (0.520)	Data 0.488 (0.493)	Loss 0.0179 (0.0276)
# Finished training epoch 78
# Validate: [0/34]	Time 0.517 (0.517)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.501 (0.508)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 79
# Epoch: [79][0/134]	Time 0.516 (0.516)	Data 0.489 (0.489)	Loss 0.0141 (0.0141)
# Epoch: [79][25/134]	Time 0.510 (0.533)	Data 0.483 (0.507)	Loss 0.0192 (0.0193)
# Epoch: [79][50/134]	Time 0.524 (0.529)	Data 0.497 (0.502)	Loss 0.0252 (0.0219)
# Epoch: [79][75/134]	Time 0.504 (0.525)	Data 0.477 (0.498)	Loss 0.0413 (0.0247)
# Epoch: [79][100/134]	Time 0.516 (0.523)	Data 0.490 (0.496)	Loss 0.0250 (0.0262)
# Epoch: [79][125/134]	Time 0.502 (0.521)	Data 0.476 (0.494)	Loss 0.0179 (0.0276)
# Finished training epoch 79
# Validate: [0/34]	Time 0.509 (0.509)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.513 (0.507)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 80
# Epoch: [80][0/134]	Time 0.515 (0.515)	Data 0.488 (0.488)	Loss 0.0141 (0.0141)
# Epoch: [80][25/134]	Time 0.502 (0.528)	Data 0.475 (0.502)	Loss 0.0192 (0.0193)
# Epoch: [80][50/134]	Time 0.526 (0.523)	Data 0.499 (0.497)	Loss 0.0252 (0.0219)
# Epoch: [80][75/134]	Time 0.495 (0.522)	Data 0.469 (0.495)	Loss 0.0413 (0.0247)
# Epoch: [80][100/134]	Time 0.507 (0.520)	Data 0.481 (0.494)	Loss 0.0250 (0.0262)
# Epoch: [80][125/134]	Time 0.511 (0.518)	Data 0.484 (0.491)	Loss 0.0179 (0.0276)
# Finished training epoch 80
# Validate: [0/34]	Time 0.528 (0.528)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.515 (0.516)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 81
# Epoch: [81][0/134]	Time 0.532 (0.532)	Data 0.505 (0.505)	Loss 0.0141 (0.0141)
# Epoch: [81][25/134]	Time 0.508 (0.535)	Data 0.481 (0.508)	Loss 0.0192 (0.0193)
# Epoch: [81][50/134]	Time 0.525 (0.529)	Data 0.498 (0.502)	Loss 0.0252 (0.0219)
# Epoch: [81][75/134]	Time 0.511 (0.527)	Data 0.484 (0.500)	Loss 0.0413 (0.0247)
# Epoch: [81][100/134]	Time 0.525 (0.526)	Data 0.498 (0.499)	Loss 0.0250 (0.0262)
# Epoch: [81][125/134]	Time 0.510 (0.524)	Data 0.483 (0.497)	Loss 0.0179 (0.0276)
# Finished training epoch 81
# Validate: [0/34]	Time 0.525 (0.525)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.508 (0.514)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 82
# Epoch: [82][0/134]	Time 0.519 (0.519)	Data 0.493 (0.493)	Loss 0.0141 (0.0141)
# Epoch: [82][25/134]	Time 0.515 (0.534)	Data 0.489 (0.507)	Loss 0.0192 (0.0193)
# Epoch: [82][50/134]	Time 0.530 (0.530)	Data 0.503 (0.504)	Loss 0.0252 (0.0219)
# Epoch: [82][75/134]	Time 0.513 (0.527)	Data 0.486 (0.500)	Loss 0.0413 (0.0247)
# Epoch: [82][100/134]	Time 0.509 (0.526)	Data 0.482 (0.499)	Loss 0.0250 (0.0262)
# Epoch: [82][125/134]	Time 0.513 (0.524)	Data 0.487 (0.497)	Loss 0.0179 (0.0276)
# Finished training epoch 82
# Validate: [0/34]	Time 0.523 (0.523)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.513 (0.510)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 83
# Epoch: [83][0/134]	Time 0.515 (0.515)	Data 0.488 (0.488)	Loss 0.0141 (0.0141)
# Epoch: [83][25/134]	Time 0.508 (0.530)	Data 0.481 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [83][50/134]	Time 0.531 (0.526)	Data 0.505 (0.500)	Loss 0.0252 (0.0219)
# Epoch: [83][75/134]	Time 0.502 (0.524)	Data 0.475 (0.497)	Loss 0.0413 (0.0247)
# Epoch: [83][100/134]	Time 0.515 (0.524)	Data 0.488 (0.497)	Loss 0.0250 (0.0262)
# Epoch: [83][125/134]	Time 0.515 (0.522)	Data 0.488 (0.496)	Loss 0.0179 (0.0276)
# Finished training epoch 83
# Validate: [0/34]	Time 0.527 (0.527)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.512 (0.516)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 84
# Epoch: [84][0/134]	Time 0.522 (0.522)	Data 0.496 (0.496)	Loss 0.0141 (0.0141)
# Epoch: [84][25/134]	Time 0.502 (0.533)	Data 0.476 (0.506)	Loss 0.0192 (0.0193)
# Epoch: [84][50/134]	Time 0.529 (0.529)	Data 0.502 (0.502)	Loss 0.0252 (0.0219)
# Epoch: [84][75/134]	Time 0.505 (0.526)	Data 0.479 (0.500)	Loss 0.0413 (0.0247)
# Epoch: [84][100/134]	Time 0.510 (0.525)	Data 0.483 (0.498)	Loss 0.0250 (0.0262)
# Epoch: [84][125/134]	Time 0.505 (0.523)	Data 0.479 (0.496)	Loss 0.0179 (0.0276)
# Finished training epoch 84
# Validate: [0/34]	Time 0.518 (0.518)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.510 (0.510)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 85
# Epoch: [85][0/134]	Time 0.524 (0.524)	Data 0.497 (0.497)	Loss 0.0141 (0.0141)
# Epoch: [85][25/134]	Time 0.500 (0.532)	Data 0.473 (0.505)	Loss 0.0192 (0.0193)
# Epoch: [85][50/134]	Time 0.546 (0.527)	Data 0.519 (0.500)	Loss 0.0252 (0.0219)
# Epoch: [85][75/134]	Time 0.506 (0.524)	Data 0.479 (0.498)	Loss 0.0413 (0.0247)
# Epoch: [85][100/134]	Time 0.514 (0.523)	Data 0.488 (0.497)	Loss 0.0250 (0.0262)
# Epoch: [85][125/134]	Time 0.509 (0.521)	Data 0.482 (0.495)	Loss 0.0179 (0.0276)
# Finished training epoch 85
# Validate: [0/34]	Time 0.521 (0.521)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.508 (0.513)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 86
# Epoch: [86][0/134]	Time 0.521 (0.521)	Data 0.493 (0.493)	Loss 0.0141 (0.0141)
# Epoch: [86][25/134]	Time 0.509 (0.535)	Data 0.483 (0.508)	Loss 0.0192 (0.0193)
# Epoch: [86][50/134]	Time 0.541 (0.531)	Data 0.515 (0.504)	Loss 0.0252 (0.0219)
# Epoch: [86][75/134]	Time 0.496 (0.528)	Data 0.469 (0.501)	Loss 0.0413 (0.0247)
# Epoch: [86][100/134]	Time 0.518 (0.526)	Data 0.491 (0.499)	Loss 0.0250 (0.0262)
# Epoch: [86][125/134]	Time 0.503 (0.523)	Data 0.477 (0.496)	Loss 0.0179 (0.0276)
# Finished training epoch 86
# Validate: [0/34]	Time 0.510 (0.510)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.512 (0.511)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 87
# Epoch: [87][0/134]	Time 0.520 (0.520)	Data 0.493 (0.493)	Loss 0.0141 (0.0141)
# Epoch: [87][25/134]	Time 0.501 (0.532)	Data 0.474 (0.505)	Loss 0.0192 (0.0193)
# Epoch: [87][50/134]	Time 0.544 (0.530)	Data 0.517 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [87][75/134]	Time 0.502 (0.528)	Data 0.475 (0.501)	Loss 0.0413 (0.0247)
# Epoch: [87][100/134]	Time 0.518 (0.526)	Data 0.491 (0.500)	Loss 0.0250 (0.0262)
# Epoch: [87][125/134]	Time 0.507 (0.524)	Data 0.480 (0.497)	Loss 0.0179 (0.0276)
# Finished training epoch 87
# Validate: [0/34]	Time 0.522 (0.522)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.511 (0.511)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 88
# Epoch: [88][0/134]	Time 0.534 (0.534)	Data 0.506 (0.506)	Loss 0.0141 (0.0141)
# Epoch: [88][25/134]	Time 0.500 (0.536)	Data 0.474 (0.510)	Loss 0.0192 (0.0193)
# Epoch: [88][50/134]	Time 0.530 (0.529)	Data 0.504 (0.502)	Loss 0.0252 (0.0219)
# Epoch: [88][75/134]	Time 0.495 (0.526)	Data 0.466 (0.499)	Loss 0.0413 (0.0247)
# Epoch: [88][100/134]	Time 0.515 (0.524)	Data 0.488 (0.497)	Loss 0.0250 (0.0262)
# Epoch: [88][125/134]	Time 0.510 (0.523)	Data 0.483 (0.496)	Loss 0.0179 (0.0276)
# Finished training epoch 88
# Validate: [0/34]	Time 0.518 (0.518)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.510 (0.514)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 89
# Epoch: [89][0/134]	Time 0.519 (0.519)	Data 0.492 (0.492)	Loss 0.0141 (0.0141)
# Epoch: [89][25/134]	Time 0.499 (0.535)	Data 0.473 (0.508)	Loss 0.0192 (0.0193)
# Epoch: [89][50/134]	Time 0.531 (0.531)	Data 0.505 (0.504)	Loss 0.0252 (0.0219)
# Epoch: [89][75/134]	Time 0.502 (0.528)	Data 0.476 (0.501)	Loss 0.0413 (0.0247)
# Epoch: [89][100/134]	Time 0.518 (0.527)	Data 0.491 (0.500)	Loss 0.0250 (0.0262)
# Epoch: [89][125/134]	Time 0.504 (0.524)	Data 0.477 (0.497)	Loss 0.0179 (0.0276)
# Finished training epoch 89
# Validate: [0/34]	Time 0.517 (0.517)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.503 (0.511)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 90
# Epoch: [90][0/134]	Time 0.522 (0.522)	Data 0.496 (0.496)	Loss 0.0141 (0.0141)
# Epoch: [90][25/134]	Time 0.498 (0.532)	Data 0.471 (0.506)	Loss 0.0192 (0.0193)
# Epoch: [90][50/134]	Time 0.529 (0.528)	Data 0.503 (0.502)	Loss 0.0252 (0.0219)
# Epoch: [90][75/134]	Time 0.507 (0.526)	Data 0.480 (0.499)	Loss 0.0413 (0.0247)
# Epoch: [90][100/134]	Time 0.516 (0.525)	Data 0.489 (0.498)	Loss 0.0250 (0.0262)
# Epoch: [90][125/134]	Time 0.507 (0.524)	Data 0.480 (0.497)	Loss 0.0179 (0.0276)
# Finished training epoch 90
# Validate: [0/34]	Time 0.524 (0.524)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.506 (0.512)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 91
# Epoch: [91][0/134]	Time 0.532 (0.532)	Data 0.505 (0.505)	Loss 0.0141 (0.0141)
# Epoch: [91][25/134]	Time 0.504 (0.535)	Data 0.477 (0.508)	Loss 0.0192 (0.0193)
# Epoch: [91][50/134]	Time 0.542 (0.531)	Data 0.516 (0.504)	Loss 0.0252 (0.0219)
# Epoch: [91][75/134]	Time 0.510 (0.528)	Data 0.483 (0.502)	Loss 0.0413 (0.0247)
# Epoch: [91][100/134]	Time 0.526 (0.528)	Data 0.499 (0.501)	Loss 0.0250 (0.0262)
# Epoch: [91][125/134]	Time 0.521 (0.526)	Data 0.494 (0.499)	Loss 0.0179 (0.0276)
# Finished training epoch 91
# Validate: [0/34]	Time 0.517 (0.517)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.511 (0.511)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 92
# Epoch: [92][0/134]	Time 0.524 (0.524)	Data 0.496 (0.496)	Loss 0.0141 (0.0141)
# Epoch: [92][25/134]	Time 0.509 (0.535)	Data 0.483 (0.508)	Loss 0.0192 (0.0193)
# Epoch: [92][50/134]	Time 0.530 (0.530)	Data 0.503 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [92][75/134]	Time 0.504 (0.527)	Data 0.477 (0.500)	Loss 0.0413 (0.0247)
# Epoch: [92][100/134]	Time 0.519 (0.525)	Data 0.492 (0.498)	Loss 0.0250 (0.0262)
# Epoch: [92][125/134]	Time 0.514 (0.523)	Data 0.488 (0.496)	Loss 0.0179 (0.0276)
# Finished training epoch 92
# Validate: [0/34]	Time 0.536 (0.536)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.513 (0.514)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 93
# Epoch: [93][0/134]	Time 0.519 (0.519)	Data 0.493 (0.493)	Loss 0.0141 (0.0141)
# Epoch: [93][25/134]	Time 0.501 (0.530)	Data 0.473 (0.504)	Loss 0.0192 (0.0193)
# Epoch: [93][50/134]	Time 0.533 (0.526)	Data 0.506 (0.500)	Loss 0.0252 (0.0219)
# Epoch: [93][75/134]	Time 0.501 (0.522)	Data 0.475 (0.495)	Loss 0.0413 (0.0247)
# Epoch: [93][100/134]	Time 0.530 (0.522)	Data 0.503 (0.495)	Loss 0.0250 (0.0262)
# Epoch: [93][125/134]	Time 0.505 (0.522)	Data 0.479 (0.496)	Loss 0.0179 (0.0276)
# Finished training epoch 93
# Validate: [0/34]	Time 0.521 (0.521)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.517 (0.516)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 94
# Epoch: [94][0/134]	Time 0.526 (0.526)	Data 0.498 (0.498)	Loss 0.0141 (0.0141)
# Epoch: [94][25/134]	Time 0.513 (0.538)	Data 0.486 (0.511)	Loss 0.0192 (0.0193)
# Epoch: [94][50/134]	Time 0.532 (0.533)	Data 0.506 (0.507)	Loss 0.0252 (0.0219)
# Epoch: [94][75/134]	Time 0.506 (0.531)	Data 0.480 (0.505)	Loss 0.0413 (0.0247)
# Epoch: [94][100/134]	Time 0.513 (0.529)	Data 0.487 (0.502)	Loss 0.0250 (0.0262)
# Epoch: [94][125/134]	Time 0.511 (0.526)	Data 0.485 (0.500)	Loss 0.0179 (0.0276)
# Finished training epoch 94
# Validate: [0/34]	Time 0.524 (0.524)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.516 (0.514)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 95
# Epoch: [95][0/134]	Time 0.521 (0.521)	Data 0.494 (0.494)	Loss 0.0141 (0.0141)
# Epoch: [95][25/134]	Time 0.520 (0.537)	Data 0.494 (0.510)	Loss 0.0192 (0.0193)
# Epoch: [95][50/134]	Time 0.536 (0.533)	Data 0.509 (0.507)	Loss 0.0252 (0.0219)
# Epoch: [95][75/134]	Time 0.504 (0.530)	Data 0.477 (0.503)	Loss 0.0413 (0.0247)
# Epoch: [95][100/134]	Time 0.519 (0.529)	Data 0.493 (0.503)	Loss 0.0250 (0.0262)
# Epoch: [95][125/134]	Time 0.516 (0.527)	Data 0.489 (0.500)	Loss 0.0179 (0.0276)
# Finished training epoch 95
# Validate: [0/34]	Time 0.540 (0.540)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.523 (0.516)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 96
# Epoch: [96][0/134]	Time 0.523 (0.523)	Data 0.496 (0.496)	Loss 0.0141 (0.0141)
# Epoch: [96][25/134]	Time 0.500 (0.536)	Data 0.473 (0.509)	Loss 0.0192 (0.0193)
# Epoch: [96][50/134]	Time 0.552 (0.532)	Data 0.525 (0.506)	Loss 0.0252 (0.0219)
# Epoch: [96][75/134]	Time 0.501 (0.529)	Data 0.475 (0.502)	Loss 0.0413 (0.0247)
# Epoch: [96][100/134]	Time 0.510 (0.528)	Data 0.484 (0.501)	Loss 0.0250 (0.0262)
# Epoch: [96][125/134]	Time 0.507 (0.525)	Data 0.480 (0.499)	Loss 0.0179 (0.0276)
# Finished training epoch 96
# Validate: [0/34]	Time 0.522 (0.522)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.516 (0.516)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 97
# Epoch: [97][0/134]	Time 0.520 (0.520)	Data 0.494 (0.494)	Loss 0.0141 (0.0141)
# Epoch: [97][25/134]	Time 0.511 (0.540)	Data 0.485 (0.513)	Loss 0.0192 (0.0193)
# Epoch: [97][50/134]	Time 0.534 (0.533)	Data 0.508 (0.506)	Loss 0.0252 (0.0219)
# Epoch: [97][75/134]	Time 0.505 (0.530)	Data 0.479 (0.503)	Loss 0.0413 (0.0247)
# Epoch: [97][100/134]	Time 0.514 (0.528)	Data 0.487 (0.502)	Loss 0.0250 (0.0262)
# Epoch: [97][125/134]	Time 0.513 (0.527)	Data 0.486 (0.500)	Loss 0.0179 (0.0276)
# Finished training epoch 97
# Validate: [0/34]	Time 0.526 (0.526)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.508 (0.513)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 98
# Epoch: [98][0/134]	Time 0.517 (0.517)	Data 0.491 (0.491)	Loss 0.0141 (0.0141)
# Epoch: [98][25/134]	Time 0.503 (0.534)	Data 0.477 (0.507)	Loss 0.0192 (0.0193)
# Epoch: [98][50/134]	Time 0.534 (0.530)	Data 0.508 (0.503)	Loss 0.0252 (0.0219)
# Epoch: [98][75/134]	Time 0.499 (0.528)	Data 0.472 (0.501)	Loss 0.0413 (0.0247)
# Epoch: [98][100/134]	Time 0.527 (0.527)	Data 0.501 (0.501)	Loss 0.0250 (0.0262)
# Epoch: [98][125/134]	Time 0.511 (0.525)	Data 0.484 (0.498)	Loss 0.0179 (0.0276)
# Finished training epoch 98
# Validate: [0/34]	Time 0.532 (0.532)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.513 (0.509)	Loss 0.0291 (0.0253)
# Finished validation.
# Starting training epoch 99
# Epoch: [99][0/134]	Time 0.515 (0.515)	Data 0.489 (0.489)	Loss 0.0141 (0.0141)
# Epoch: [99][25/134]	Time 0.502 (0.529)	Data 0.475 (0.503)	Loss 0.0192 (0.0193)
# Epoch: [99][50/134]	Time 0.532 (0.526)	Data 0.505 (0.499)	Loss 0.0252 (0.0219)
# Epoch: [99][75/134]	Time 0.504 (0.524)	Data 0.478 (0.497)	Loss 0.0413 (0.0247)
# Epoch: [99][100/134]	Time 0.508 (0.523)	Data 0.481 (0.496)	Loss 0.0250 (0.0262)
# Epoch: [99][125/134]	Time 0.515 (0.521)	Data 0.489 (0.495)	Loss 0.0179 (0.0276)
# Finished training epoch 99
# Validate: [0/34]	Time 0.518 (0.518)	Loss 0.0374 (0.0374)
# Validate: [25/34]	Time 0.512 (0.513)	Loss 0.0291 (0.0253)
# Finished validation.

# %%
## ====================== Pretrained model:
# data = next(iter(train_loader))
# Ls     = data[0] 
# abs_   = data[1] 
# target = data[2]

# print(f"Feature batch shape: {Ls.size()}")
# print(f"Labels batch shape: {abs_.size()}")

# img = Ls[0].squeeze()
# plt.imshow(img, cmap="gray")
# plt.show()

# Load model
check_point = '/content/checkpoints/model-epoch-16-losses-0.025.pth'
pretrained = torch.load(check_point, map_location=lambda storage, loc: storage)
model.load_state_dict(pretrained)

# Make folders
import os
os.makedirs('outputs/color', exist_ok=True)
os.makedirs('outputs/gray', exist_ok=True)
os.makedirs('checkpoints', exist_ok=True)

# Validate
save_images = True
with torch.no_grad():
  validate(val_loader, model, criterion, save_images, 0)

# Show images 
import matplotlib.image as mpimg
image_pairs = [(f'outputs/color/img-{i}-epoch-0.jpg', 
                f'outputs/gray/img-{i}-epoch-0.jpg')
                 for i in range(0,10)]
for c, g in image_pairs:
  color = mpimg.imread(c)
  gray  = mpimg.imread(g)
  f, axarr = plt.subplots(1, 2)
  f.set_size_inches(15, 15)
  axarr[0].imshow(gray, cmap='gray')
  axarr[1].imshow(color)
  axarr[0].axis('off'), axarr[1].axis('off')
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 3645 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 2206 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 138 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 654 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 7422 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 3270 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 57 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /usr/local/lib/python3.7/dist-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 633 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# Validate: [0/34]	Time 0.897 (0.897)	Loss 0.0357 (0.0357)
# Validate: [25/34]	Time 0.522 (0.533)	Loss 0.0278 (0.0244)
# Finished validation.
