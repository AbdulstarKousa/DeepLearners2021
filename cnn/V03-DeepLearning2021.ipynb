# %%
""""
Change the Loss Function to L1Los
Change the learning rate to 0.0001
"""

# %%
## ====================== Mount Google Drive:
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
## ====================== Libraries:
""" For plotting """
import numpy as np
import matplotlib.pyplot as plt

""" For IPython """
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')

""" For conversion """
from skimage.color import lab2rgb, rgb2lab, rgb2gray

""" For everything """
import torch
import torch.nn as nn
import torch.nn.functional as F

""" For our model """
import torchvision.models as models
from torchvision import datasets, transforms

""" For utilities """
import os, time

""" Check if GPU is available """
use_gpu = torch.cuda.is_available()

# %%
## ====================== Load data:
# Grayscale
class GrayscaleImageFolder(datasets.ImageFolder):
  '''Custom images folder, which converts images to grayscale before loading'''
  def __getitem__(self, index):
    path, target = self.imgs[index]
    img = self.loader(path)
    if self.transform is not None:
      img_original = self.transform(img)
      img_original = np.asarray(img_original)
      img_lab = rgb2lab(img_original)
      img_lab = (img_lab + 128) / 255
      img_ab = img_lab[:, :, 1:3]
      img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
      img_original = rgb2gray(img_original)
      img_original = torch.from_numpy(img_original).unsqueeze(0).float()
    if self.target_transform is not None:
      target = self.target_transform(target)
    return img_original, img_ab, target

# transforms
train_transforms = transforms.Compose([
                      transforms.RandomResizedCrop(224),
                      transforms.RandomHorizontalFlip()
                      ])
val_transforms = transforms.Compose([
                      transforms.Resize(256), 
                      transforms.CenterCrop(224)
                      ])

# loaders 
train_imagefolder = GrayscaleImageFolder('/content/gdrive/MyDrive/Data/DeepLearning2021/images/train', train_transforms)
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=16, shuffle=True)
val_imagefolder = GrayscaleImageFolder('/content/gdrive/MyDrive/Data/DeepLearning2021/images/val' , val_transforms)
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=16, shuffle=False)

# %%
## ====================== The Model:
class ColorizationNet(nn.Module):
  def __init__(self, input_size=128):
    super(ColorizationNet, self).__init__()
    MIDLEVEL_FEATURE_SIZE = 128

    # First half: ResNet
    resnet = models.resnet18(num_classes=365) 
    """ Change first conv layer to accept single-channel (grayscale) input """
    resnet.conv1.weight = nn.Parameter(resnet.conv1.weight.sum(dim=1).unsqueeze(1)) 
    """ Extract midlevel features from ResNet-gray """
    self.midlevel_resnet = nn.Sequential(*list(resnet.children())[0:6])

    # Second half: Upsampling
    self.upsample = nn.Sequential(     
      nn.Conv2d(MIDLEVEL_FEATURE_SIZE, 128, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(128),
      nn.ReLU(),
      nn.Upsample(scale_factor=2),
      nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(64),
      nn.ReLU(),
      nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(64),
      nn.ReLU(),
      nn.Upsample(scale_factor=2),
      nn.Conv2d(64, 32, kernel_size=3, stride=1, padding=1),
      nn.BatchNorm2d(32),
      nn.ReLU(),
      nn.Conv2d(32, 2, kernel_size=3, stride=1, padding=1),
      nn.Upsample(scale_factor=2)
    )

  def forward(self, input):
    # Pass input through ResNet-gray to extract features
    midlevel_features = self.midlevel_resnet(input)
    # Upsample to get colors
    output = self.upsample(midlevel_features)
    return output

model = ColorizationNet()

# %%
## ====================== Helper functions:
class AverageMeter(object):
  '''A handy class from the PyTorch ImageNet tutorial''' 
  def __init__(self):
    self.reset()

  def reset(self):
    self.val, self.avg, self.sum, self.count = 0, 0, 0, 0

  def update(self, val, n=1):
    self.val = val
    self.sum += val * n
    self.count += n
    self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
  '''Show/save rgb image from grayscale and ab channels
     Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
  plt.clf() # clear matplotlib 
  color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
  color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
  color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
  color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
  color_image = lab2rgb(color_image.astype(np.float64))
  grayscale_input = grayscale_input.squeeze().numpy()
  if save_path is not None and save_name is not None: 
    plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
    plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
## ====================== Set-up Training:
# Loss Function
criterion = nn.L1Loss()

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0)

## ====================== Training:
def train(train_loader, model, criterion, optimizer, epoch):
  print('Starting training epoch {}'.format(epoch))
  model.train()
  
  # Prepare value counters and timers
  batch_time, data_time, losses = AverageMeter(), AverageMeter(), AverageMeter()

  end = time.time()
  for i, (input_gray, input_ab, target) in enumerate(train_loader):
    
    # Use GPU if available
    if use_gpu: input_gray, input_ab, target = input_gray.cuda(), input_ab.cuda(), target.cuda()

    # Record time to load data (above)
    data_time.update(time.time() - end)

    # Run forward pass
    output_ab = model(input_gray) 
    loss = criterion(output_ab, input_ab) 
    losses.update(loss.item(), input_gray.size(0))

    # Compute gradient and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Record time to do forward and backward passes
    batch_time.update(time.time() - end)
    end = time.time()

    # Print model accuracy -- in the code below, val refers to value, not validation
    if i % 25 == 0:
      print('Epoch: [{0}][{1}/{2}]\t'
            'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
            'Data {data_time.val:.3f} ({data_time.avg:.3f})\t'
            'Loss {loss.val:.4f} ({loss.avg:.4f})\t'.format(
              epoch, i, len(train_loader), batch_time=batch_time,
             data_time=data_time, loss=losses)) 

  print('Finished training epoch {}'.format(epoch))

# %%
## ====================== Validation:
def validate(val_loader, model, criterion, save_images, epoch):
  model.eval()

  # Prepare value counters and timers
  batch_time, data_time, losses = AverageMeter(), AverageMeter(), AverageMeter()

  end = time.time()
  already_saved_images = False
  for i, (input_gray, input_ab, target) in enumerate(val_loader):
    data_time.update(time.time() - end)

    # Use GPU
    if use_gpu: input_gray, input_ab, target = input_gray.cuda(), input_ab.cuda(), target.cuda()

    # Run model and record loss
    output_ab = model(input_gray) # throw away class predictions
    loss = criterion(output_ab, input_ab)
    losses.update(loss.item(), input_gray.size(0))

    # Save images to file
    if save_images and not already_saved_images:
      already_saved_images = True
      for j in range(min(len(output_ab), 10)): # save at most 5 images
        save_path = {'grayscale': 'outputs/gray/', 'colorized': 'outputs/color/'}
        save_name = 'img-{}-epoch-{}.jpg'.format(i * val_loader.batch_size + j, epoch)
        to_rgb(input_gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    # Record time to do forward passes and save images
    batch_time.update(time.time() - end)
    end = time.time()

    # Print model accuracy -- in the code below, val refers to both value and validation
    if i % 25 == 0:
      print('Validate: [{0}/{1}]\t'
            'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
            'Loss {loss.val:.4f} ({loss.avg:.4f})\t'.format(
             i, len(val_loader), batch_time=batch_time, loss=losses))

  print('Finished validation.')
  return losses.avg

# %%
## ====================== Main Driver:
# to GPU
if use_gpu: 
  criterion = criterion.cuda()
  model = model.cuda()

# Make folders and set parameters
import os
os.makedirs('outputs/color', exist_ok=True)
os.makedirs('outputs/gray', exist_ok=True)
os.makedirs('checkpoints', exist_ok=True)
save_images = False
best_losses = 1e10
epochs = 100

# Train model
for epoch in range(epochs):
  # Train for one epoch, then validate
  train(train_loader, model, criterion, optimizer, epoch)
  with torch.no_grad():
    losses = validate(val_loader, model, criterion, save_images, epoch)
  # Save checkpoint and replace old best model if current model is better
  if losses < best_losses:
    best_losses = losses
    torch.save(model.state_dict(), 'checkpoints/model-epoch-{}-losses-{:.3f}.pth'.format(epoch+1,losses))
# Out:
# Starting training epoch 0
# Epoch: [0][0/134]	Time 6.473 (6.473)	Data 6.112 (6.112)	Loss 0.5797 (0.5797)
# Epoch: [0][25/134]	Time 5.918 (5.895)	Data 5.899 (5.861)	Loss 0.1855 (0.3602)
# Epoch: [0][50/134]	Time 5.687 (5.909)	Data 5.667 (5.881)	Loss 0.0672 (0.2359)
# Epoch: [0][75/134]	Time 5.710 (5.858)	Data 5.691 (5.833)	Loss 0.0596 (0.1808)
# Epoch: [0][100/134]	Time 5.751 (5.840)	Data 5.731 (5.816)	Loss 0.0635 (0.1521)
# Epoch: [0][125/134]	Time 5.625 (5.819)	Data 5.602 (5.795)	Loss 0.0601 (0.1341)
# Finished training epoch 0
# Validate: [0/34]	Time 5.492 (5.492)	Loss 0.0416 (0.0416)
# Validate: [25/34]	Time 5.590 (6.140)	Loss 0.0528 (0.0590)
# Finished validation.
# Starting training epoch 1
# Epoch: [1][0/134]	Time 0.389 (0.389)	Data 0.369 (0.369)	Loss 0.0641 (0.0641)
# Epoch: [1][25/134]	Time 0.388 (0.398)	Data 0.365 (0.377)	Loss 0.0516 (0.0597)
# Epoch: [1][50/134]	Time 0.392 (0.398)	Data 0.372 (0.377)	Loss 0.0658 (0.0591)
# Epoch: [1][75/134]	Time 0.405 (0.399)	Data 0.385 (0.379)	Loss 0.0552 (0.0577)
# Epoch: [1][100/134]	Time 0.399 (0.399)	Data 0.379 (0.378)	Loss 0.0448 (0.0574)
# Epoch: [1][125/134]	Time 0.397 (0.401)	Data 0.378 (0.380)	Loss 0.0517 (0.0565)
# Finished training epoch 1
# Validate: [0/34]	Time 0.389 (0.389)	Loss 0.0408 (0.0408)
# Validate: [25/34]	Time 0.446 (0.407)	Loss 0.0534 (0.0538)
# Finished validation.
# Starting training epoch 2
# Epoch: [2][0/134]	Time 0.429 (0.429)	Data 0.409 (0.409)	Loss 0.0592 (0.0592)
# Epoch: [2][25/134]	Time 0.402 (0.408)	Data 0.382 (0.387)	Loss 0.0542 (0.0540)
# Epoch: [2][50/134]	Time 0.579 (0.409)	Data 0.560 (0.388)	Loss 0.0685 (0.0556)
# Epoch: [2][75/134]	Time 0.411 (0.406)	Data 0.391 (0.385)	Loss 0.0602 (0.0554)
# Epoch: [2][100/134]	Time 0.404 (0.405)	Data 0.384 (0.384)	Loss 0.0548 (0.0551)
# Epoch: [3][25/134]	Time 0.400 (0.397)	Data 0.378 (0.376)	Loss 0.0504 (0.0534)
# Epoch: [3][50/134]	Time 0.392 (0.394)	Data 0.371 (0.374)	Loss 0.0471 (0.0530)
# Epoch: [3][75/134]	Time 0.391 (0.395)	Data 0.368 (0.374)	Loss 0.0682 (0.0541)
# Epoch: [3][100/134]	Time 0.389 (0.394)	Data 0.369 (0.373)	Loss 0.0415 (0.0538)
# Epoch: [3][125/134]	Time 0.404 (0.395)	Data 0.384 (0.374)	Loss 0.0519 (0.0538)
# Finished training epoch 3
# Validate: [0/34]	Time 0.381 (0.381)	Loss 0.0380 (0.0380)
# Validate: [25/34]	Time 0.422 (0.392)	Loss 0.0533 (0.0521)
# Finished validation.
# Starting training epoch 4
# Epoch: [4][0/134]	Time 0.392 (0.392)	Data 0.372 (0.372)	Loss 0.0519 (0.0519)
# Epoch: [4][25/134]	Time 0.391 (0.397)	Data 0.372 (0.377)	Loss 0.0437 (0.0549)
# Epoch: [4][50/134]	Time 0.405 (0.395)	Data 0.385 (0.375)	Loss 0.0557 (0.0532)
# Epoch: [4][75/134]	Time 0.402 (0.393)	Data 0.381 (0.373)	Loss 0.0533 (0.0536)
# Epoch: [4][100/134]	Time 0.376 (0.391)	Data 0.357 (0.370)	Loss 0.0511 (0.0534)
# Epoch: [4][125/134]	Time 0.378 (0.390)	Data 0.358 (0.370)	Loss 0.0485 (0.0531)
# Finished training epoch 4
# Validate: [0/34]	Time 0.404 (0.404)	Loss 0.0354 (0.0354)
# Validate: [25/34]	Time 0.421 (0.390)	Loss 0.0529 (0.0515)
# Finished validation.
# Starting training epoch 5
# Epoch: [5][0/134]	Time 0.380 (0.380)	Data 0.361 (0.361)	Loss 0.0470 (0.0470)
# Epoch: [5][25/134]	Time 0.402 (0.405)	Data 0.381 (0.384)	Loss 0.0487 (0.0523)
# Epoch: [5][50/134]	Time 0.386 (0.402)	Data 0.367 (0.381)	Loss 0.0469 (0.0523)
# Epoch: [5][75/134]	Time 0.381 (0.399)	Data 0.361 (0.379)	Loss 0.0518 (0.0524)
# Epoch: [5][100/134]	Time 0.392 (0.398)	Data 0.370 (0.378)	Loss 0.0571 (0.0528)
# Epoch: [5][125/134]	Time 0.386 (0.397)	Data 0.366 (0.376)	Loss 0.0467 (0.0525)
# Finished training epoch 5
# Validate: [0/34]	Time 0.395 (0.395)	Loss 0.0360 (0.0360)
# Validate: [25/34]	Time 0.428 (0.397)	Loss 0.0531 (0.0505)
# Finished validation.
# Starting training epoch 6
# Epoch: [6][0/134]	Time 0.429 (0.429)	Data 0.407 (0.407)	Loss 0.0516 (0.0516)
# Epoch: [6][25/134]	Time 0.389 (0.398)	Data 0.369 (0.378)	Loss 0.0503 (0.0550)
# Epoch: [6][50/134]	Time 0.388 (0.397)	Data 0.364 (0.376)	Loss 0.0495 (0.0535)
# Epoch: [6][75/134]	Time 0.398 (0.395)	Data 0.379 (0.375)	Loss 0.0590 (0.0531)
# Epoch: [6][100/134]	Time 0.383 (0.394)	Data 0.361 (0.374)	Loss 0.0506 (0.0522)
# Epoch: [6][125/134]	Time 0.387 (0.395)	Data 0.367 (0.374)	Loss 0.0482 (0.0522)
# Finished training epoch 6
# Validate: [0/34]	Time 0.402 (0.402)	Loss 0.0337 (0.0337)
# Validate: [25/34]	Time 0.413 (0.396)	Loss 0.0512 (0.0513)
# Finished validation.
# Starting training epoch 7
# Epoch: [7][0/134]	Time 0.395 (0.395)	Data 0.374 (0.374)	Loss 0.0572 (0.0572)
# Epoch: [7][25/134]	Time 0.409 (0.395)	Data 0.387 (0.375)	Loss 0.0558 (0.0512)
# Epoch: [7][50/134]	Time 0.390 (0.394)	Data 0.371 (0.373)	Loss 0.0494 (0.0512)
# Epoch: [7][75/134]	Time 0.386 (0.395)	Data 0.367 (0.375)	Loss 0.0544 (0.0515)
# Epoch: [7][100/134]	Time 0.378 (0.396)	Data 0.359 (0.376)	Loss 0.0411 (0.0513)
# Epoch: [7][125/134]	Time 0.390 (0.396)	Data 0.371 (0.375)	Loss 0.0484 (0.0516)
# Finished training epoch 7
# Validate: [0/34]	Time 0.392 (0.392)	Loss 0.0390 (0.0390)
# Validate: [25/34]	Time 0.418 (0.398)	Loss 0.0520 (0.0525)
# Finished validation.
# Starting training epoch 8
# Epoch: [8][0/134]	Time 0.392 (0.392)	Data 0.372 (0.372)	Loss 0.0504 (0.0504)
# Epoch: [8][25/134]	Time 0.407 (0.402)	Data 0.386 (0.381)	Loss 0.0582 (0.0543)
# Epoch: [8][50/134]	Time 0.384 (0.398)	Data 0.363 (0.377)	Loss 0.0480 (0.0529)
# Epoch: [8][75/134]	Time 0.397 (0.396)	Data 0.377 (0.375)	Loss 0.0439 (0.0522)
# Epoch: [8][100/134]	Time 0.388 (0.396)	Data 0.367 (0.376)	Loss 0.0457 (0.0520)
# Epoch: [8][125/134]	Time 0.381 (0.396)	Data 0.360 (0.375)	Loss 0.0552 (0.0521)
# Finished training epoch 8
# Validate: [0/34]	Time 0.401 (0.401)	Loss 0.0383 (0.0383)
# Validate: [25/34]	Time 0.426 (0.397)	Loss 0.0539 (0.0524)
# Finished validation.
# Starting training epoch 9
# Epoch: [9][0/134]	Time 0.397 (0.397)	Data 0.378 (0.378)	Loss 0.0577 (0.0577)
# Epoch: [9][25/134]	Time 0.395 (0.401)	Data 0.375 (0.380)	Loss 0.0476 (0.0550)
# Epoch: [9][50/134]	Time 0.393 (0.399)	Data 0.374 (0.379)	Loss 0.0515 (0.0524)
# Epoch: [9][75/134]	Time 0.394 (0.399)	Data 0.375 (0.378)	Loss 0.0505 (0.0519)
# Epoch: [9][100/134]	Time 0.393 (0.397)	Data 0.373 (0.377)	Loss 0.0447 (0.0515)
# Epoch: [9][125/134]	Time 0.398 (0.396)	Data 0.375 (0.376)	Loss 0.0454 (0.0518)
# Finished training epoch 9
# Validate: [0/34]	Time 0.393 (0.393)	Loss 0.0359 (0.0359)
# Validate: [25/34]	Time 0.421 (0.393)	Loss 0.0551 (0.0505)
# Finished validation.
# Starting training epoch 10
# Epoch: [10][0/134]	Time 0.398 (0.398)	Data 0.378 (0.378)	Loss 0.0618 (0.0618)
# Epoch: [10][25/134]	Time 0.395 (0.398)	Data 0.375 (0.378)	Loss 0.0515 (0.0540)
# Epoch: [10][50/134]	Time 0.394 (0.398)	Data 0.374 (0.377)	Loss 0.0439 (0.0530)
# Epoch: [10][75/134]	Time 0.387 (0.397)	Data 0.368 (0.376)	Loss 0.0434 (0.0522)
# Epoch: [10][100/134]	Time 0.392 (0.397)	Data 0.369 (0.377)	Loss 0.0455 (0.0517)
# Epoch: [10][125/134]	Time 0.406 (0.397)	Data 0.383 (0.377)	Loss 0.0559 (0.0515)
# Finished training epoch 10
# Validate: [0/34]	Time 0.389 (0.389)	Loss 0.0356 (0.0356)
# Validate: [25/34]	Time 0.427 (0.402)	Loss 0.0514 (0.0514)
# Finished validation.
# Starting training epoch 11
# Epoch: [11][0/134]	Time 0.394 (0.394)	Data 0.372 (0.372)	Loss 0.0416 (0.0416)
# Epoch: [11][25/134]	Time 0.412 (0.401)	Data 0.392 (0.381)	Loss 0.0602 (0.0483)
# Epoch: [11][50/134]	Time 0.398 (0.399)	Data 0.376 (0.379)	Loss 0.0504 (0.0495)
# Epoch: [11][75/134]	Time 0.409 (0.399)	Data 0.386 (0.378)	Loss 0.0526 (0.0493)
# Epoch: [11][100/134]	Time 0.392 (0.399)	Data 0.372 (0.379)	Loss 0.0513 (0.0505)
# Epoch: [11][125/134]	Time 0.395 (0.401)	Data 0.374 (0.381)	Loss 0.0432 (0.0506)
# Finished training epoch 11
# Validate: [0/34]	Time 0.387 (0.387)	Loss 0.0348 (0.0348)
# Validate: [25/34]	Time 0.424 (0.400)	Loss 0.0494 (0.0509)
# Finished validation.
# Starting training epoch 12
# Epoch: [12][0/134]	Time 0.392 (0.392)	Data 0.371 (0.371)	Loss 0.0472 (0.0472)
# Epoch: [12][25/134]	Time 0.387 (0.394)	Data 0.368 (0.374)	Loss 0.0522 (0.0531)
# Epoch: [12][50/134]	Time 0.410 (0.400)	Data 0.390 (0.380)	Loss 0.0480 (0.0519)
# Epoch: [12][75/134]	Time 0.401 (0.400)	Data 0.381 (0.379)	Loss 0.0538 (0.0516)
# Epoch: [12][100/134]	Time 0.391 (0.399)	Data 0.371 (0.379)	Loss 0.0440 (0.0510)
# Epoch: [12][125/134]	Time 0.400 (0.398)	Data 0.377 (0.378)	Loss 0.0598 (0.0511)
# Finished training epoch 12
# Validate: [0/34]	Time 0.391 (0.391)	Loss 0.0351 (0.0351)
# Validate: [25/34]	Time 0.428 (0.402)	Loss 0.0527 (0.0512)
# Finished validation.
# Starting training epoch 13
# Epoch: [13][0/134]	Time 0.408 (0.408)	Data 0.385 (0.385)	Loss 0.0519 (0.0519)
# Epoch: [13][25/134]	Time 0.384 (0.395)	Data 0.364 (0.374)	Loss 0.0574 (0.0532)
# Epoch: [13][50/134]	Time 0.396 (0.399)	Data 0.375 (0.378)	Loss 0.0545 (0.0523)
# Epoch: [13][75/134]	Time 0.401 (0.401)	Data 0.381 (0.380)	Loss 0.0522 (0.0517)
# Epoch: [13][100/134]	Time 0.395 (0.399)	Data 0.376 (0.379)	Loss 0.0541 (0.0516)
# Epoch: [13][125/134]	Time 0.406 (0.399)	Data 0.383 (0.378)	Loss 0.0508 (0.0513)
# Finished training epoch 13
# Validate: [0/34]	Time 0.388 (0.388)	Loss 0.0338 (0.0338)
# Validate: [25/34]	Time 0.430 (0.398)	Loss 0.0519 (0.0519)
# Finished validation.
# Starting training epoch 14
# Epoch: [14][0/134]	Time 0.404 (0.404)	Data 0.382 (0.382)	Loss 0.0514 (0.0514)
# Epoch: [14][25/134]	Time 0.385 (0.401)	Data 0.366 (0.380)	Loss 0.0472 (0.0501)
# Epoch: [14][50/134]	Time 0.392 (0.401)	Data 0.372 (0.380)	Loss 0.0401 (0.0508)
# Epoch: [14][75/134]	Time 0.404 (0.399)	Data 0.381 (0.378)	Loss 0.0438 (0.0516)
# Epoch: [14][100/134]	Time 0.400 (0.398)	Data 0.378 (0.377)	Loss 0.0622 (0.0508)
# Epoch: [14][125/134]	Time 0.426 (0.398)	Data 0.404 (0.377)	Loss 0.0458 (0.0509)
# Finished training epoch 14
# Validate: [0/34]	Time 0.389 (0.389)	Loss 0.0348 (0.0348)
# Validate: [25/34]	Time 0.436 (0.400)	Loss 0.0496 (0.0504)
# Finished validation.
# Starting training epoch 15
# Epoch: [15][0/134]	Time 0.402 (0.402)	Data 0.379 (0.379)	Loss 0.0520 (0.0520)
# Epoch: [15][25/134]	Time 0.397 (0.397)	Data 0.377 (0.376)	Loss 0.0473 (0.0495)
# Epoch: [15][50/134]	Time 0.393 (0.400)	Data 0.373 (0.380)	Loss 0.0505 (0.0495)
# Epoch: [15][75/134]	Time 0.393 (0.400)	Data 0.371 (0.379)	Loss 0.0559 (0.0501)
# Epoch: [15][100/134]	Time 0.394 (0.401)	Data 0.375 (0.380)	Loss 0.0520 (0.0510)
# Epoch: [15][125/134]	Time 0.399 (0.401)	Data 0.377 (0.380)	Loss 0.0520 (0.0505)
# Finished training epoch 15
# Validate: [0/34]	Time 0.401 (0.401)	Loss 0.0350 (0.0350)
# Validate: [25/34]	Time 0.431 (0.401)	Loss 0.0499 (0.0498)
# Finished validation.
# Starting training epoch 16
# Epoch: [16][0/134]	Time 0.399 (0.399)	Data 0.379 (0.379)	Loss 0.0549 (0.0549)
# Epoch: [16][25/134]	Time 0.393 (0.398)	Data 0.370 (0.377)	Loss 0.0529 (0.0499)
# Epoch: [16][50/134]	Time 0.379 (0.398)	Data 0.358 (0.377)	Loss 0.0617 (0.0500)
# Epoch: [16][75/134]	Time 0.404 (0.399)	Data 0.384 (0.379)	Loss 0.0550 (0.0500)
# Epoch: [16][100/134]	Time 0.391 (0.400)	Data 0.370 (0.379)	Loss 0.0461 (0.0502)
# Epoch: [16][125/134]	Time 0.397 (0.400)	Data 0.378 (0.379)	Loss 0.0535 (0.0505)
# Finished training epoch 16
# Validate: [0/34]	Time 0.382 (0.382)	Loss 0.0386 (0.0386)
# Validate: [25/34]	Time 0.434 (0.399)	Loss 0.0512 (0.0506)
# Finished validation.
# Starting training epoch 17
# Epoch: [17][0/134]	Time 0.408 (0.408)	Data 0.385 (0.385)	Loss 0.0420 (0.0420)
# Epoch: [17][25/134]	Time 0.396 (0.397)	Data 0.374 (0.376)	Loss 0.0479 (0.0516)
# Epoch: [17][50/134]	Time 0.402 (0.398)	Data 0.382 (0.377)	Loss 0.0591 (0.0507)
# Epoch: [17][75/134]	Time 0.400 (0.400)	Data 0.380 (0.379)	Loss 0.0510 (0.0507)
# Epoch: [17][100/134]	Time 0.397 (0.399)	Data 0.375 (0.379)	Loss 0.0490 (0.0502)
# Epoch: [17][125/134]	Time 0.417 (0.400)	Data 0.396 (0.380)	Loss 0.0518 (0.0505)
# Finished training epoch 17
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0344 (0.0344)
# Validate: [25/34]	Time 0.435 (0.406)	Loss 0.0515 (0.0494)
# Finished validation.
# Starting training epoch 18
# Epoch: [18][0/134]	Time 0.408 (0.408)	Data 0.385 (0.385)	Loss 0.0540 (0.0540)
# Epoch: [18][25/134]	Time 0.409 (0.403)	Data 0.389 (0.382)	Loss 0.0618 (0.0522)
# Epoch: [18][50/134]	Time 0.397 (0.402)	Data 0.378 (0.381)	Loss 0.0480 (0.0509)
# Epoch: [18][75/134]	Time 0.414 (0.405)	Data 0.392 (0.384)	Loss 0.0452 (0.0510)
# Epoch: [18][100/134]	Time 0.402 (0.404)	Data 0.382 (0.383)	Loss 0.0540 (0.0508)
# Epoch: [18][125/134]	Time 0.406 (0.404)	Data 0.387 (0.383)	Loss 0.0457 (0.0508)
# Finished training epoch 18
# Validate: [0/34]	Time 0.380 (0.380)	Loss 0.0350 (0.0350)
# Validate: [25/34]	Time 0.432 (0.403)	Loss 0.0499 (0.0498)
# Finished validation.
# Starting training epoch 19
# Epoch: [19][0/134]	Time 0.396 (0.396)	Data 0.375 (0.375)	Loss 0.0519 (0.0519)
# Epoch: [19][25/134]	Time 0.437 (0.411)	Data 0.417 (0.390)	Loss 0.0521 (0.0495)
# Epoch: [19][50/134]	Time 0.402 (0.407)	Data 0.380 (0.386)	Loss 0.0494 (0.0498)
# Epoch: [19][75/134]	Time 0.414 (0.407)	Data 0.392 (0.386)	Loss 0.0401 (0.0498)
# Epoch: [19][100/134]	Time 0.394 (0.406)	Data 0.375 (0.386)	Loss 0.0523 (0.0500)
# Epoch: [19][125/134]	Time 0.410 (0.407)	Data 0.391 (0.386)	Loss 0.0496 (0.0502)
# Finished training epoch 19
# Validate: [0/34]	Time 0.402 (0.402)	Loss 0.0340 (0.0340)
# Validate: [25/34]	Time 0.442 (0.401)	Loss 0.0541 (0.0539)
# Finished validation.
# Starting training epoch 20
# Epoch: [20][0/134]	Time 0.390 (0.390)	Data 0.370 (0.370)	Loss 0.0444 (0.0444)
# Epoch: [20][25/134]	Time 0.410 (0.406)	Data 0.390 (0.386)	Loss 0.0579 (0.0499)
# Epoch: [20][50/134]	Time 0.405 (0.405)	Data 0.384 (0.385)	Loss 0.0536 (0.0508)
# Epoch: [20][75/134]	Time 0.415 (0.407)	Data 0.395 (0.386)	Loss 0.0479 (0.0509)
# Epoch: [20][100/134]	Time 0.408 (0.407)	Data 0.385 (0.387)	Loss 0.0564 (0.0505)
# Epoch: [20][125/134]	Time 0.415 (0.409)	Data 0.393 (0.388)	Loss 0.0437 (0.0505)
# Finished training epoch 20
# Validate: [0/34]	Time 0.395 (0.395)	Loss 0.0418 (0.0418)
# Validate: [25/34]	Time 0.436 (0.408)	Loss 0.0515 (0.0559)
# Finished validation.
# Starting training epoch 21
# Epoch: [21][0/134]	Time 0.416 (0.416)	Data 0.396 (0.396)	Loss 0.0612 (0.0612)
# Epoch: [21][25/134]	Time 0.418 (0.408)	Data 0.398 (0.387)	Loss 0.0453 (0.0504)
# Epoch: [21][50/134]	Time 0.404 (0.407)	Data 0.385 (0.387)	Loss 0.0437 (0.0505)
# Epoch: [21][75/134]	Time 0.413 (0.408)	Data 0.393 (0.388)	Loss 0.0475 (0.0499)
# Epoch: [21][100/134]	Time 0.409 (0.409)	Data 0.389 (0.388)	Loss 0.0520 (0.0505)
# Epoch: [21][125/134]	Time 0.417 (0.409)	Data 0.397 (0.388)	Loss 0.0582 (0.0504)
# Finished training epoch 21
# Validate: [0/34]	Time 0.396 (0.396)	Loss 0.0397 (0.0397)
# Validate: [25/34]	Time 0.444 (0.409)	Loss 0.0509 (0.0523)
# Finished validation.
# Starting training epoch 22
# Epoch: [22][0/134]	Time 0.406 (0.406)	Data 0.386 (0.386)	Loss 0.0466 (0.0466)
# Epoch: [22][25/134]	Time 0.423 (0.415)	Data 0.403 (0.394)	Loss 0.0591 (0.0513)
# Epoch: [22][50/134]	Time 0.401 (0.412)	Data 0.379 (0.391)	Loss 0.0465 (0.0503)
# Epoch: [22][75/134]	Time 0.417 (0.410)	Data 0.397 (0.390)	Loss 0.0412 (0.0503)
# Epoch: [22][100/134]	Time 0.409 (0.410)	Data 0.389 (0.389)	Loss 0.0575 (0.0506)
# Epoch: [22][125/134]	Time 0.404 (0.410)	Data 0.384 (0.389)	Loss 0.0572 (0.0507)
# Finished training epoch 22
# Validate: [0/34]	Time 0.394 (0.394)	Loss 0.0358 (0.0358)
# Validate: [25/34]	Time 0.447 (0.409)	Loss 0.0498 (0.0509)
# Finished validation.
# Starting training epoch 23
# Epoch: [23][0/134]	Time 0.407 (0.407)	Data 0.386 (0.386)	Loss 0.0518 (0.0518)
# Epoch: [23][25/134]	Time 0.424 (0.415)	Data 0.404 (0.394)	Loss 0.0493 (0.0516)
# Epoch: [23][50/134]	Time 0.393 (0.410)	Data 0.373 (0.389)	Loss 0.0444 (0.0510)
# Epoch: [23][75/134]	Time 0.417 (0.408)	Data 0.397 (0.387)	Loss 0.0679 (0.0509)
# Epoch: [23][100/134]	Time 0.398 (0.408)	Data 0.377 (0.387)	Loss 0.0491 (0.0505)
# Epoch: [23][125/134]	Time 0.403 (0.408)	Data 0.383 (0.387)	Loss 0.0497 (0.0505)
# Finished training epoch 23
# Validate: [0/34]	Time 0.397 (0.397)	Loss 0.0336 (0.0336)
# Validate: [25/34]	Time 0.437 (0.406)	Loss 0.0496 (0.0490)
# Finished validation.
# Starting training epoch 24
# Epoch: [24][0/134]	Time 0.402 (0.402)	Data 0.383 (0.383)	Loss 0.0469 (0.0469)
# Epoch: [24][25/134]	Time 0.421 (0.412)	Data 0.401 (0.391)	Loss 0.0499 (0.0488)
# Epoch: [24][50/134]	Time 0.410 (0.409)	Data 0.389 (0.388)	Loss 0.0408 (0.0502)
# Epoch: [24][75/134]	Time 0.412 (0.407)	Data 0.393 (0.387)	Loss 0.0531 (0.0500)
# Epoch: [24][100/134]	Time 0.397 (0.409)	Data 0.376 (0.388)	Loss 0.0539 (0.0501)
# Epoch: [24][125/134]	Time 0.404 (0.409)	Data 0.384 (0.388)	Loss 0.0527 (0.0502)
# Finished training epoch 24
# Validate: [0/34]	Time 0.399 (0.399)	Loss 0.0339 (0.0339)
# Validate: [25/34]	Time 0.453 (0.416)	Loss 0.0519 (0.0501)
# Finished validation.
# Starting training epoch 25
# Epoch: [25][0/134]	Time 0.403 (0.403)	Data 0.383 (0.383)	Loss 0.0521 (0.0521)
# Epoch: [25][25/134]	Time 0.416 (0.412)	Data 0.394 (0.391)	Loss 0.0388 (0.0497)
# Epoch: [25][50/134]	Time 0.406 (0.412)	Data 0.386 (0.391)	Loss 0.0465 (0.0490)
# Epoch: [25][75/134]	Time 0.416 (0.413)	Data 0.395 (0.392)	Loss 0.0736 (0.0499)
# Epoch: [25][100/134]	Time 0.407 (0.412)	Data 0.388 (0.391)	Loss 0.0407 (0.0501)
# Epoch: [25][125/134]	Time 0.404 (0.411)	Data 0.382 (0.390)	Loss 0.0619 (0.0504)
# Finished training epoch 25
# Validate: [0/34]	Time 0.400 (0.400)	Loss 0.0331 (0.0331)
# Validate: [25/34]	Time 0.450 (0.412)	Loss 0.0490 (0.0494)
# Finished validation.
# Starting training epoch 26
# Epoch: [26][0/134]	Time 0.400 (0.400)	Data 0.380 (0.380)	Loss 0.0476 (0.0476)
# Epoch: [26][25/134]	Time 0.407 (0.406)	Data 0.387 (0.385)	Loss 0.0499 (0.0514)
# Epoch: [26][50/134]	Time 0.402 (0.408)	Data 0.383 (0.388)	Loss 0.0433 (0.0514)
# Epoch: [26][75/134]	Time 0.433 (0.409)	Data 0.411 (0.388)	Loss 0.0481 (0.0508)
# Epoch: [26][100/134]	Time 0.396 (0.409)	Data 0.372 (0.388)	Loss 0.0473 (0.0503)
# Epoch: [26][125/134]	Time 0.404 (0.410)	Data 0.385 (0.389)	Loss 0.0460 (0.0505)
# Finished training epoch 26
# Validate: [0/34]	Time 0.396 (0.396)	Loss 0.0341 (0.0341)
# Validate: [25/34]	Time 0.436 (0.410)	Loss 0.0504 (0.0490)
# Finished validation.
# Starting training epoch 27
# Epoch: [27][0/134]	Time 0.399 (0.399)	Data 0.380 (0.380)	Loss 0.0468 (0.0468)
# Epoch: [27][25/134]	Time 0.418 (0.408)	Data 0.396 (0.388)	Loss 0.0606 (0.0502)
# Epoch: [27][50/134]	Time 0.398 (0.406)	Data 0.379 (0.386)	Loss 0.0502 (0.0509)
# Epoch: [27][75/134]	Time 0.407 (0.410)	Data 0.385 (0.389)	Loss 0.0386 (0.0496)
# Epoch: [27][100/134]	Time 0.395 (0.410)	Data 0.375 (0.389)	Loss 0.0447 (0.0496)
# Epoch: [27][125/134]	Time 0.396 (0.409)	Data 0.376 (0.389)	Loss 0.0440 (0.0496)
# Finished training epoch 27
# Validate: [0/34]	Time 0.392 (0.392)	Loss 0.0368 (0.0368)
# Validate: [25/34]	Time 0.441 (0.413)	Loss 0.0469 (0.0512)
# Finished validation.
# Starting training epoch 28
# Epoch: [28][0/134]	Time 0.561 (0.561)	Data 0.541 (0.541)	Loss 0.0455 (0.0455)
# Epoch: [28][25/134]	Time 0.413 (0.410)	Data 0.391 (0.390)	Loss 0.0521 (0.0506)
# Epoch: [28][50/134]	Time 0.407 (0.406)	Data 0.387 (0.385)	Loss 0.0580 (0.0509)
# Epoch: [28][75/134]	Time 0.396 (0.404)	Data 0.376 (0.384)	Loss 0.0496 (0.0507)
# Epoch: [28][100/134]	Time 0.407 (0.404)	Data 0.385 (0.383)	Loss 0.0531 (0.0502)
# Epoch: [28][125/134]	Time 0.403 (0.404)	Data 0.382 (0.383)	Loss 0.0465 (0.0497)
# Finished training epoch 28
# Validate: [0/34]	Time 0.389 (0.389)	Loss 0.0335 (0.0335)
# Validate: [25/34]	Time 0.439 (0.413)	Loss 0.0483 (0.0496)
# Finished validation.
# Starting training epoch 29
# Epoch: [29][0/134]	Time 0.399 (0.399)	Data 0.380 (0.380)	Loss 0.0558 (0.0558)
# Epoch: [29][25/134]	Time 0.413 (0.409)	Data 0.393 (0.389)	Loss 0.0538 (0.0502)
# Epoch: [29][50/134]	Time 0.397 (0.409)	Data 0.377 (0.389)	Loss 0.0364 (0.0488)
# Epoch: [29][75/134]	Time 0.400 (0.410)	Data 0.379 (0.390)	Loss 0.0473 (0.0490)
# Epoch: [29][100/134]	Time 0.394 (0.410)	Data 0.370 (0.389)	Loss 0.0451 (0.0497)
# Epoch: [29][125/134]	Time 0.406 (0.411)	Data 0.383 (0.390)	Loss 0.0431 (0.0498)
# Finished training epoch 29
# Validate: [0/34]	Time 0.403 (0.403)	Loss 0.0351 (0.0351)
# Validate: [25/34]	Time 0.440 (0.412)	Loss 0.0512 (0.0496)
# Finished validation.
# Starting training epoch 30
# Epoch: [30][0/134]	Time 0.418 (0.418)	Data 0.394 (0.394)	Loss 0.0580 (0.0580)
# Epoch: [30][25/134]	Time 0.409 (0.413)	Data 0.389 (0.392)	Loss 0.0559 (0.0499)
# Epoch: [30][50/134]	Time 0.412 (0.411)	Data 0.390 (0.390)	Loss 0.0480 (0.0495)
# Epoch: [30][75/134]	Time 0.424 (0.411)	Data 0.400 (0.390)	Loss 0.0454 (0.0500)
# Epoch: [30][100/134]	Time 0.395 (0.410)	Data 0.375 (0.389)	Loss 0.0473 (0.0495)
# Epoch: [30][125/134]	Time 0.571 (0.411)	Data 0.550 (0.390)	Loss 0.0444 (0.0499)
# Finished training epoch 30
# Validate: [0/34]	Time 0.402 (0.402)	Loss 0.0300 (0.0300)
# Validate: [25/34]	Time 0.441 (0.413)	Loss 0.0524 (0.0509)
# Finished validation.
# Starting training epoch 31
# Epoch: [31][0/134]	Time 0.401 (0.401)	Data 0.381 (0.381)	Loss 0.0470 (0.0470)
# Epoch: [31][25/134]	Time 0.421 (0.410)	Data 0.401 (0.389)	Loss 0.0462 (0.0518)
# Epoch: [31][50/134]	Time 0.402 (0.411)	Data 0.379 (0.390)	Loss 0.0527 (0.0507)
# Epoch: [31][75/134]	Time 0.408 (0.413)	Data 0.387 (0.392)	Loss 0.0471 (0.0505)
# Epoch: [31][100/134]	Time 0.403 (0.412)	Data 0.384 (0.392)	Loss 0.0435 (0.0505)
# Epoch: [31][125/134]	Time 0.416 (0.412)	Data 0.392 (0.391)	Loss 0.0521 (0.0503)
# Finished training epoch 31
# Validate: [0/34]	Time 0.388 (0.388)	Loss 0.0320 (0.0320)
# Validate: [25/34]	Time 0.439 (0.413)	Loss 0.0477 (0.0499)
# Finished validation.
# Starting training epoch 32
# Epoch: [32][0/134]	Time 0.405 (0.405)	Data 0.385 (0.385)	Loss 0.0432 (0.0432)
# Epoch: [32][25/134]	Time 0.409 (0.409)	Data 0.389 (0.388)	Loss 0.0452 (0.0484)
# Epoch: [32][50/134]	Time 0.416 (0.411)	Data 0.396 (0.390)	Loss 0.0497 (0.0502)
# Epoch: [32][75/134]	Time 0.408 (0.409)	Data 0.387 (0.388)	Loss 0.0482 (0.0499)
# Epoch: [32][100/134]	Time 0.401 (0.410)	Data 0.381 (0.389)	Loss 0.0671 (0.0498)
# Epoch: [32][125/134]	Time 0.425 (0.409)	Data 0.402 (0.388)	Loss 0.0472 (0.0502)
# Finished training epoch 32
# Validate: [0/34]	Time 0.402 (0.402)	Loss 0.0353 (0.0353)
# Validate: [25/34]	Time 0.446 (0.406)	Loss 0.0528 (0.0515)
# Finished validation.
# Starting training epoch 33
# Epoch: [33][0/134]	Time 0.399 (0.399)	Data 0.379 (0.379)	Loss 0.0539 (0.0539)
# Epoch: [33][25/134]	Time 0.410 (0.403)	Data 0.389 (0.382)	Loss 0.0510 (0.0480)
# Epoch: [33][50/134]	Time 0.399 (0.404)	Data 0.379 (0.383)	Loss 0.0434 (0.0492)
# Epoch: [33][75/134]	Time 0.407 (0.405)	Data 0.387 (0.385)	Loss 0.0597 (0.0500)
# Epoch: [33][100/134]	Time 0.393 (0.404)	Data 0.374 (0.384)	Loss 0.0478 (0.0501)
# Epoch: [33][125/134]	Time 0.400 (0.405)	Data 0.381 (0.384)	Loss 0.0466 (0.0500)
# Finished training epoch 33
# Validate: [0/34]	Time 0.387 (0.387)	Loss 0.0379 (0.0379)
# Validate: [25/34]	Time 0.427 (0.407)	Loss 0.0496 (0.0492)
# Finished validation.
# Starting training epoch 34
# Epoch: [34][0/134]	Time 0.407 (0.407)	Data 0.387 (0.387)	Loss 0.0584 (0.0584)
# Epoch: [34][25/134]	Time 0.414 (0.404)	Data 0.391 (0.383)	Loss 0.0569 (0.0517)
# Epoch: [34][50/134]	Time 0.403 (0.407)	Data 0.380 (0.386)	Loss 0.0404 (0.0501)
# Epoch: [34][75/134]	Time 0.412 (0.405)	Data 0.392 (0.384)	Loss 0.0507 (0.0497)
# Epoch: [34][100/134]	Time 0.555 (0.407)	Data 0.534 (0.386)	Loss 0.0353 (0.0492)
# Epoch: [34][125/134]	Time 0.403 (0.407)	Data 0.382 (0.386)	Loss 0.0599 (0.0494)
# Finished training epoch 34
# Validate: [0/34]	Time 0.386 (0.386)	Loss 0.0360 (0.0360)
# Validate: [25/34]	Time 0.445 (0.407)	Loss 0.0498 (0.0502)
# Finished validation.
# Starting training epoch 35
# Epoch: [35][0/134]	Time 0.398 (0.398)	Data 0.378 (0.378)	Loss 0.0467 (0.0467)
# Epoch: [35][25/134]	Time 0.412 (0.412)	Data 0.389 (0.391)	Loss 0.0598 (0.0513)
# Epoch: [35][50/134]	Time 0.407 (0.409)	Data 0.388 (0.388)	Loss 0.0474 (0.0489)
# Epoch: [35][75/134]	Time 0.419 (0.408)	Data 0.400 (0.387)	Loss 0.0537 (0.0496)
# Epoch: [35][100/134]	Time 0.402 (0.407)	Data 0.381 (0.387)	Loss 0.0502 (0.0497)
# Epoch: [35][125/134]	Time 0.401 (0.408)	Data 0.381 (0.387)	Loss 0.0467 (0.0494)
# Finished training epoch 35
# Validate: [0/34]	Time 0.403 (0.403)	Loss 0.0373 (0.0373)
# Validate: [25/34]	Time 0.441 (0.412)	Loss 0.0490 (0.0521)
# Finished validation.
# Starting training epoch 36
# Epoch: [36][0/134]	Time 0.406 (0.406)	Data 0.386 (0.386)	Loss 0.0480 (0.0480)
# Epoch: [36][25/134]	Time 0.411 (0.413)	Data 0.390 (0.393)	Loss 0.0578 (0.0516)
# Epoch: [36][50/134]	Time 0.408 (0.410)	Data 0.387 (0.389)	Loss 0.0607 (0.0519)
# Epoch: [36][75/134]	Time 0.412 (0.409)	Data 0.388 (0.388)	Loss 0.0474 (0.0512)
# Epoch: [36][100/134]	Time 0.413 (0.409)	Data 0.390 (0.388)	Loss 0.0460 (0.0503)
# Epoch: [36][125/134]	Time 0.405 (0.409)	Data 0.384 (0.388)	Loss 0.0526 (0.0499)
# Finished training epoch 36
# Validate: [0/34]	Time 0.392 (0.392)	Loss 0.0337 (0.0337)
# Validate: [25/34]	Time 0.435 (0.407)	Loss 0.0509 (0.0519)
# Finished validation.
# Starting training epoch 37
# Epoch: [37][0/134]	Time 0.403 (0.403)	Data 0.383 (0.383)	Loss 0.0435 (0.0435)
# Epoch: [37][25/134]	Time 0.406 (0.416)	Data 0.386 (0.395)	Loss 0.0473 (0.0504)
# Epoch: [37][50/134]	Time 0.402 (0.411)	Data 0.382 (0.390)	Loss 0.0429 (0.0511)
# Epoch: [37][75/134]	Time 0.409 (0.411)	Data 0.388 (0.390)	Loss 0.0579 (0.0510)
# Epoch: [37][100/134]	Time 0.410 (0.410)	Data 0.390 (0.390)	Loss 0.0414 (0.0512)
# Epoch: [37][125/134]	Time 0.422 (0.410)	Data 0.403 (0.390)	Loss 0.0497 (0.0509)
# Finished training epoch 37
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0352 (0.0352)
# Validate: [25/34]	Time 0.439 (0.412)	Loss 0.0489 (0.0489)
# Finished validation.
# Starting training epoch 38
# Epoch: [38][0/134]	Time 0.405 (0.405)	Data 0.384 (0.384)	Loss 0.0488 (0.0488)
# Epoch: [38][25/134]	Time 0.410 (0.407)	Data 0.390 (0.387)	Loss 0.0540 (0.0502)
# Epoch: [38][50/134]	Time 0.410 (0.409)	Data 0.387 (0.389)	Loss 0.0530 (0.0499)
# Epoch: [38][75/134]	Time 0.413 (0.409)	Data 0.394 (0.388)	Loss 0.0505 (0.0498)
# Epoch: [38][100/134]	Time 0.401 (0.411)	Data 0.381 (0.390)	Loss 0.0676 (0.0502)
# Epoch: [38][125/134]	Time 0.416 (0.410)	Data 0.392 (0.390)	Loss 0.0401 (0.0501)
# Finished training epoch 38
# Validate: [0/34]	Time 0.391 (0.391)	Loss 0.0395 (0.0395)
# Validate: [25/34]	Time 0.445 (0.413)	Loss 0.0535 (0.0505)
# Finished validation.
# Starting training epoch 39
# Epoch: [39][0/134]	Time 0.399 (0.399)	Data 0.379 (0.379)	Loss 0.0495 (0.0495)
# Epoch: [39][25/134]	Time 0.392 (0.406)	Data 0.371 (0.385)	Loss 0.0401 (0.0513)
# Epoch: [39][50/134]	Time 0.396 (0.402)	Data 0.376 (0.382)	Loss 0.0491 (0.0494)
# Epoch: [39][75/134]	Time 0.393 (0.402)	Data 0.373 (0.382)	Loss 0.0553 (0.0492)
# Epoch: [39][100/134]	Time 0.394 (0.403)	Data 0.371 (0.383)	Loss 0.0501 (0.0494)
# Epoch: [39][125/134]	Time 0.396 (0.405)	Data 0.376 (0.384)	Loss 0.0530 (0.0496)
# Finished training epoch 39
# Validate: [0/34]	Time 0.407 (0.407)	Loss 0.0343 (0.0343)
# Validate: [25/34]	Time 0.449 (0.416)	Loss 0.0515 (0.0487)
# Finished validation.
# Starting training epoch 40
# Epoch: [40][0/134]	Time 0.416 (0.416)	Data 0.396 (0.396)	Loss 0.0592 (0.0592)
# Epoch: [40][25/134]	Time 0.403 (0.410)	Data 0.383 (0.389)	Loss 0.0568 (0.0498)
# Epoch: [40][50/134]	Time 0.398 (0.409)	Data 0.378 (0.388)	Loss 0.0414 (0.0502)
# Epoch: [40][75/134]	Time 0.412 (0.410)	Data 0.392 (0.389)	Loss 0.0420 (0.0503)
# Epoch: [40][100/134]	Time 0.394 (0.411)	Data 0.374 (0.390)	Loss 0.0659 (0.0504)
# Epoch: [40][125/134]	Time 0.411 (0.411)	Data 0.391 (0.390)	Loss 0.0432 (0.0501)
# Finished training epoch 40
# Validate: [0/34]	Time 0.403 (0.403)	Loss 0.0334 (0.0334)
# Validate: [25/34]	Time 0.447 (0.413)	Loss 0.0491 (0.0502)
# Finished validation.
# Starting training epoch 41
# Epoch: [41][0/134]	Time 0.415 (0.415)	Data 0.392 (0.392)	Loss 0.0419 (0.0419)
# Epoch: [41][25/134]	Time 0.402 (0.408)	Data 0.383 (0.387)	Loss 0.0502 (0.0493)
# Epoch: [41][50/134]	Time 0.409 (0.403)	Data 0.388 (0.382)	Loss 0.0450 (0.0501)
# Epoch: [41][75/134]	Time 0.417 (0.403)	Data 0.395 (0.382)	Loss 0.0528 (0.0505)
# Epoch: [41][100/134]	Time 0.399 (0.405)	Data 0.379 (0.384)	Loss 0.0552 (0.0499)
# Epoch: [41][125/134]	Time 0.411 (0.404)	Data 0.391 (0.384)	Loss 0.0483 (0.0495)
# Finished training epoch 41
# Validate: [0/34]	Time 0.395 (0.395)	Loss 0.0328 (0.0328)
# Validate: [25/34]	Time 0.435 (0.412)	Loss 0.0501 (0.0493)
# Finished validation.
# Starting training epoch 42
# Epoch: [42][0/134]	Time 0.415 (0.415)	Data 0.392 (0.392)	Loss 0.0576 (0.0576)
# Epoch: [42][25/134]	Time 0.401 (0.401)	Data 0.382 (0.380)	Loss 0.0433 (0.0496)
# Epoch: [42][50/134]	Time 0.401 (0.404)	Data 0.382 (0.383)	Loss 0.0624 (0.0503)
# Epoch: [42][75/134]	Time 0.411 (0.403)	Data 0.391 (0.383)	Loss 0.0487 (0.0504)
# Epoch: [42][100/134]	Time 0.407 (0.404)	Data 0.386 (0.383)	Loss 0.0509 (0.0501)
# Epoch: [42][125/134]	Time 0.392 (0.405)	Data 0.372 (0.384)	Loss 0.0464 (0.0496)
# Finished training epoch 42
# Validate: [0/34]	Time 0.398 (0.398)	Loss 0.0342 (0.0342)
# Validate: [25/34]	Time 0.443 (0.415)	Loss 0.0568 (0.0535)
# Finished validation.
# Starting training epoch 43
# Epoch: [43][0/134]	Time 0.408 (0.408)	Data 0.387 (0.387)	Loss 0.0550 (0.0550)
# Epoch: [43][25/134]	Time 0.412 (0.411)	Data 0.389 (0.390)	Loss 0.0431 (0.0519)
# Epoch: [43][50/134]	Time 0.396 (0.407)	Data 0.377 (0.386)	Loss 0.0494 (0.0514)
# Epoch: [43][75/134]	Time 0.409 (0.407)	Data 0.390 (0.386)	Loss 0.0485 (0.0506)
# Epoch: [43][100/134]	Time 0.418 (0.409)	Data 0.395 (0.388)	Loss 0.0429 (0.0498)
# Epoch: [43][125/134]	Time 0.400 (0.409)	Data 0.379 (0.388)	Loss 0.0515 (0.0497)
# Finished training epoch 43
# Validate: [0/34]	Time 0.388 (0.388)	Loss 0.0346 (0.0346)
# Validate: [25/34]	Time 0.446 (0.413)	Loss 0.0503 (0.0487)
# Finished validation.
# Starting training epoch 44
# Epoch: [44][0/134]	Time 0.409 (0.409)	Data 0.389 (0.389)	Loss 0.0512 (0.0512)
# Epoch: [44][25/134]	Time 0.400 (0.405)	Data 0.381 (0.385)	Loss 0.0562 (0.0494)
# Epoch: [44][50/134]	Time 0.398 (0.405)	Data 0.374 (0.385)	Loss 0.0441 (0.0492)
# Epoch: [44][75/134]	Time 0.476 (0.405)	Data 0.457 (0.384)	Loss 0.0598 (0.0490)
# Epoch: [44][100/134]	Time 0.412 (0.405)	Data 0.391 (0.385)	Loss 0.0615 (0.0494)
# Epoch: [44][125/134]	Time 0.395 (0.405)	Data 0.376 (0.384)	Loss 0.0504 (0.0497)
# Finished training epoch 44
# Validate: [0/34]	Time 0.397 (0.397)	Loss 0.0343 (0.0343)
# Validate: [25/34]	Time 0.434 (0.413)	Loss 0.0504 (0.0490)
# Finished validation.
# Starting training epoch 45
# Epoch: [45][0/134]	Time 0.405 (0.405)	Data 0.385 (0.385)	Loss 0.0444 (0.0444)
# Epoch: [45][25/134]	Time 0.411 (0.411)	Data 0.391 (0.390)	Loss 0.0607 (0.0496)
# Epoch: [45][50/134]	Time 0.405 (0.408)	Data 0.385 (0.387)	Loss 0.0506 (0.0497)
# Epoch: [45][75/134]	Time 0.381 (0.405)	Data 0.362 (0.384)	Loss 0.0530 (0.0497)
# Epoch: [45][100/134]	Time 0.410 (0.407)	Data 0.387 (0.386)	Loss 0.0426 (0.0496)
# Epoch: [45][125/134]	Time 0.401 (0.405)	Data 0.380 (0.384)	Loss 0.0460 (0.0495)
# Finished training epoch 45
# Validate: [0/34]	Time 0.387 (0.387)	Loss 0.0371 (0.0371)
# Validate: [25/34]	Time 0.433 (0.410)	Loss 0.0490 (0.0505)
# Finished validation.
# Starting training epoch 46
# Epoch: [46][0/134]	Time 0.417 (0.417)	Data 0.393 (0.393)	Loss 0.0506 (0.0506)
# Epoch: [46][25/134]	Time 0.405 (0.405)	Data 0.385 (0.384)	Loss 0.0474 (0.0516)
# Epoch: [46][50/134]	Time 0.402 (0.408)	Data 0.381 (0.387)	Loss 0.0372 (0.0509)
# Epoch: [46][75/134]	Time 0.398 (0.405)	Data 0.379 (0.384)	Loss 0.0431 (0.0502)
# Epoch: [46][100/134]	Time 0.403 (0.403)	Data 0.382 (0.382)	Loss 0.0375 (0.0494)
# Epoch: [46][125/134]	Time 0.410 (0.403)	Data 0.388 (0.382)	Loss 0.0503 (0.0494)
# Finished training epoch 46
# Validate: [0/34]	Time 0.404 (0.404)	Loss 0.0337 (0.0337)
# Validate: [25/34]	Time 0.440 (0.410)	Loss 0.0494 (0.0496)
# Finished validation.
# Starting training epoch 47
# Epoch: [47][0/134]	Time 0.405 (0.405)	Data 0.383 (0.383)	Loss 0.0497 (0.0497)
# Epoch: [47][25/134]	Time 0.399 (0.403)	Data 0.379 (0.382)	Loss 0.0458 (0.0519)
# Epoch: [47][50/134]	Time 0.398 (0.404)	Data 0.376 (0.383)	Loss 0.0476 (0.0498)
# Epoch: [47][75/134]	Time 0.393 (0.402)	Data 0.372 (0.382)	Loss 0.0444 (0.0491)
# Epoch: [47][100/134]	Time 0.393 (0.402)	Data 0.372 (0.382)	Loss 0.0553 (0.0495)
# Epoch: [47][125/134]	Time 0.409 (0.403)	Data 0.386 (0.382)	Loss 0.0415 (0.0494)
# Finished training epoch 47
# Validate: [0/34]	Time 0.400 (0.400)	Loss 0.0354 (0.0354)
# Validate: [25/34]	Time 0.452 (0.410)	Loss 0.0502 (0.0495)
# Finished validation.
# Starting training epoch 48
# Epoch: [48][0/134]	Time 0.396 (0.396)	Data 0.376 (0.376)	Loss 0.0508 (0.0508)
# Epoch: [48][25/134]	Time 0.411 (0.402)	Data 0.388 (0.381)	Loss 0.0500 (0.0502)
# Epoch: [48][50/134]	Time 0.410 (0.402)	Data 0.390 (0.382)	Loss 0.0586 (0.0497)
# Epoch: [48][75/134]	Time 0.399 (0.402)	Data 0.379 (0.382)	Loss 0.0621 (0.0493)
# Epoch: [48][100/134]	Time 0.396 (0.402)	Data 0.377 (0.382)	Loss 0.0454 (0.0494)
# Epoch: [48][125/134]	Time 0.419 (0.402)	Data 0.399 (0.382)	Loss 0.0516 (0.0494)
# Finished training epoch 48
# Validate: [0/34]	Time 0.391 (0.391)	Loss 0.0385 (0.0385)
# Validate: [25/34]	Time 0.437 (0.412)	Loss 0.0507 (0.0503)
# Finished validation.
# Starting training epoch 49
# Epoch: [49][0/134]	Time 0.405 (0.405)	Data 0.385 (0.385)	Loss 0.0545 (0.0545)
# Epoch: [49][25/134]	Time 0.412 (0.417)	Data 0.392 (0.397)	Loss 0.0376 (0.0496)
# Epoch: [49][50/134]	Time 0.399 (0.409)	Data 0.379 (0.388)	Loss 0.0554 (0.0502)
# Epoch: [49][75/134]	Time 0.394 (0.406)	Data 0.374 (0.386)	Loss 0.0487 (0.0492)
# Epoch: [49][100/134]	Time 0.392 (0.405)	Data 0.372 (0.385)	Loss 0.0534 (0.0490)
# Epoch: [49][125/134]	Time 0.401 (0.405)	Data 0.378 (0.384)	Loss 0.0457 (0.0496)
# Finished training epoch 49
# Validate: [0/34]	Time 0.386 (0.386)	Loss 0.0400 (0.0400)
# Validate: [25/34]	Time 0.453 (0.408)	Loss 0.0524 (0.0500)
# Finished validation.
# Starting training epoch 50
# Epoch: [50][0/134]	Time 0.413 (0.413)	Data 0.392 (0.392)	Loss 0.0445 (0.0445)
# Epoch: [50][25/134]	Time 0.405 (0.402)	Data 0.383 (0.381)	Loss 0.0483 (0.0492)
# Epoch: [50][50/134]	Time 0.410 (0.401)	Data 0.390 (0.380)	Loss 0.0380 (0.0488)
# Epoch: [50][75/134]	Time 0.394 (0.401)	Data 0.372 (0.381)	Loss 0.0458 (0.0492)
# Epoch: [50][100/134]	Time 0.407 (0.400)	Data 0.387 (0.379)	Loss 0.0625 (0.0493)
# Epoch: [50][125/134]	Time 0.401 (0.399)	Data 0.381 (0.379)	Loss 0.0484 (0.0498)
# Finished training epoch 50
# Validate: [0/34]	Time 0.389 (0.389)	Loss 0.0329 (0.0329)
# Validate: [25/34]	Time 0.430 (0.406)	Loss 0.0521 (0.0493)
# Finished validation.
# Starting training epoch 51
# Epoch: [51][0/134]	Time 0.399 (0.399)	Data 0.380 (0.380)	Loss 0.0450 (0.0450)
# Epoch: [51][25/134]	Time 0.391 (0.395)	Data 0.370 (0.375)	Loss 0.0454 (0.0488)
# Epoch: [51][50/134]	Time 0.412 (0.398)	Data 0.391 (0.377)	Loss 0.0388 (0.0482)
# Epoch: [51][75/134]	Time 0.397 (0.397)	Data 0.376 (0.377)	Loss 0.0500 (0.0481)
# Epoch: [51][100/134]	Time 0.398 (0.398)	Data 0.375 (0.378)	Loss 0.0411 (0.0489)
# Epoch: [51][125/134]	Time 0.389 (0.400)	Data 0.367 (0.379)	Loss 0.0587 (0.0495)
# Finished training epoch 51
# Validate: [0/34]	Time 0.380 (0.380)	Loss 0.0339 (0.0339)
# Validate: [25/34]	Time 0.428 (0.405)	Loss 0.0532 (0.0514)
# Finished validation.
# Starting training epoch 52
# Epoch: [52][0/134]	Time 0.402 (0.402)	Data 0.382 (0.382)	Loss 0.0463 (0.0463)
# Epoch: [52][25/134]	Time 0.406 (0.395)	Data 0.386 (0.375)	Loss 0.0512 (0.0510)
# Epoch: [52][50/134]	Time 0.394 (0.401)	Data 0.373 (0.381)	Loss 0.0360 (0.0505)
# Epoch: [52][75/134]	Time 0.408 (0.401)	Data 0.388 (0.381)	Loss 0.0508 (0.0499)
# Epoch: [52][100/134]	Time 0.397 (0.400)	Data 0.377 (0.380)	Loss 0.0575 (0.0489)
# Epoch: [52][125/134]	Time 0.407 (0.402)	Data 0.388 (0.381)	Loss 0.0558 (0.0491)
# Finished training epoch 52
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0424 (0.0424)
# Validate: [25/34]	Time 0.447 (0.407)	Loss 0.0531 (0.0512)
# Finished validation.
# Starting training epoch 53
# Epoch: [53][0/134]	Time 0.406 (0.406)	Data 0.387 (0.387)	Loss 0.0469 (0.0469)
# Epoch: [53][25/134]	Time 0.421 (0.415)	Data 0.401 (0.394)	Loss 0.0478 (0.0492)
# Epoch: [53][50/134]	Time 0.396 (0.411)	Data 0.374 (0.390)	Loss 0.0532 (0.0496)
# Epoch: [53][75/134]	Time 0.415 (0.409)	Data 0.393 (0.388)	Loss 0.0568 (0.0499)
# Epoch: [53][100/134]	Time 0.406 (0.408)	Data 0.384 (0.387)	Loss 0.0435 (0.0496)
# Epoch: [53][125/134]	Time 0.381 (0.407)	Data 0.362 (0.386)	Loss 0.0473 (0.0494)
# Finished training epoch 53
# Validate: [0/34]	Time 0.384 (0.384)	Loss 0.0375 (0.0375)
# Validate: [25/34]	Time 0.439 (0.409)	Loss 0.0545 (0.0500)
# Finished validation.
# Starting training epoch 54
# Epoch: [54][0/134]	Time 0.399 (0.399)	Data 0.379 (0.379)	Loss 0.0509 (0.0509)
# Epoch: [54][25/134]	Time 0.415 (0.412)	Data 0.393 (0.392)	Loss 0.0470 (0.0503)
# Epoch: [54][50/134]	Time 0.403 (0.412)	Data 0.382 (0.391)	Loss 0.0533 (0.0502)
# Epoch: [54][75/134]	Time 0.398 (0.409)	Data 0.377 (0.388)	Loss 0.0446 (0.0497)
# Epoch: [54][100/134]	Time 0.398 (0.407)	Data 0.379 (0.386)	Loss 0.0514 (0.0495)
# Epoch: [54][125/134]	Time 0.397 (0.406)	Data 0.374 (0.385)	Loss 0.0466 (0.0494)
# Finished training epoch 54
# Validate: [0/34]	Time 0.389 (0.389)	Loss 0.0313 (0.0313)
# Validate: [25/34]	Time 0.441 (0.409)	Loss 0.0533 (0.0522)
# Finished validation.
# Starting training epoch 55
# Epoch: [55][0/134]	Time 0.403 (0.403)	Data 0.380 (0.380)	Loss 0.0476 (0.0476)
# Epoch: [55][25/134]	Time 0.398 (0.410)	Data 0.378 (0.389)	Loss 0.0425 (0.0486)
# Epoch: [55][50/134]	Time 0.422 (0.407)	Data 0.402 (0.386)	Loss 0.0571 (0.0485)
# Epoch: [55][75/134]	Time 0.397 (0.408)	Data 0.378 (0.387)	Loss 0.0527 (0.0493)
# Epoch: [55][100/134]	Time 0.427 (0.407)	Data 0.405 (0.387)	Loss 0.0515 (0.0494)
# Epoch: [55][125/134]	Time 0.409 (0.408)	Data 0.389 (0.387)	Loss 0.0538 (0.0494)
# Finished training epoch 55
# Validate: [0/34]	Time 0.396 (0.396)	Loss 0.0333 (0.0333)
# Validate: [25/34]	Time 0.441 (0.411)	Loss 0.0499 (0.0480)
# Finished validation.
# Starting training epoch 56
# Epoch: [56][0/134]	Time 0.399 (0.399)	Data 0.376 (0.376)	Loss 0.0468 (0.0468)
# Epoch: [56][25/134]	Time 0.412 (0.415)	Data 0.389 (0.394)	Loss 0.0588 (0.0501)
# Epoch: [56][50/134]	Time 0.403 (0.410)	Data 0.379 (0.389)	Loss 0.0550 (0.0494)
# Epoch: [56][75/134]	Time 0.423 (0.407)	Data 0.400 (0.386)	Loss 0.0461 (0.0497)
# Epoch: [56][100/134]	Time 0.416 (0.408)	Data 0.393 (0.387)	Loss 0.0570 (0.0493)
# Epoch: [56][125/134]	Time 0.396 (0.407)	Data 0.376 (0.386)	Loss 0.0383 (0.0493)
# Finished training epoch 56
# Validate: [0/34]	Time 0.385 (0.385)	Loss 0.0353 (0.0353)
# Validate: [25/34]	Time 0.435 (0.405)	Loss 0.0498 (0.0492)
# Finished validation.
# Starting training epoch 57
# Epoch: [57][0/134]	Time 0.404 (0.404)	Data 0.385 (0.385)	Loss 0.0535 (0.0535)
# Epoch: [57][25/134]	Time 0.403 (0.414)	Data 0.384 (0.393)	Loss 0.0511 (0.0493)
# Epoch: [57][50/134]	Time 0.398 (0.405)	Data 0.378 (0.384)	Loss 0.0474 (0.0489)
# Epoch: [57][75/134]	Time 0.403 (0.402)	Data 0.383 (0.381)	Loss 0.0348 (0.0487)
# Epoch: [57][100/134]	Time 0.387 (0.401)	Data 0.367 (0.380)	Loss 0.0450 (0.0489)
# Epoch: [57][125/134]	Time 0.401 (0.401)	Data 0.382 (0.381)	Loss 0.0509 (0.0489)
# Finished training epoch 57
# Validate: [0/34]	Time 0.388 (0.388)	Loss 0.0415 (0.0415)
# Validate: [25/34]	Time 0.429 (0.400)	Loss 0.0565 (0.0516)
# Finished validation.
# Starting training epoch 58
# Epoch: [58][0/134]	Time 0.396 (0.396)	Data 0.377 (0.377)	Loss 0.0435 (0.0435)
# Epoch: [58][25/134]	Time 0.406 (0.413)	Data 0.383 (0.392)	Loss 0.0511 (0.0495)
# Epoch: [58][50/134]	Time 0.382 (0.406)	Data 0.363 (0.386)	Loss 0.0437 (0.0484)
# Epoch: [58][75/134]	Time 0.422 (0.404)	Data 0.402 (0.383)	Loss 0.0490 (0.0486)
# Epoch: [58][100/134]	Time 0.413 (0.404)	Data 0.392 (0.384)	Loss 0.0430 (0.0491)
# Epoch: [58][125/134]	Time 0.403 (0.406)	Data 0.380 (0.385)	Loss 0.0502 (0.0492)
# Finished training epoch 58
# Validate: [0/34]	Time 0.398 (0.398)	Loss 0.0357 (0.0357)
# Validate: [25/34]	Time 0.443 (0.412)	Loss 0.0480 (0.0500)
# Finished validation.
# Starting training epoch 59
# Epoch: [59][0/134]	Time 0.399 (0.399)	Data 0.378 (0.378)	Loss 0.0506 (0.0506)
# Epoch: [59][25/134]	Time 0.408 (0.404)	Data 0.388 (0.383)	Loss 0.0623 (0.0500)
# Epoch: [59][50/134]	Time 0.388 (0.405)	Data 0.368 (0.384)	Loss 0.0485 (0.0495)
# Epoch: [59][75/134]	Time 0.394 (0.404)	Data 0.372 (0.384)	Loss 0.0465 (0.0490)
# Epoch: [59][100/134]	Time 0.384 (0.403)	Data 0.362 (0.383)	Loss 0.0502 (0.0487)
# Epoch: [59][125/134]	Time 0.423 (0.403)	Data 0.403 (0.383)	Loss 0.0531 (0.0488)
# Finished training epoch 59
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0348 (0.0348)
# Validate: [25/34]	Time 0.440 (0.408)	Loss 0.0493 (0.0484)
# Finished validation.
# Starting training epoch 60
# Epoch: [60][0/134]	Time 0.413 (0.413)	Data 0.392 (0.392)	Loss 0.0406 (0.0406)
# Epoch: [60][25/134]	Time 0.397 (0.397)	Data 0.378 (0.377)	Loss 0.0406 (0.0474)
# Epoch: [60][50/134]	Time 0.393 (0.398)	Data 0.370 (0.378)	Loss 0.0502 (0.0485)
# Epoch: [60][75/134]	Time 0.384 (0.397)	Data 0.363 (0.376)	Loss 0.0488 (0.0483)
# Epoch: [60][100/134]	Time 0.395 (0.399)	Data 0.373 (0.378)	Loss 0.0507 (0.0486)
# Epoch: [60][125/134]	Time 0.378 (0.399)	Data 0.358 (0.378)	Loss 0.0584 (0.0489)
# Finished training epoch 60
# Validate: [0/34]	Time 0.383 (0.383)	Loss 0.0353 (0.0353)
# Validate: [25/34]	Time 0.433 (0.404)	Loss 0.0533 (0.0495)
# Finished validation.
# Starting training epoch 61
# Epoch: [61][0/134]	Time 0.395 (0.395)	Data 0.376 (0.376)	Loss 0.0460 (0.0460)
# Epoch: [61][25/134]	Time 0.381 (0.400)	Data 0.362 (0.380)	Loss 0.0586 (0.0498)
# Epoch: [61][50/134]	Time 0.397 (0.401)	Data 0.377 (0.381)	Loss 0.0443 (0.0498)
# Epoch: [61][75/134]	Time 0.380 (0.399)	Data 0.360 (0.378)	Loss 0.0387 (0.0492)
# Epoch: [61][100/134]	Time 0.397 (0.398)	Data 0.377 (0.378)	Loss 0.0517 (0.0491)
# Epoch: [61][125/134]	Time 0.394 (0.401)	Data 0.374 (0.380)	Loss 0.0647 (0.0490)
# Finished training epoch 61
# Validate: [0/34]	Time 0.378 (0.378)	Loss 0.0319 (0.0319)
# Validate: [25/34]	Time 0.432 (0.400)	Loss 0.0509 (0.0491)
# Finished validation.
# Starting training epoch 62
# Epoch: [62][0/134]	Time 0.401 (0.401)	Data 0.382 (0.382)	Loss 0.0461 (0.0461)
# Epoch: [62][25/134]	Time 0.390 (0.404)	Data 0.371 (0.383)	Loss 0.0440 (0.0485)
# Epoch: [62][50/134]	Time 0.409 (0.404)	Data 0.389 (0.383)	Loss 0.0492 (0.0485)
# Epoch: [62][75/134]	Time 0.428 (0.403)	Data 0.408 (0.382)	Loss 0.0515 (0.0490)
# Epoch: [62][100/134]	Time 0.417 (0.404)	Data 0.395 (0.383)	Loss 0.0480 (0.0488)
# Epoch: [62][125/134]	Time 0.395 (0.403)	Data 0.374 (0.382)	Loss 0.0507 (0.0488)
# Finished training epoch 62
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0392 (0.0392)
# Validate: [25/34]	Time 0.435 (0.403)	Loss 0.0528 (0.0486)
# Finished validation.
# Starting training epoch 63
# Epoch: [63][0/134]	Time 0.393 (0.393)	Data 0.373 (0.373)	Loss 0.0507 (0.0507)
# Epoch: [63][25/134]	Time 0.379 (0.393)	Data 0.359 (0.373)	Loss 0.0453 (0.0495)
# Epoch: [63][50/134]	Time 0.412 (0.394)	Data 0.392 (0.374)	Loss 0.0468 (0.0494)
# Epoch: [63][75/134]	Time 0.409 (0.396)	Data 0.389 (0.376)	Loss 0.0553 (0.0492)
# Epoch: [63][100/134]	Time 0.462 (0.398)	Data 0.443 (0.377)	Loss 0.0440 (0.0489)
# Epoch: [63][125/134]	Time 0.411 (0.397)	Data 0.392 (0.376)	Loss 0.0490 (0.0491)
# Finished training epoch 63
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0332 (0.0332)
# Validate: [25/34]	Time 0.420 (0.396)	Loss 0.0510 (0.0491)
# Finished validation.
# Starting training epoch 64
# Epoch: [64][0/134]	Time 0.404 (0.404)	Data 0.382 (0.382)	Loss 0.0531 (0.0531)
# Epoch: [64][25/134]	Time 0.387 (0.395)	Data 0.365 (0.374)	Loss 0.0575 (0.0500)
# Epoch: [64][50/134]	Time 0.392 (0.392)	Data 0.372 (0.372)	Loss 0.0451 (0.0495)
# Epoch: [64][75/134]	Time 0.385 (0.393)	Data 0.365 (0.372)	Loss 0.0491 (0.0498)
# Epoch: [64][100/134]	Time 0.392 (0.393)	Data 0.373 (0.373)	Loss 0.0468 (0.0491)
# Epoch: [64][125/134]	Time 0.408 (0.395)	Data 0.385 (0.374)	Loss 0.0514 (0.0491)
# Finished training epoch 64
# Validate: [0/34]	Time 0.397 (0.397)	Loss 0.0375 (0.0375)
# Validate: [25/34]	Time 0.428 (0.394)	Loss 0.0489 (0.0483)
# Finished validation.
# Starting training epoch 65
# Epoch: [65][0/134]	Time 0.398 (0.398)	Data 0.377 (0.377)	Loss 0.0459 (0.0459)
# Epoch: [65][25/134]	Time 0.392 (0.393)	Data 0.372 (0.372)	Loss 0.0397 (0.0488)
# Epoch: [65][50/134]	Time 0.398 (0.396)	Data 0.377 (0.376)	Loss 0.0501 (0.0486)
# Epoch: [65][75/134]	Time 0.398 (0.394)	Data 0.378 (0.373)	Loss 0.0478 (0.0486)
# Epoch: [65][100/134]	Time 0.395 (0.395)	Data 0.372 (0.374)	Loss 0.0462 (0.0487)
# Epoch: [65][125/134]	Time 0.377 (0.394)	Data 0.356 (0.373)	Loss 0.0503 (0.0489)
# Finished training epoch 65
# Validate: [0/34]	Time 0.381 (0.381)	Loss 0.0362 (0.0362)
# Validate: [25/34]	Time 0.432 (0.389)	Loss 0.0493 (0.0482)
# Finished validation.
# Starting training epoch 66
# Epoch: [66][0/134]	Time 0.404 (0.404)	Data 0.382 (0.382)	Loss 0.0588 (0.0588)
# Epoch: [66][25/134]	Time 0.406 (0.395)	Data 0.384 (0.375)	Loss 0.0360 (0.0503)
# Epoch: [66][50/134]	Time 0.391 (0.391)	Data 0.369 (0.371)	Loss 0.0483 (0.0502)
# Epoch: [66][75/134]	Time 0.395 (0.390)	Data 0.375 (0.369)	Loss 0.0475 (0.0495)
# Epoch: [66][100/134]	Time 0.380 (0.393)	Data 0.357 (0.372)	Loss 0.0411 (0.0494)
# Epoch: [66][125/134]	Time 0.394 (0.393)	Data 0.375 (0.372)	Loss 0.0513 (0.0489)
# Finished training epoch 66
# Validate: [0/34]	Time 0.373 (0.373)	Loss 0.0322 (0.0322)
# Validate: [25/34]	Time 0.407 (0.392)	Loss 0.0537 (0.0507)
# Finished validation.
# Starting training epoch 67
# Epoch: [67][0/134]	Time 0.396 (0.396)	Data 0.376 (0.376)	Loss 0.0617 (0.0617)
# Epoch: [67][25/134]	Time 0.413 (0.398)	Data 0.390 (0.378)	Loss 0.0485 (0.0481)
# Epoch: [67][50/134]	Time 0.382 (0.398)	Data 0.364 (0.378)	Loss 0.0451 (0.0493)
# Epoch: [67][75/134]	Time 0.431 (0.399)	Data 0.412 (0.379)	Loss 0.0527 (0.0496)
# Epoch: [67][100/134]	Time 0.394 (0.402)	Data 0.372 (0.381)	Loss 0.0531 (0.0493)
# Epoch: [67][125/134]	Time 0.405 (0.402)	Data 0.382 (0.381)	Loss 0.0459 (0.0492)
# Finished training epoch 67
# Validate: [0/34]	Time 0.378 (0.378)	Loss 0.0332 (0.0332)
# Validate: [25/34]	Time 0.430 (0.403)	Loss 0.0494 (0.0481)
# Finished validation.
# Starting training epoch 68
# Epoch: [68][0/134]	Time 0.403 (0.403)	Data 0.379 (0.379)	Loss 0.0418 (0.0418)
# Epoch: [68][25/134]	Time 0.404 (0.406)	Data 0.384 (0.385)	Loss 0.0470 (0.0484)
# Epoch: [68][50/134]	Time 0.404 (0.403)	Data 0.381 (0.382)	Loss 0.0534 (0.0482)
# Epoch: [68][75/134]	Time 0.399 (0.401)	Data 0.379 (0.381)	Loss 0.0529 (0.0489)
# Epoch: [68][100/134]	Time 0.406 (0.402)	Data 0.382 (0.381)	Loss 0.0483 (0.0492)
# Epoch: [68][125/134]	Time 0.413 (0.402)	Data 0.393 (0.381)	Loss 0.0581 (0.0490)
# Finished training epoch 68
# Validate: [0/34]	Time 0.385 (0.385)	Loss 0.0383 (0.0383)
# Validate: [25/34]	Time 0.424 (0.401)	Loss 0.0512 (0.0494)
# Finished validation.
# Starting training epoch 69
# Epoch: [69][0/134]	Time 0.402 (0.402)	Data 0.381 (0.381)	Loss 0.0495 (0.0495)
# Epoch: [69][25/134]	Time 0.400 (0.400)	Data 0.381 (0.380)	Loss 0.0396 (0.0491)
# Epoch: [69][50/134]	Time 0.401 (0.401)	Data 0.382 (0.380)	Loss 0.0421 (0.0489)
# Epoch: [69][75/134]	Time 0.409 (0.399)	Data 0.387 (0.379)	Loss 0.0482 (0.0495)
# Epoch: [69][100/134]	Time 0.394 (0.399)	Data 0.374 (0.378)	Loss 0.0382 (0.0495)
# Epoch: [69][125/134]	Time 0.405 (0.402)	Data 0.385 (0.381)	Loss 0.0578 (0.0494)
# Finished training epoch 69
# Validate: [0/34]	Time 0.398 (0.398)	Loss 0.0438 (0.0438)
# Validate: [25/34]	Time 0.421 (0.404)	Loss 0.0552 (0.0526)
# Finished validation.
# Starting training epoch 70
# Epoch: [70][0/134]	Time 0.390 (0.390)	Data 0.370 (0.370)	Loss 0.0372 (0.0372)
# Epoch: [70][25/134]	Time 0.417 (0.403)	Data 0.397 (0.382)	Loss 0.0509 (0.0480)
# Epoch: [70][50/134]	Time 0.471 (0.403)	Data 0.452 (0.382)	Loss 0.0530 (0.0498)
# Epoch: [70][75/134]	Time 0.419 (0.403)	Data 0.396 (0.382)	Loss 0.0595 (0.0494)
# Epoch: [70][100/134]	Time 0.391 (0.404)	Data 0.371 (0.383)	Loss 0.0459 (0.0490)
# Epoch: [70][125/134]	Time 0.415 (0.404)	Data 0.395 (0.383)	Loss 0.0475 (0.0490)
# Finished training epoch 70
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0385 (0.0385)
# Validate: [25/34]	Time 0.437 (0.405)	Loss 0.0526 (0.0496)
# Finished validation.
# Starting training epoch 71
# Epoch: [71][0/134]	Time 0.403 (0.403)	Data 0.384 (0.384)	Loss 0.0584 (0.0584)
# Epoch: [71][25/134]	Time 0.400 (0.402)	Data 0.380 (0.382)	Loss 0.0461 (0.0496)
# Epoch: [71][50/134]	Time 0.421 (0.401)	Data 0.398 (0.380)	Loss 0.0485 (0.0493)
# Epoch: [71][75/134]	Time 0.391 (0.401)	Data 0.370 (0.380)	Loss 0.0547 (0.0484)
# Epoch: [71][100/134]	Time 0.396 (0.403)	Data 0.376 (0.382)	Loss 0.0423 (0.0486)
# Epoch: [71][125/134]	Time 0.402 (0.403)	Data 0.382 (0.382)	Loss 0.0472 (0.0485)
# Finished training epoch 71
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0355 (0.0355)
# ...
# Epoch: [76][50/134]	Time 0.413 (0.401)	Data 0.391 (0.381)	Loss 0.0499 (0.0493)
# Epoch: [76][75/134]	Time 0.407 (0.402)	Data 0.384 (0.381)	Loss 0.0462 (0.0493)
# Epoch: [76][100/134]	Time 0.390 (0.401)	Data 0.370 (0.380)	Loss 0.0435 (0.0493)
# Epoch: [76][125/134]	Time 0.399 (0.402)	Data 0.379 (0.381)	Loss 0.0590 (0.0490)
# Finished training epoch 76
# Validate: [0/34]	Time 0.398 (0.398)	Loss 0.0315 (0.0315)
# Validate: [25/34]	Time 0.423 (0.399)	Loss 0.0531 (0.0502)
# Finished validation.
# Starting training epoch 77
# Epoch: [77][0/134]	Time 0.413 (0.413)	Data 0.391 (0.391)	Loss 0.0494 (0.0494)
# Epoch: [77][25/134]	Time 0.390 (0.401)	Data 0.370 (0.381)	Loss 0.0499 (0.0475)
# Epoch: [77][50/134]	Time 0.392 (0.402)	Data 0.373 (0.381)	Loss 0.0668 (0.0486)
# Epoch: [77][75/134]	Time 0.398 (0.400)	Data 0.378 (0.379)	Loss 0.0474 (0.0486)
# Epoch: [77][100/134]	Time 0.398 (0.399)	Data 0.379 (0.378)	Loss 0.0565 (0.0493)
# Epoch: [77][125/134]	Time 0.405 (0.400)	Data 0.385 (0.379)	Loss 0.0485 (0.0489)
# Finished training epoch 77
# Validate: [0/34]	Time 0.389 (0.389)	Loss 0.0336 (0.0336)
# Validate: [25/34]	Time 0.418 (0.400)	Loss 0.0505 (0.0498)
# Finished validation.
# Starting training epoch 78
# Epoch: [78][0/134]	Time 0.400 (0.400)	Data 0.381 (0.381)	Loss 0.0516 (0.0516)
# Epoch: [78][25/134]	Time 0.399 (0.405)	Data 0.379 (0.385)	Loss 0.0458 (0.0487)
# Epoch: [78][50/134]	Time 0.396 (0.402)	Data 0.376 (0.382)	Loss 0.0457 (0.0501)
# Epoch: [78][75/134]	Time 0.385 (0.402)	Data 0.366 (0.381)	Loss 0.0496 (0.0498)
# Epoch: [78][100/134]	Time 0.420 (0.402)	Data 0.398 (0.382)	Loss 0.0460 (0.0496)
# Epoch: [78][125/134]	Time 0.413 (0.404)	Data 0.391 (0.383)	Loss 0.0425 (0.0493)
# Finished training epoch 78
# Validate: [0/34]	Time 0.396 (0.396)	Loss 0.0375 (0.0375)
# Validate: [25/34]	Time 0.431 (0.402)	Loss 0.0526 (0.0491)
# Finished validation.
# Starting training epoch 79
# Epoch: [79][0/134]	Time 0.406 (0.406)	Data 0.382 (0.382)	Loss 0.0585 (0.0585)
# Epoch: [79][25/134]	Time 0.402 (0.403)	Data 0.378 (0.381)	Loss 0.0465 (0.0477)
# Epoch: [79][50/134]	Time 0.393 (0.401)	Data 0.374 (0.380)	Loss 0.0646 (0.0497)
# Epoch: [79][75/134]	Time 0.406 (0.402)	Data 0.385 (0.381)	Loss 0.0537 (0.0497)
# Epoch: [79][100/134]	Time 0.411 (0.403)	Data 0.392 (0.382)	Loss 0.0467 (0.0486)
# Epoch: [79][125/134]	Time 0.411 (0.404)	Data 0.389 (0.383)	Loss 0.0469 (0.0487)
# Finished training epoch 79
# Validate: [0/34]	Time 0.387 (0.387)	Loss 0.0332 (0.0332)
# Validate: [25/34]	Time 0.424 (0.401)	Loss 0.0513 (0.0498)
# Finished validation.
# Starting training epoch 80
# Epoch: [80][0/134]	Time 0.395 (0.395)	Data 0.375 (0.375)	Loss 0.0471 (0.0471)
# Epoch: [80][25/134]	Time 0.403 (0.397)	Data 0.381 (0.376)	Loss 0.0487 (0.0468)
# Epoch: [80][50/134]	Time 0.397 (0.399)	Data 0.377 (0.378)	Loss 0.0569 (0.0472)
# Epoch: [80][75/134]	Time 0.395 (0.401)	Data 0.375 (0.381)	Loss 0.0533 (0.0486)
# Epoch: [80][100/134]	Time 0.390 (0.400)	Data 0.369 (0.380)	Loss 0.0398 (0.0485)
# Epoch: [80][125/134]	Time 0.402 (0.400)	Data 0.377 (0.380)	Loss 0.0497 (0.0483)
# Finished training epoch 80
# Validate: [0/34]	Time 0.392 (0.392)	Loss 0.0351 (0.0351)
# Validate: [25/34]	Time 0.433 (0.407)	Loss 0.0481 (0.0492)
# Finished validation.
# Starting training epoch 81
# Epoch: [81][0/134]	Time 0.414 (0.414)	Data 0.393 (0.393)	Loss 0.0547 (0.0547)
# Epoch: [81][25/134]	Time 0.411 (0.401)	Data 0.387 (0.380)	Loss 0.0433 (0.0501)
# Epoch: [81][50/134]	Time 0.409 (0.402)	Data 0.385 (0.382)	Loss 0.0463 (0.0489)
# Epoch: [81][75/134]	Time 0.414 (0.403)	Data 0.394 (0.382)	Loss 0.0534 (0.0494)
# Epoch: [81][100/134]	Time 0.396 (0.403)	Data 0.375 (0.383)	Loss 0.0421 (0.0489)
# Epoch: [81][125/134]	Time 0.400 (0.403)	Data 0.379 (0.382)	Loss 0.0598 (0.0488)
# Finished training epoch 81
# Validate: [0/34]	Time 0.401 (0.401)	Loss 0.0334 (0.0334)
# Validate: [25/34]	Time 0.426 (0.402)	Loss 0.0523 (0.0496)
# Finished validation.
# Starting training epoch 82
# Epoch: [82][0/134]	Time 0.412 (0.412)	Data 0.393 (0.393)	Loss 0.0492 (0.0492)
# Epoch: [82][25/134]	Time 0.394 (0.398)	Data 0.373 (0.378)	Loss 0.0441 (0.0487)
# Epoch: [82][50/134]	Time 0.400 (0.402)	Data 0.380 (0.382)	Loss 0.0602 (0.0490)
# Epoch: [82][75/134]	Time 0.399 (0.400)	Data 0.378 (0.380)	Loss 0.0508 (0.0495)
# Epoch: [82][100/134]	Time 0.394 (0.399)	Data 0.375 (0.379)	Loss 0.0438 (0.0491)
# Epoch: [82][125/134]	Time 0.398 (0.399)	Data 0.378 (0.378)	Loss 0.0493 (0.0489)
# Finished training epoch 82
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0414 (0.0414)
# Validate: [25/34]	Time 0.427 (0.398)	Loss 0.0511 (0.0508)
# Finished validation.
# Starting training epoch 83
# Epoch: [83][0/134]	Time 0.388 (0.388)	Data 0.369 (0.369)	Loss 0.0461 (0.0461)
# Epoch: [83][25/134]	Time 0.397 (0.401)	Data 0.378 (0.380)	Loss 0.0511 (0.0494)
# Epoch: [83][50/134]	Time 0.410 (0.398)	Data 0.390 (0.378)	Loss 0.0578 (0.0478)
# Epoch: [83][75/134]	Time 0.406 (0.398)	Data 0.385 (0.378)	Loss 0.0442 (0.0481)
# Epoch: [83][100/134]	Time 0.395 (0.400)	Data 0.375 (0.380)	Loss 0.0448 (0.0485)
# Epoch: [83][125/134]	Time 0.393 (0.400)	Data 0.373 (0.379)	Loss 0.0424 (0.0487)
# Finished training epoch 83
# Validate: [0/34]	Time 0.386 (0.386)	Loss 0.0352 (0.0352)
# Validate: [25/34]	Time 0.419 (0.396)	Loss 0.0514 (0.0478)
# Finished validation.
# Starting training epoch 84
# Epoch: [84][0/134]	Time 0.398 (0.398)	Data 0.375 (0.375)	Loss 0.0447 (0.0447)
# Epoch: [84][25/134]	Time 0.399 (0.398)	Data 0.379 (0.378)	Loss 0.0450 (0.0473)
# Epoch: [84][50/134]	Time 0.396 (0.398)	Data 0.371 (0.377)	Loss 0.0457 (0.0485)
# Epoch: [84][75/134]	Time 0.392 (0.398)	Data 0.371 (0.377)	Loss 0.0473 (0.0484)
# Epoch: [84][100/134]	Time 0.390 (0.399)	Data 0.370 (0.379)	Loss 0.0506 (0.0480)
# Epoch: [84][125/134]	Time 0.413 (0.401)	Data 0.394 (0.380)	Loss 0.0501 (0.0484)
# Finished training epoch 84
# Validate: [0/34]	Time 0.394 (0.394)	Loss 0.0339 (0.0339)
# Validate: [25/34]	Time 0.430 (0.399)	Loss 0.0505 (0.0498)
# Finished validation.
# Starting training epoch 85
# Epoch: [85][0/134]	Time 0.394 (0.394)	Data 0.372 (0.372)	Loss 0.0435 (0.0435)
# Epoch: [85][25/134]	Time 0.399 (0.395)	Data 0.377 (0.375)	Loss 0.0459 (0.0501)
# Epoch: [85][50/134]	Time 0.420 (0.398)	Data 0.401 (0.378)	Loss 0.0414 (0.0497)
# Epoch: [85][75/134]	Time 0.387 (0.400)	Data 0.368 (0.380)	Loss 0.0528 (0.0493)
# Epoch: [85][100/134]	Time 0.414 (0.405)	Data 0.394 (0.384)	Loss 0.0384 (0.0489)
# Epoch: [85][125/134]	Time 0.419 (0.406)	Data 0.396 (0.385)	Loss 0.0430 (0.0487)
# Finished training epoch 85
# Validate: [0/34]	Time 0.389 (0.389)	Loss 0.0340 (0.0340)
# Validate: [25/34]	Time 0.428 (0.397)	Loss 0.0471 (0.0481)
# Finished validation.
# Starting training epoch 86
# Epoch: [86][0/134]	Time 0.408 (0.408)	Data 0.386 (0.386)	Loss 0.0548 (0.0548)
# Epoch: [86][25/134]	Time 0.417 (0.395)	Data 0.396 (0.375)	Loss 0.0531 (0.0484)
# Epoch: [86][50/134]	Time 0.409 (0.397)	Data 0.386 (0.376)	Loss 0.0442 (0.0487)
# Epoch: [86][75/134]	Time 0.395 (0.401)	Data 0.372 (0.381)	Loss 0.0486 (0.0485)
# Epoch: [86][100/134]	Time 0.412 (0.404)	Data 0.392 (0.383)	Loss 0.0551 (0.0486)
# Epoch: [86][125/134]	Time 0.401 (0.405)	Data 0.379 (0.385)	Loss 0.0449 (0.0487)
# Finished training epoch 86
# Validate: [0/34]	Time 0.387 (0.387)	Loss 0.0315 (0.0315)
# Validate: [25/34]	Time 0.441 (0.401)	Loss 0.0533 (0.0503)
# Finished validation.
# Starting training epoch 87
# Epoch: [87][0/134]	Time 0.398 (0.398)	Data 0.376 (0.376)	Loss 0.0555 (0.0555)
# Epoch: [87][25/134]	Time 0.400 (0.406)	Data 0.380 (0.385)	Loss 0.0529 (0.0479)
# Epoch: [87][50/134]	Time 0.409 (0.408)	Data 0.390 (0.388)	Loss 0.0570 (0.0492)
# Epoch: [87][75/134]	Time 0.421 (0.406)	Data 0.401 (0.386)	Loss 0.0483 (0.0491)
# Epoch: [87][100/134]	Time 0.397 (0.406)	Data 0.377 (0.385)	Loss 0.0537 (0.0491)
# Epoch: [87][125/134]	Time 0.401 (0.406)	Data 0.379 (0.385)	Loss 0.0499 (0.0485)
# Finished training epoch 87
# Validate: [0/34]	Time 0.392 (0.392)	Loss 0.0458 (0.0458)
# Validate: [25/34]	Time 0.441 (0.401)	Loss 0.0575 (0.0522)
# Finished validation.
# Starting training epoch 88
# Epoch: [88][0/134]	Time 0.400 (0.400)	Data 0.381 (0.381)	Loss 0.0434 (0.0434)
# Epoch: [88][25/134]	Time 0.425 (0.402)	Data 0.405 (0.381)	Loss 0.0531 (0.0487)
# Epoch: [88][50/134]	Time 0.381 (0.404)	Data 0.361 (0.383)	Loss 0.0525 (0.0485)
# Epoch: [88][75/134]	Time 0.396 (0.406)	Data 0.376 (0.385)	Loss 0.0440 (0.0485)
# Epoch: [88][100/134]	Time 0.408 (0.407)	Data 0.386 (0.386)	Loss 0.0441 (0.0485)
# Epoch: [88][125/134]	Time 0.408 (0.407)	Data 0.388 (0.386)	Loss 0.0406 (0.0484)
# Finished training epoch 88
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0326 (0.0326)
# Validate: [25/34]	Time 0.426 (0.401)	Loss 0.0491 (0.0488)
# Finished validation.
# Starting training epoch 89
# Epoch: [89][0/134]	Time 0.406 (0.406)	Data 0.383 (0.383)	Loss 0.0421 (0.0421)
# Epoch: [89][25/134]	Time 0.400 (0.396)	Data 0.380 (0.375)	Loss 0.0475 (0.0470)
# Epoch: [89][50/134]	Time 0.401 (0.396)	Data 0.381 (0.376)	Loss 0.0496 (0.0476)
# Epoch: [89][75/134]	Time 0.402 (0.399)	Data 0.382 (0.379)	Loss 0.0460 (0.0472)
# Epoch: [89][100/134]	Time 0.400 (0.400)	Data 0.381 (0.380)	Loss 0.0445 (0.0477)
# Epoch: [89][125/134]	Time 0.399 (0.401)	Data 0.379 (0.380)	Loss 0.0547 (0.0481)
# Finished training epoch 89
# Validate: [0/34]	Time 0.390 (0.390)	Loss 0.0329 (0.0329)
# Validate: [25/34]	Time 0.449 (0.408)	Loss 0.0487 (0.0479)
# Finished validation.
# Starting training epoch 90
# Epoch: [90][0/134]	Time 0.409 (0.409)	Data 0.389 (0.389)	Loss 0.0549 (0.0549)
# Epoch: [90][25/134]	Time 0.402 (0.402)	Data 0.381 (0.381)	Loss 0.0434 (0.0481)
# Epoch: [90][50/134]	Time 0.402 (0.406)	Data 0.380 (0.385)	Loss 0.0514 (0.0482)
# Epoch: [90][75/134]	Time 0.416 (0.405)	Data 0.396 (0.384)	Loss 0.0466 (0.0483)
# Epoch: [90][100/134]	Time 0.403 (0.407)	Data 0.383 (0.386)	Loss 0.0442 (0.0484)
# Epoch: [90][125/134]	Time 0.391 (0.408)	Data 0.372 (0.387)	Loss 0.0394 (0.0481)
# Finished training epoch 90
# Validate: [0/34]	Time 0.395 (0.395)	Loss 0.0352 (0.0352)
# Validate: [25/34]	Time 0.441 (0.407)	Loss 0.0514 (0.0492)
# Finished validation.
# Starting training epoch 91
# Epoch: [91][0/134]	Time 0.417 (0.417)	Data 0.397 (0.397)	Loss 0.0527 (0.0527)
# Epoch: [91][25/134]	Time 0.399 (0.402)	Data 0.378 (0.381)	Loss 0.0470 (0.0500)
# Epoch: [91][50/134]	Time 0.397 (0.400)	Data 0.378 (0.379)	Loss 0.0534 (0.0493)
# Epoch: [91][75/134]	Time 0.392 (0.400)	Data 0.372 (0.379)	Loss 0.0470 (0.0489)
# Epoch: [91][100/134]	Time 0.400 (0.400)	Data 0.380 (0.379)	Loss 0.0507 (0.0487)
# Epoch: [91][125/134]	Time 0.395 (0.401)	Data 0.376 (0.380)	Loss 0.0495 (0.0490)
# Finished training epoch 91
# Validate: [0/34]	Time 0.394 (0.394)	Loss 0.0363 (0.0363)
# Validate: [25/34]	Time 0.423 (0.397)	Loss 0.0510 (0.0480)
# Finished validation.
# Starting training epoch 92
# Epoch: [92][0/134]	Time 0.393 (0.393)	Data 0.374 (0.374)	Loss 0.0597 (0.0597)
# Epoch: [92][25/134]	Time 0.385 (0.393)	Data 0.365 (0.373)	Loss 0.0530 (0.0494)
# Epoch: [92][50/134]	Time 0.401 (0.396)	Data 0.379 (0.375)	Loss 0.0538 (0.0484)
# Epoch: [92][75/134]	Time 0.405 (0.399)	Data 0.386 (0.378)	Loss 0.0594 (0.0488)
# Epoch: [92][100/134]	Time 0.404 (0.400)	Data 0.384 (0.379)	Loss 0.0406 (0.0492)
# Epoch: [92][125/134]	Time 0.387 (0.401)	Data 0.368 (0.380)	Loss 0.0533 (0.0489)
# Finished training epoch 92
# Validate: [0/34]	Time 0.401 (0.401)	Loss 0.0353 (0.0353)
# Validate: [25/34]	Time 0.425 (0.404)	Loss 0.0486 (0.0476)
# Finished validation.
# Starting training epoch 93
# Epoch: [93][0/134]	Time 0.393 (0.393)	Data 0.374 (0.374)	Loss 0.0429 (0.0429)
# Epoch: [93][25/134]	Time 0.397 (0.399)	Data 0.378 (0.378)	Loss 0.0450 (0.0465)
# Epoch: [93][50/134]	Time 0.406 (0.398)	Data 0.386 (0.378)	Loss 0.0506 (0.0475)
# Epoch: [93][75/134]	Time 0.405 (0.399)	Data 0.385 (0.378)	Loss 0.0435 (0.0478)
# Epoch: [93][100/134]	Time 0.396 (0.399)	Data 0.376 (0.378)	Loss 0.0537 (0.0480)
# Epoch: [93][125/134]	Time 0.403 (0.401)	Data 0.380 (0.380)	Loss 0.0476 (0.0480)
# Finished training epoch 93
# Validate: [0/34]	Time 0.394 (0.394)	Loss 0.0313 (0.0313)
# Validate: [25/34]	Time 0.430 (0.401)	Loss 0.0492 (0.0485)
# Finished validation.
# Starting training epoch 94
# Epoch: [94][0/134]	Time 0.407 (0.407)	Data 0.387 (0.387)	Loss 0.0570 (0.0570)
# Epoch: [94][25/134]	Time 0.393 (0.400)	Data 0.372 (0.378)	Loss 0.0618 (0.0494)
# Epoch: [94][50/134]	Time 0.399 (0.400)	Data 0.379 (0.379)	Loss 0.0453 (0.0487)
# Epoch: [94][75/134]	Time 0.398 (0.400)	Data 0.378 (0.379)	Loss 0.0464 (0.0486)
# Epoch: [94][100/134]	Time 0.401 (0.403)	Data 0.381 (0.382)	Loss 0.0458 (0.0487)
# Epoch: [94][125/134]	Time 0.409 (0.402)	Data 0.388 (0.382)	Loss 0.0410 (0.0485)
# Finished training epoch 94
# Validate: [0/34]	Time 0.394 (0.394)	Loss 0.0351 (0.0351)
# Validate: [25/34]	Time 0.445 (0.400)	Loss 0.0492 (0.0485)
# Finished validation.
# Starting training epoch 95
# Epoch: [95][0/134]	Time 0.407 (0.407)	Data 0.386 (0.386)	Loss 0.0460 (0.0460)
# Epoch: [95][25/134]	Time 0.397 (0.398)	Data 0.378 (0.378)	Loss 0.0474 (0.0495)
# Epoch: [95][50/134]	Time 0.398 (0.399)	Data 0.376 (0.379)	Loss 0.0502 (0.0496)
# Epoch: [95][75/134]	Time 0.418 (0.402)	Data 0.397 (0.382)	Loss 0.0489 (0.0498)
# Epoch: [95][100/134]	Time 0.408 (0.401)	Data 0.389 (0.381)	Loss 0.0513 (0.0490)
# Epoch: [95][125/134]	Time 0.398 (0.402)	Data 0.377 (0.381)	Loss 0.0476 (0.0489)
# Finished training epoch 95
# Validate: [0/34]	Time 0.388 (0.388)	Loss 0.0344 (0.0344)
# Validate: [25/34]	Time 0.433 (0.404)	Loss 0.0491 (0.0498)
# Finished validation.
# Starting training epoch 96
# Epoch: [96][0/134]	Time 0.411 (0.411)	Data 0.391 (0.391)	Loss 0.0454 (0.0454)
# Epoch: [96][25/134]	Time 0.399 (0.400)	Data 0.379 (0.380)	Loss 0.0558 (0.0473)
# Epoch: [96][50/134]	Time 0.396 (0.402)	Data 0.376 (0.382)	Loss 0.0373 (0.0488)
# Epoch: [96][75/134]	Time 0.399 (0.402)	Data 0.378 (0.381)	Loss 0.0427 (0.0483)
# Epoch: [96][100/134]	Time 0.407 (0.401)	Data 0.386 (0.381)	Loss 0.0442 (0.0480)
# Epoch: [96][125/134]	Time 0.412 (0.402)	Data 0.392 (0.382)	Loss 0.0426 (0.0479)
# Finished training epoch 96
# Validate: [0/34]	Time 0.387 (0.387)	Loss 0.0326 (0.0326)
# Validate: [25/34]	Time 0.427 (0.404)	Loss 0.0511 (0.0489)
# Finished validation.
# Starting training epoch 97
# Epoch: [97][0/134]	Time 0.407 (0.407)	Data 0.387 (0.387)	Loss 0.0470 (0.0470)
# Epoch: [97][25/134]	Time 0.388 (0.399)	Data 0.368 (0.379)	Loss 0.0566 (0.0498)
# Epoch: [97][50/134]	Time 0.402 (0.399)	Data 0.381 (0.379)	Loss 0.0448 (0.0489)
# Epoch: [97][75/134]	Time 0.396 (0.401)	Data 0.376 (0.381)	Loss 0.0439 (0.0481)
# Epoch: [97][100/134]	Time 0.395 (0.401)	Data 0.375 (0.380)	Loss 0.0465 (0.0483)
# Epoch: [97][125/134]	Time 0.395 (0.400)	Data 0.375 (0.379)	Loss 0.0438 (0.0485)
# Finished training epoch 97
# Validate: [0/34]	Time 0.389 (0.389)	Loss 0.0343 (0.0343)
# Validate: [25/34]	Time 0.439 (0.403)	Loss 0.0596 (0.0552)
# Finished validation.
# Starting training epoch 98
# Epoch: [98][0/134]	Time 0.392 (0.392)	Data 0.367 (0.367)	Loss 0.0462 (0.0462)
# Epoch: [98][25/134]	Time 0.400 (0.397)	Data 0.380 (0.376)	Loss 0.0591 (0.0477)
# Epoch: [98][50/134]	Time 0.398 (0.397)	Data 0.377 (0.376)	Loss 0.0473 (0.0493)
# Epoch: [98][75/134]	Time 0.400 (0.400)	Data 0.378 (0.379)	Loss 0.0415 (0.0492)
# Epoch: [98][100/134]	Time 0.398 (0.399)	Data 0.378 (0.378)	Loss 0.0482 (0.0487)
# Epoch: [98][125/134]	Time 0.398 (0.400)	Data 0.378 (0.379)	Loss 0.0402 (0.0484)
# Finished training epoch 98
# Validate: [0/34]	Time 0.394 (0.394)	Loss 0.0312 (0.0312)
# Validate: [25/34]	Time 0.427 (0.401)	Loss 0.0494 (0.0496)
# Finished validation.
# Starting training epoch 99
# Epoch: [99][0/134]	Time 0.398 (0.398)	Data 0.379 (0.379)	Loss 0.0648 (0.0648)
# Epoch: [99][25/134]	Time 0.408 (0.400)	Data 0.388 (0.379)	Loss 0.0455 (0.0471)
# Epoch: [99][50/134]	Time 0.402 (0.399)	Data 0.382 (0.378)	Loss 0.0492 (0.0479)
# Epoch: [99][75/134]	Time 0.403 (0.400)	Data 0.380 (0.379)	Loss 0.0412 (0.0481)
# Epoch: [99][100/134]	Time 0.394 (0.402)	Data 0.373 (0.382)	Loss 0.0530 (0.0482)
# Epoch: [99][125/134]	Time 0.385 (0.401)	Data 0.365 (0.380)	Loss 0.0503 (0.0481)
# Finished training epoch 99
# Validate: [0/34]	Time 0.387 (0.387)	Loss 0.0330 (0.0330)
# Validate: [25/34]	Time 0.420 (0.400)	Loss 0.0505 (0.0508)
# Finished validation.

# %%
## ====================== Pretrained model:
# data = next(iter(train_loader))
# Ls     = data[0] 
# abs_   = data[1] 
# target = data[2]

# print(f"Feature batch shape: {Ls.size()}")
# print(f"Labels batch shape: {abs_.size()}")

# img = Ls[0].squeeze()
# plt.imshow(img, cmap="gray")
# plt.show()

# Load model
check_point =  'checkpoints/model-epoch-90-losses-0.047.pth'
pretrained = torch.load(check_point, map_location=lambda storage, loc: storage)
model.load_state_dict(pretrained)

# Make folders and set parameters
import os
os.makedirs('outputs/color', exist_ok=True)
os.makedirs('outputs/gray', exist_ok=True)
save_images = True

# Validate
with torch.no_grad():
  validate(val_loader, model, criterion, save_images, 0)

# Show images 
import matplotlib.image as mpimg
image_pairs = [(f'outputs/color/img-{i}-epoch-0.jpg', 
                f'outputs/gray/img-{i}-epoch-0.jpg')
                 for i in range(0,10)]
for c, g in image_pairs:
  color = mpimg.imread(c)
  gray  = mpimg.imread(g)
  f, axarr = plt.subplots(1, 2)
  f.set_size_inches(15, 15)
  axarr[0].imshow(gray, cmap='gray')
  axarr[1].imshow(color)
  axarr[0].axis('off'), axarr[1].axis('off')
  plt.show()
# Out:
# Validate: [0/34]	Time 0.718 (0.718)	Loss 0.0329 (0.0329)
# Validate: [25/34]	Time 0.435 (0.417)	Loss 0.0487 (0.0479)
# Finished validation.
